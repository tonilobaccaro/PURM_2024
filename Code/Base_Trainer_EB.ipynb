# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import random
import sklearn
import collections
from sklearn.model_selection import train_test_split
import json
import pylab
from scipy.optimize import curve_fit
from tensorflow.keras import layers, Model
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, auc
import matplotlib
import matplotlib.patches as mpatches
#import shap
import os
import pandas as pd
#improve gpu memory usagef
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# %%
# Set matplotlib default color cycle
new_color_cycle = [
#jjJZ4
    '#4f2ca8',
#A14N23LO
    '#b45f06',
#HAHMggf
    '#ff0000',
#qqa
    '#d4d400',
#ZZ4lep
    '#294a18',
#Zprime2EJs
    '#00de00',
#HHbbttHadHad
    '#5b0f00',
#jjJZ2
  '#ca7dff',
#jjJZ1
  '#d201d2',
#data
# '#3232ff', 
#zerobias
    '#002a75',
#passedHLT
    '#00cdcd',
#jjJZ124
    '#8e1d55',
#test 2
    '#7f7f7f'
]

# You can then apply this new color cycle to your matplotlib plots
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=new_color_cycle)

# %% [markdown]
# ## Read Data Files

# %%
# This is the list that will hold all of the data 
datasets = {}

# %%
# Read Monte Carlo Simulated Collisions

data_path = '/home/jovyan/MC_data/'

for filename in os.listdir(data_path):

    if filename.startswith('N') or filename.startswith('.'): continue

    dataset_tag = filename.split('_')[0]
    
    with h5py.File(data_path+filename, 'r') as hf:
        HLT_jets = hf['HLT_jets'][:]
        L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
        L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
        HLT_electrons = hf['HLT_electrons'][:]
        LRT_electrons = hf['LRT_electrons'][:]
        L1_egammas = hf['L1_egammas'][:]
        HLT_muons = hf['HLT_muons'][:]
        LRT_muons = hf['LRT_muons'][:]
        L1_muons = hf['L1_muons'][:]
        L1_eFex_taus = hf['L1_eFex_taus'][:]
        L1_jFex_taus = hf['L1_jFex_taus'][:]
        HLT_photons = hf['HLT_photons'][:]
        HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 4)  # Broadcasting MET
        L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
        pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
        pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]

        HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, [0, 2, 3]], HLT_muons[:, :3, [0, 2, 3]], HLT_photons[:, :3, [0, 2, 3]], HLT_MET[:, :, [0, 2, 3]]], axis=1)
        L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)
        
        datasets[dataset_tag] = {
            'HLT_data': HLT_objects,
            'L1_data': L1_objects,
            'passL1': pass_L1_unprescaled==1,
            'passHLT': pass_HLT_unprescaled==1,
            'weights': np.ones(len(HLT_objects)),
        }

        if len(HLT_objects) > 100000:
            datasets[dataset_tag] = {key: value[:100000] for key, value in datasets[dataset_tag].items()}

# %%
# Read 2024 EB data

with h5py.File('/home/jovyan/EB_data/EB_ntuples_08-13-2024-003.h5', 'r') as hf:
    HLT_jets = hf['HLT_jets'][:]
    ofl_jets = hf['ofl_jets'][:]
    L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
    L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
    HLT_electrons = hf['HLT_electrons'][:]
    LRT_electrons = hf['LRT_electrons'][:]
    ofl_electrons = hf['ofl_electrons'][:]
    L1_egammas = hf['L1_egammas'][:]
    HLT_muons = hf['HLT_muons'][:]
    LRT_muons = hf['LRT_muons'][:]
    ofl_muons = hf['ofl_muons'][:]
    L1_muons = hf['L1_muons'][:]
    L1_eFex_taus = hf['L1_eFex_taus'][:]
    L1_jFex_taus = hf['L1_jFex_taus'][:]
    HLT_photons = hf['HLT_photons'][:]
    ofl_photons = hf['ofl_photons'][:]
    HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 3)  # Broadcasting MET
    L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
    pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
    pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]
    EB_weights = hf["EB_weights"][:]
    event_number = hf["event_number"][:]
    run_number = hf["run_number"][:]

HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, :], HLT_muons[:, :3, :], HLT_photons[:, :3, :], HLT_MET], axis=1)
L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)



# Indices of events that passed L1
pass_L1_idxs = (pass_L1_unprescaled == 1)

# Indices of events that passed HLT
pass_HLT_idxs = (pass_HLT_unprescaled == 1)



datasets['EB_data'] = {
    'HLT_data': HLT_objects[pass_L1_idxs] ,
    'L1_data': L1_objects[pass_L1_idxs] ,
    'passL1': pass_L1_idxs[pass_L1_idxs],
    'passHLT': pass_HLT_idxs[pass_L1_idxs],
    'weights': EB_weights[pass_L1_idxs],
}

datasets['EB_zerobias'] = {
    'HLT_data': HLT_objects[~pass_L1_idxs] ,
    'L1_data': L1_objects[~pass_L1_idxs] ,
    'passL1': pass_L1_idxs[~pass_L1_idxs],
    'passHLT': pass_HLT_idxs[~pass_L1_idxs],
    'weights': EB_weights[~pass_L1_idxs],
}

datasets['EB_passHLT'] = {
    'HLT_data': HLT_objects[pass_HLT_idxs] ,
    'L1_data': L1_objects[pass_HLT_idxs] ,
    'passL1': pass_L1_idxs[pass_HLT_idxs],
    'passHLT': pass_HLT_idxs[pass_HLT_idxs],
    'weights': EB_weights[pass_HLT_idxs],
}

# %% [markdown]
# ## Data Processing

# %%
#create combo of jjJZ4 & jjJZ2 & jjJZ1

datasets['jjJZ1&2&4'] = {
    'HLT_data': np.concatenate((datasets['jjJZ1']['HLT_data'],datasets['jjJZ2']['HLT_data'],datasets['jjJZ4']['HLT_data'])),
    'L1_data': np.concatenate((datasets['jjJZ1']['L1_data'],datasets['jjJZ2']['L1_data'],datasets['jjJZ4']['L1_data'])) ,
    'passL1': np.concatenate((datasets['jjJZ1']['passL1'],datasets['jjJZ2']['passL1'],datasets['jjJZ4']['passL1'])),
    'passHLT': np.concatenate((datasets['jjJZ1']['passHLT'],datasets['jjJZ2']['passHLT'],datasets['jjJZ4']['passHLT'])),
    'weights': np.concatenate((datasets['jjJZ1']['weights'],datasets['jjJZ2']['weights'],datasets['jjJZ4']['weights'])),
}

# %%
"""Multiply the pt of the L1 muons by 1000 to get them into the right units."""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label == 'L1_data':
            data[:, 13:16, 0] *= 1000

# %%
# Split EB data in train, test

random_seed = 789247

indices = np.arange(len(datasets['EB_data']['HLT_data']))
train_indices, _indices = train_test_split(indices, train_size=0.5, random_state=random_seed)
test1_indices, test2_indices = train_test_split(_indices, train_size=0.5, random_state=random_seed)

datasets['EB_datatrain'] = {key:value[train_indices] for key, value in datasets['EB_data'].items()}
datasets['EB_datatest1'] = {key:value[test1_indices] for key, value in datasets['EB_data'].items()}
datasets['EB_datatest2'] = {key:value[test2_indices] for key, value in datasets['EB_data'].items()}

del datasets['EB_data']

# %%
#save pt values before normalization for 2d histogram of max pt vs. anomaly score & efficiency plots
HLT_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['HLT_data'][i,j,0]:
                temp[i] = datasets[tag]['HLT_data'][i,j,0]
    HLT_max_pt_vals[tag] = temp
L1_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['L1_data'][i,j,0]:
                temp[i] = datasets[tag]['L1_data'][i,j,0]
    L1_max_pt_vals[tag] = temp
HLT_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_jet_mults[tag] = temp
L1_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_jet_mults[tag] = temp
HLT_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10,13):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_electron_mults[tag] = temp
L1_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10,13):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_electron_mults[tag] = temp
HLT_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(13,16):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_muon_mults[tag] = temp
L1_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(13,16):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_muon_mults[tag] = temp
HLT_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(16,19):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_photon_mults[tag] = temp
L1_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(16,19):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_photon_mults[tag] = temp

# %%
for tag, dict in datasets.items():
    print(f'\n{tag}:')
    for key, value in dict.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 20, 3)
# L1_data: (10000, 20, 3)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 20, 3)
# L1_data: (70000, 20, 3)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 20, 3)
# L1_data: (50000, 20, 3)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_zerobias:
# HLT_data: (1501347, 20, 3)
# L1_data: (1501347, 20, 3)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 20, 3)
# L1_data: (15255, 20, 3)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4:
# HLT_data: (300000, 20, 3)
# L1_data: (300000, 20, 3)
# passL1: (300000,)
# passHLT: (300000,)
# weights: (300000,)
#
# EB_datatrain:
# HLT_data: (301743, 20, 3)
# L1_data: (301743, 20, 3)
# passL1: (301743,)
# passHLT: (301743,)
# weights: (301743,)
#
# EB_datatest1:
# HLT_data: (150871, 20, 3)
# L1_data: (150871, 20, 3)
# passL1: (150871,)
# passHLT: (150871,)
# weights: (150871,)
#
# EB_datatest2:
# HLT_data: (150872, 20, 3)
# L1_data: (150872, 20, 3)
# passL1: (150872,)
# passHLT: (150872,)
# weights: (150872,)

# %%
"""Met bias. For some events, MET was not calculated, so was written as -999.
We don't want this to impact training, so we map 0 --> 0.001 and -999 --> 0"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):

            # MET: 0 --> 0.001 and -999 --> 0 and nan --> 0
            MET_zeros = (data[:, 19, 0] == 0) # indices where MET=0
            MET_999 = ((data[:, 19, 0] == -999)) # indices where MET=-999 (not calculated)
            MET_nan = np.isnan(data[:, 19, 2])
            data[MET_zeros, 19, 0] = 0.001
            data[MET_999, 19, :] = 0
            data[MET_nan, 19, :] = 0

# %%
"""Normalize pt such that sum(pt) = 1 in each event"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
#             # sum of the pt and E in each event
            sum_pt = np.sum(data[:, :, 0], axis=1, keepdims=True)
        
#             # If the sum is 0, set the sum to 1 to avoid division by 0
            sum_pt[sum_pt == 0] = 1
        
#             # Divide pt and E by their respective sums, multiply by 10
            data[:, :, 0] *= (1/sum_pt)

# %%
## Autoencoder Architecture

# %%
# Flatten ndarrays for use in DNN

for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
            datasets[tag][label] = np.reshape(data, newshape=(-1, 60))

# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4:
# HLT_data: (300000, 60)
# L1_data: (300000, 60)
# passL1: (300000,)
# passHLT: (300000,)
# weights: (300000,)
#
# EB_datatrain:
# HLT_data: (301743, 60)
# L1_data: (301743, 60)
# passL1: (301743,)
# passHLT: (301743,)
# weights: (301743,)
#
# EB_datatest1:
# HLT_data: (150871, 60)
# L1_data: (150871, 60)
# passL1: (150871,)
# passHLT: (150871,)
# weights: (150871,)
#
# EB_datatest2:
# HLT_data: (150872, 60)
# L1_data: (150872, 60)
# passL1: (150872,)
# passHLT: (150872,)
# weights: (150872,)

# %%
def create_AE(input_dim, h_dim_1, h_dim_2, latent_dim):
    
     # Encoder
    encoder_inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(h_dim_1, activation='relu')(encoder_inputs)
    x = layers.Dense(h_dim_2, activation='relu')(x)
    z = layers.Dense(latent_dim, activation='relu')(x)
    
    encoder = Model(inputs=encoder_inputs, outputs=z)

    # Decoder
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(h_dim_2, activation='relu')(decoder_inputs)
    x = layers.Dense(h_dim_1, activation='relu')(x)
    outputs = layers.Dense(input_dim)(x)

    decoder = Model(inputs=decoder_inputs, outputs=outputs)

    ae_outputs = decoder(encoder(encoder_inputs))
    ae = Model(encoder_inputs, outputs=ae_outputs)
    return ae, encoder, decoder

# %%
def loss_fn(y_true, y_pred):
    """masked mse"""
    mask0 = K.cast(K.not_equal(y_true, 0), K.floatx())
    maskMET = K.cast(K.not_equal(y_true, -999), K.floatx())
    mask = mask0 * maskMET
    squared_difference = K.square((y_pred - y_true))
    return K.mean(squared_difference)

# %%
# Initialize models
INPUT_DIM = datasets['EB_datatrain']['HLT_data'].shape[1]
H_DIM_1 = 32
H_DIM_2 = 8
LATENT_DIM = 2

HLT_AE, HLT_encoder, HLT_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)
L1_AE, L1_encoder, L1_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)

HLT_AE.summary()
L1_AE.summary()
# Out:
# 2024-10-07 23:21:27.236602: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20732 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:41:00.0, compute capability: 8.6
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_3 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_7 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_9 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# Define callbacks: early stopping and learning rate scheduler

STOP_PATIENCE = 8
LR_PATIENCE = 4

early_stopping = EarlyStopping(patience=STOP_PATIENCE, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=LR_PATIENCE, verbose=1)

callbacks = [early_stopping, reduce_lr]

# %%
NUM_EPOCHS = 150
BATCH_SIZE = 512

# %%
#Model Training

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# train HLT model
history = HLT_AE.fit(
    x=datasets['EB_datatrain']['HLT_data'], 
    y=datasets['EB_datatrain']['HLT_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['EB_datatrain']['weights']
)
# Out:
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728343289.931570  493122 service.cc:145] XLA service 0x7f337c00c5f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728343289.931617  493122 service.cc:153]   StreamExecutor device (0): NVIDIA A10, Compute Capability 8.6
# 2024-10-07 23:21:29.959764: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-07 23:21:30.238481: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728343290.780418  493234 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_513', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1728343290.902830  493275 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_513', 8 bytes spill stores, 8 bytes spill loads
# 182/501 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 1776.5248
# I0000 00:00:1728343292.700894  493122 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 497/501 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 1675.5790
# I0000 00:00:1728343293.485141  493549 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_500', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1728343293.628584  493552 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_500', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1728343293.709108  493495 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_500', 12 bytes spill stores, 12 bytes spill loads
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 1674.4565 - val_loss: 1396.2854 - learning_rate: 0.0010
# Epoch 2/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - loss: 1487.9965 - val_loss: 1387.4498 - learning_rate: 0.0010
# Epoch 3/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1450.1772 - val_loss: 1374.3684 - learning_rate: 0.0010
# Epoch 4/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - loss: 1491.7192 - val_loss: 1361.5426 - learning_rate: 0.0010
# Epoch 5/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - loss: 1432.4136 - val_loss: 1350.7701 - learning_rate: 0.0010
# Epoch 6/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - loss: 1461.6472 - val_loss: 1344.1246 - learning_rate: 0.0010
# Epoch 7/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 1463.0371 - val_loss: 1340.2894 - learning_rate: 0.0010
# Epoch 8/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 966us/step - loss: 1428.8341 - val_loss: 1336.2617 - learning_rate: 0.0010
# Epoch 9/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1423.0697 - val_loss: 1332.9185 - learning_rate: 0.0010
# Epoch 10/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1452.8130 - val_loss: 1329.4305 - learning_rate: 0.0010
# Epoch 11/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - loss: 1418.7159 - val_loss: 1324.8514 - learning_rate: 0.0010
# Epoch 12/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - loss: 1420.1665 - val_loss: 1322.2594 - learning_rate: 0.0010
# Epoch 13/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 1409.7358 - val_loss: 1317.9141 - learning_rate: 0.0010
# Epoch 14/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - loss: 1398.7401 - val_loss: 1314.9548 - learning_rate: 0.0010
# Epoch 15/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1414.9020 - val_loss: 1312.6243 - learning_rate: 0.0010
# Epoch 16/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - loss: 1414.8248 - val_loss: 1309.3831 - learning_rate: 0.0010
# Epoch 17/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1412.4585 - val_loss: 1307.4072 - learning_rate: 0.0010
# Epoch 18/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - loss: 1388.1799 - val_loss: 1305.5211 - learning_rate: 0.0010
# Epoch 19/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - loss: 1388.5488 - val_loss: 1302.4586 - learning_rate: 0.0010
# Epoch 20/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1390.7808 - val_loss: 1300.6888 - learning_rate: 0.0010
# Epoch 21/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1403.8494 - val_loss: 1299.4113 - learning_rate: 0.0010
# Epoch 22/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - loss: 1411.4526 - val_loss: 1296.3406 - learning_rate: 0.0010
# Epoch 23/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 1409.4390 - val_loss: 1294.8518 - learning_rate: 0.0010
# Epoch 24/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - loss: 1392.6556 - val_loss: 1294.8617 - learning_rate: 0.0010
# Epoch 25/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 943us/step - loss: 1378.0123 - val_loss: 1292.7223 - learning_rate: 0.0010
# Epoch 26/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 1378.3104 - val_loss: 1291.2590 - learning_rate: 0.0010
# Epoch 27/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 1384.3463 - val_loss: 1291.8724 - learning_rate: 0.0010
# Epoch 28/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - loss: 1387.5691 - val_loss: 1289.3650 - learning_rate: 0.0010
# Epoch 29/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1369.6787 - val_loss: 1287.4880 - learning_rate: 0.0010
# Epoch 30/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1402.0588 - val_loss: 1287.0586 - learning_rate: 0.0010
# Epoch 31/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - loss: 1367.5626 - val_loss: 1285.3375 - learning_rate: 0.0010
# Epoch 32/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 1351.1958 - val_loss: 1283.2755 - learning_rate: 0.0010
# Epoch 33/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1377.3981 - val_loss: 1281.4905 - learning_rate: 0.0010
# Epoch 34/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1364.6062 - val_loss: 1279.6361 - learning_rate: 0.0010
# Epoch 35/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - loss: 1395.2556 - val_loss: 1276.9181 - learning_rate: 0.0010
# Epoch 36/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - loss: 1407.4662 - val_loss: 1276.1428 - learning_rate: 0.0010
# Epoch 37/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 1400.9742 - val_loss: 1275.7118 - learning_rate: 0.0010
# Epoch 38/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - loss: 1361.5183 - val_loss: 1272.8923 - learning_rate: 0.0010
# Epoch 39/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 950us/step - loss: 1361.0306 - val_loss: 1273.2035 - learning_rate: 0.0010
# Epoch 40/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - loss: 1367.9335 - val_loss: 1270.5237 - learning_rate: 0.0010
# Epoch 41/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 946us/step - loss: 1351.8983 - val_loss: 1271.0508 - learning_rate: 0.0010
# Epoch 42/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1371.5959 - val_loss: 1268.6937 - learning_rate: 0.0010
# Epoch 43/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 992us/step - loss: 1354.6290 - val_loss: 1266.5854 - learning_rate: 0.0010
# Epoch 44/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step - loss: 1329.6542 - val_loss: 1265.7510 - learning_rate: 0.0010
# Epoch 45/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 1377.8073 - val_loss: 1265.0637 - learning_rate: 0.0010
# Epoch 46/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - loss: 1342.8629 - val_loss: 1264.5291 - learning_rate: 0.0010
# Epoch 47/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1376.6488 - val_loss: 1264.0936 - learning_rate: 0.0010
# Epoch 48/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - loss: 1337.1290 - val_loss: 1263.5629 - learning_rate: 0.0010
# Epoch 49/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1345.3599 - val_loss: 1262.5764 - learning_rate: 0.0010
# Epoch 50/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - loss: 1364.7347 - val_loss: 1262.4683 - learning_rate: 0.0010
# Epoch 51/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - loss: 1345.3357 - val_loss: 1260.5488 - learning_rate: 0.0010
# Epoch 52/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 1349.6388 - val_loss: 1259.1599 - learning_rate: 0.0010
# Epoch 53/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - loss: 1347.9169 - val_loss: 1262.7804 - learning_rate: 0.0010
# Epoch 54/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - loss: 1357.0604 - val_loss: 1258.7212 - learning_rate: 0.0010
# Epoch 55/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1355.2146 - val_loss: 1258.9781 - learning_rate: 0.0010
# Epoch 56/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1341.6951 - val_loss: 1257.8267 - learning_rate: 0.0010
# Epoch 57/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - loss: 1342.1095 - val_loss: 1261.4993 - learning_rate: 0.0010
# Epoch 58/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 1347.0796 - val_loss: 1256.2809 - learning_rate: 0.0010
# Epoch 59/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - loss: 1335.3390 - val_loss: 1257.8109 - learning_rate: 0.0010
# Epoch 60/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - loss: 1345.1477 - val_loss: 1254.3411 - learning_rate: 0.0010
# Epoch 61/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 948us/step - loss: 1340.9911 - val_loss: 1253.1163 - learning_rate: 0.0010
# Epoch 62/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1331.8127 - val_loss: 1251.0787 - learning_rate: 0.0010
# Epoch 63/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - loss: 1338.4950 - val_loss: 1253.2465 - learning_rate: 0.0010
# Epoch 64/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 950us/step - loss: 1344.2015 - val_loss: 1249.2050 - learning_rate: 0.0010
# Epoch 65/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - loss: 1322.9203 - val_loss: 1251.6488 - learning_rate: 0.0010
# Epoch 66/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - loss: 1343.2438 - val_loss: 1251.6000 - learning_rate: 0.0010
# Epoch 67/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 1332.9657 - val_loss: 1249.2086 - learning_rate: 0.0010
# Epoch 68/150
# 440/501 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 1332.3126
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1332.3790 - val_loss: 1249.4861 - learning_rate: 0.0010
# Epoch 69/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - loss: 1314.3357 - val_loss: 1243.5364 - learning_rate: 1.0000e-04
# Epoch 70/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 1320.6882 - val_loss: 1243.0729 - learning_rate: 1.0000e-04
# Epoch 71/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 996us/step - loss: 1318.3079 - val_loss: 1242.6761 - learning_rate: 1.0000e-04
# Epoch 72/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 988us/step - loss: 1341.7793 - val_loss: 1242.6206 - learning_rate: 1.0000e-04
# Epoch 73/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 1332.7809 - val_loss: 1241.9399 - learning_rate: 1.0000e-04
# Epoch 74/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1343.5338 - val_loss: 1241.6219 - learning_rate: 1.0000e-04
# Epoch 75/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1316.2865 - val_loss: 1241.4854 - learning_rate: 1.0000e-04
# Epoch 76/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1298.8907 - val_loss: 1241.1219 - learning_rate: 1.0000e-04
# Epoch 77/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 1328.5460 - val_loss: 1241.0331 - learning_rate: 1.0000e-04
# Epoch 78/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 1314.9026 - val_loss: 1240.6632 - learning_rate: 1.0000e-04
# Epoch 79/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - loss: 1331.0001 - val_loss: 1240.8683 - learning_rate: 1.0000e-04
# Epoch 80/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - loss: 1300.2784 - val_loss: 1240.0935 - learning_rate: 1.0000e-04
# Epoch 81/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - loss: 1312.6508 - val_loss: 1239.9177 - learning_rate: 1.0000e-04
# Epoch 82/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - loss: 1323.3918 - val_loss: 1239.9669 - learning_rate: 1.0000e-04
# Epoch 83/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 1308.0542 - val_loss: 1239.7328 - learning_rate: 1.0000e-04
# Epoch 84/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 1320.9788 - val_loss: 1239.6029 - learning_rate: 1.0000e-04
# Epoch 85/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - loss: 1317.1989 - val_loss: 1239.2103 - learning_rate: 1.0000e-04
# Epoch 86/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - loss: 1309.8463 - val_loss: 1239.2484 - learning_rate: 1.0000e-04
# Epoch 87/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - loss: 1325.6692 - val_loss: 1239.3635 - learning_rate: 1.0000e-04
# Epoch 88/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - loss: 1344.2844 - val_loss: 1239.2728 - learning_rate: 1.0000e-04
# Epoch 89/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - loss: 1313.7438 - val_loss: 1238.7118 - learning_rate: 1.0000e-04
# Epoch 90/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 953us/step - loss: 1321.1031 - val_loss: 1239.1357 - learning_rate: 1.0000e-04
# Epoch 91/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 1317.7646 - val_loss: 1238.8707 - learning_rate: 1.0000e-04
# Epoch 92/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - loss: 1319.6503 - val_loss: 1238.9868 - learning_rate: 1.0000e-04
# Epoch 93/150
# 450/501 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 1326.0798
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - loss: 1325.6742 - val_loss: 1238.8396 - learning_rate: 1.0000e-04
# Epoch 94/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1313.5009 - val_loss: 1238.3923 - learning_rate: 1.0000e-05
# Epoch 95/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 1334.0190 - val_loss: 1238.3239 - learning_rate: 1.0000e-05
# Epoch 96/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 938us/step - loss: 1314.7012 - val_loss: 1238.2812 - learning_rate: 1.0000e-05
# Epoch 97/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1319.9122 - val_loss: 1238.2502 - learning_rate: 1.0000e-05
# Epoch 98/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 1307.2953 - val_loss: 1238.2030 - learning_rate: 1.0000e-05
# Epoch 99/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 1335.5366 - val_loss: 1238.1680 - learning_rate: 1.0000e-05
# Epoch 100/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - loss: 1325.8134 - val_loss: 1238.1547 - learning_rate: 1.0000e-05
# Epoch 101/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 958us/step - loss: 1324.0251 - val_loss: 1238.1687 - learning_rate: 1.0000e-05
# Epoch 102/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 998us/step - loss: 1313.5176 - val_loss: 1238.1285 - learning_rate: 1.0000e-05
# Epoch 103/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - loss: 1315.5829 - val_loss: 1238.1721 - learning_rate: 1.0000e-05
# Epoch 104/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 1313.4683 - val_loss: 1238.1256 - learning_rate: 1.0000e-05
# Epoch 105/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - loss: 1305.0861 - val_loss: 1238.0316 - learning_rate: 1.0000e-05
# Epoch 106/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 1341.3921 - val_loss: 1238.0364 - learning_rate: 1.0000e-05
# Epoch 107/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step - loss: 1318.7991 - val_loss: 1238.0072 - learning_rate: 1.0000e-05
# Epoch 108/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1323.9893 - val_loss: 1238.0190 - learning_rate: 1.0000e-05
# Epoch 109/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - loss: 1326.0675 - val_loss: 1237.9313 - learning_rate: 1.0000e-05
# Epoch 110/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 954us/step - loss: 1323.2075 - val_loss: 1237.8905 - learning_rate: 1.0000e-05
# Epoch 111/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 960us/step - loss: 1313.5823 - val_loss: 1237.8717 - learning_rate: 1.0000e-05
# Epoch 112/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - loss: 1330.3713 - val_loss: 1237.8201 - learning_rate: 1.0000e-05
# Epoch 113/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 992us/step - loss: 1329.6625 - val_loss: 1237.8209 - learning_rate: 1.0000e-05
# Epoch 114/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - loss: 1308.1823 - val_loss: 1237.8126 - learning_rate: 1.0000e-05
# Epoch 115/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1334.7397 - val_loss: 1237.7670 - learning_rate: 1.0000e-05
# Epoch 116/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - loss: 1325.8789 - val_loss: 1237.7445 - learning_rate: 1.0000e-05
# Epoch 117/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1292.0076 - val_loss: 1237.7568 - learning_rate: 1.0000e-05
# Epoch 118/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - loss: 1298.7567 - val_loss: 1237.6595 - learning_rate: 1.0000e-05
# Epoch 119/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - loss: 1334.1429 - val_loss: 1237.6467 - learning_rate: 1.0000e-05
# Epoch 120/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - loss: 1315.8690 - val_loss: 1237.6627 - learning_rate: 1.0000e-05
# Epoch 121/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1346.8700 - val_loss: 1237.5487 - learning_rate: 1.0000e-05
# Epoch 122/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - loss: 1320.3138 - val_loss: 1237.5917 - learning_rate: 1.0000e-05
# Epoch 123/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 1295.6016 - val_loss: 1237.5945 - learning_rate: 1.0000e-05
# Epoch 124/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 991us/step - loss: 1318.8618 - val_loss: 1237.6321 - learning_rate: 1.0000e-05
# Epoch 125/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 1328.7025 - val_loss: 1237.5397 - learning_rate: 1.0000e-05
# Epoch 126/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 1325.5118 - val_loss: 1237.5291 - learning_rate: 1.0000e-05
# Epoch 127/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1304.0891 - val_loss: 1237.4341 - learning_rate: 1.0000e-05
# Epoch 128/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1322.8335 - val_loss: 1237.4728 - learning_rate: 1.0000e-05
# Epoch 129/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 996us/step - loss: 1325.8503 - val_loss: 1237.4788 - learning_rate: 1.0000e-05
# Epoch 130/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 1323.7911 - val_loss: 1237.4177 - learning_rate: 1.0000e-05
# Epoch 131/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1326.0424 - val_loss: 1237.4482 - learning_rate: 1.0000e-05
# Epoch 132/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 950us/step - loss: 1321.4174 - val_loss: 1237.4347 - learning_rate: 1.0000e-05
# Epoch 133/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - loss: 1315.2352 - val_loss: 1237.3790 - learning_rate: 1.0000e-05
# Epoch 134/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1309.0784 - val_loss: 1237.3231 - learning_rate: 1.0000e-05
# Epoch 135/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step - loss: 1321.4171 - val_loss: 1237.4034 - learning_rate: 1.0000e-05
# Epoch 136/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - loss: 1326.5184 - val_loss: 1237.3510 - learning_rate: 1.0000e-05
# Epoch 137/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 950us/step - loss: 1343.2488 - val_loss: 1237.3336 - learning_rate: 1.0000e-05
# Epoch 138/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 1330.9088 - val_loss: 1237.2839 - learning_rate: 1.0000e-05
# Epoch 139/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - loss: 1361.4259 - val_loss: 1237.3048 - learning_rate: 1.0000e-05
# Epoch 140/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - loss: 1325.1851 - val_loss: 1237.3025 - learning_rate: 1.0000e-05
# Epoch 141/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - loss: 1312.5525 - val_loss: 1237.2688 - learning_rate: 1.0000e-05
# Epoch 142/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - loss: 1316.1932 - val_loss: 1237.1906 - learning_rate: 1.0000e-05
# Epoch 143/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - loss: 1312.2139 - val_loss: 1237.2030 - learning_rate: 1.0000e-05
# Epoch 144/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 1313.8385 - val_loss: 1237.2125 - learning_rate: 1.0000e-05
# Epoch 145/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 1312.6945 - val_loss: 1237.1703 - learning_rate: 1.0000e-05
# Epoch 146/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 1317.4797 - val_loss: 1237.1239 - learning_rate: 1.0000e-05
# Epoch 147/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1323.0104 - val_loss: 1237.1906 - learning_rate: 1.0000e-05
# Epoch 148/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 943us/step - loss: 1315.7678 - val_loss: 1237.1345 - learning_rate: 1.0000e-05
# Epoch 149/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 939us/step - loss: 1301.1213 - val_loss: 1237.0759 - learning_rate: 1.0000e-05
# Epoch 150/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 943us/step - loss: 1337.1602 - val_loss: 1237.1646 - learning_rate: 1.0000e-05

# %%
HLT_AE.save_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.save_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')
HLT_AE.load_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.load_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')

# %%
# train L1 model
# train HLT model
history = L1_AE.fit(
    x=datasets['EB_datatrain']['L1_data'], 
    y=datasets['EB_datatrain']['L1_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['EB_datatrain']['weights']
)
# Out:
# Epoch 1/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 659.7843 - val_loss: 497.1335 - learning_rate: 0.0010
# Epoch 2/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 526.3773 - val_loss: 482.2898 - learning_rate: 0.0010
# Epoch 3/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 518.2792 - val_loss: 470.0505 - learning_rate: 0.0010
# Epoch 4/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 502.3999 - val_loss: 461.1614 - learning_rate: 0.0010
# Epoch 5/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 489.8335 - val_loss: 455.5098 - learning_rate: 0.0010
# Epoch 6/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 489.0696 - val_loss: 451.7314 - learning_rate: 0.0010
# Epoch 7/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - loss: 479.7772 - val_loss: 448.4557 - learning_rate: 0.0010
# Epoch 8/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - loss: 474.1505 - val_loss: 445.6434 - learning_rate: 0.0010
# Epoch 9/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - loss: 469.3353 - val_loss: 443.5485 - learning_rate: 0.0010
# Epoch 10/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 991us/step - loss: 469.1068 - val_loss: 441.8016 - learning_rate: 0.0010
# Epoch 11/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 470.6260 - val_loss: 440.5968 - learning_rate: 0.0010
# Epoch 12/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 466.1394 - val_loss: 439.7269 - learning_rate: 0.0010
# Epoch 13/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - loss: 462.3278 - val_loss: 438.1919 - learning_rate: 0.0010
# Epoch 14/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - loss: 476.1868 - val_loss: 437.7021 - learning_rate: 0.0010
# Epoch 15/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 960us/step - loss: 465.1606 - val_loss: 436.9523 - learning_rate: 0.0010
# Epoch 16/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 463.7689 - val_loss: 435.9376 - learning_rate: 0.0010
# Epoch 17/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 460.9107 - val_loss: 435.9174 - learning_rate: 0.0010
# Epoch 18/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 457.7393 - val_loss: 435.0720 - learning_rate: 0.0010
# Epoch 19/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step - loss: 465.8159 - val_loss: 433.9126 - learning_rate: 0.0010
# Epoch 20/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 461.0727 - val_loss: 433.5887 - learning_rate: 0.0010
# Epoch 21/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 966us/step - loss: 455.1701 - val_loss: 433.1029 - learning_rate: 0.0010
# Epoch 22/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - loss: 460.4303 - val_loss: 432.7290 - learning_rate: 0.0010
# Epoch 23/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 455.5366 - val_loss: 432.2337 - learning_rate: 0.0010
# Epoch 24/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 464.7387 - val_loss: 431.8308 - learning_rate: 0.0010
# Epoch 25/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 966us/step - loss: 454.0246 - val_loss: 432.1328 - learning_rate: 0.0010
# Epoch 26/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - loss: 462.2849 - val_loss: 431.6877 - learning_rate: 0.0010
# Epoch 27/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - loss: 461.9337 - val_loss: 431.1459 - learning_rate: 0.0010
# Epoch 28/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 956us/step - loss: 456.5098 - val_loss: 431.0276 - learning_rate: 0.0010
# Epoch 29/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 457.5596 - val_loss: 430.5132 - learning_rate: 0.0010
# Epoch 30/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 983us/step - loss: 455.2458 - val_loss: 430.3397 - learning_rate: 0.0010
# Epoch 31/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 455.1046 - val_loss: 429.6937 - learning_rate: 0.0010
# Epoch 32/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 456.9432 - val_loss: 429.6687 - learning_rate: 0.0010
# Epoch 33/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - loss: 455.9506 - val_loss: 428.9431 - learning_rate: 0.0010
# Epoch 34/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 460.5988 - val_loss: 429.1833 - learning_rate: 0.0010
# Epoch 35/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - loss: 453.3121 - val_loss: 429.0808 - learning_rate: 0.0010
# Epoch 36/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 466.3005 - val_loss: 428.4286 - learning_rate: 0.0010
# Epoch 37/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 455.1060 - val_loss: 428.5762 - learning_rate: 0.0010
# Epoch 38/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 453.6173 - val_loss: 428.3892 - learning_rate: 0.0010
# Epoch 39/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - loss: 451.2554 - val_loss: 430.3881 - learning_rate: 0.0010
# Epoch 40/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 943us/step - loss: 459.8148 - val_loss: 428.0353 - learning_rate: 0.0010
# Epoch 41/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 455.4122 - val_loss: 427.8591 - learning_rate: 0.0010
# Epoch 42/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 947us/step - loss: 453.4163 - val_loss: 428.6500 - learning_rate: 0.0010
# Epoch 43/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - loss: 452.5660 - val_loss: 428.0194 - learning_rate: 0.0010
# Epoch 44/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 998us/step - loss: 459.7601 - val_loss: 427.5500 - learning_rate: 0.0010
# Epoch 45/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1000us/step - loss: 454.2664 - val_loss: 427.4044 - learning_rate: 0.0010
# Epoch 46/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 454.9861 - val_loss: 427.3845 - learning_rate: 0.0010
# Epoch 47/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 460.7356 - val_loss: 426.8981 - learning_rate: 0.0010
# Epoch 48/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - loss: 452.5269 - val_loss: 427.0293 - learning_rate: 0.0010
# Epoch 49/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 945us/step - loss: 453.2100 - val_loss: 427.2743 - learning_rate: 0.0010
# Epoch 50/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 459.5034 - val_loss: 426.8326 - learning_rate: 0.0010
# Epoch 51/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 459.3713 - val_loss: 427.3641 - learning_rate: 0.0010
# Epoch 52/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 455.7520 - val_loss: 426.9680 - learning_rate: 0.0010
# Epoch 53/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - loss: 457.9552 - val_loss: 427.0564 - learning_rate: 0.0010
# Epoch 54/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - loss: 455.4974 - val_loss: 426.7125 - learning_rate: 0.0010
# Epoch 55/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 451.4206 - val_loss: 426.7516 - learning_rate: 0.0010
# Epoch 56/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 953us/step - loss: 457.1690 - val_loss: 425.9906 - learning_rate: 0.0010
# Epoch 57/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 999us/step - loss: 464.6435 - val_loss: 426.1118 - learning_rate: 0.0010
# Epoch 58/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 462.5940 - val_loss: 425.8756 - learning_rate: 0.0010
# Epoch 59/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - loss: 454.8932 - val_loss: 426.0184 - learning_rate: 0.0010
# Epoch 60/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 445.8302 - val_loss: 426.5975 - learning_rate: 0.0010
# Epoch 61/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 960us/step - loss: 447.1900 - val_loss: 426.2991 - learning_rate: 0.0010
# Epoch 62/150
# 447/501 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 448.5506
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 449.2181 - val_loss: 425.9518 - learning_rate: 0.0010
# Epoch 63/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 963us/step - loss: 449.3020 - val_loss: 424.5333 - learning_rate: 1.0000e-04
# Epoch 64/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.4215 - val_loss: 424.4387 - learning_rate: 1.0000e-04
# Epoch 65/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 451.1048 - val_loss: 424.3840 - learning_rate: 1.0000e-04
# Epoch 66/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - loss: 445.1009 - val_loss: 424.4023 - learning_rate: 1.0000e-04
# Epoch 67/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - loss: 451.4058 - val_loss: 424.3432 - learning_rate: 1.0000e-04
# Epoch 68/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.2899 - val_loss: 424.3674 - learning_rate: 1.0000e-04
# Epoch 69/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 455.4858 - val_loss: 424.2992 - learning_rate: 1.0000e-04
# Epoch 70/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 965us/step - loss: 453.8758 - val_loss: 424.2284 - learning_rate: 1.0000e-04
# Epoch 71/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.7856 - val_loss: 424.2053 - learning_rate: 1.0000e-04
# Epoch 72/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.7276 - val_loss: 424.2215 - learning_rate: 1.0000e-04
# Epoch 73/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - loss: 448.1394 - val_loss: 424.0769 - learning_rate: 1.0000e-04
# Epoch 74/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 983us/step - loss: 453.6426 - val_loss: 424.0253 - learning_rate: 1.0000e-04
# Epoch 75/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 451.0016 - val_loss: 424.1092 - learning_rate: 1.0000e-04
# Epoch 76/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 451.3306 - val_loss: 424.0468 - learning_rate: 1.0000e-04
# Epoch 77/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - loss: 452.8936 - val_loss: 424.0796 - learning_rate: 1.0000e-04
# Epoch 78/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 452.7121 - val_loss: 423.9818 - learning_rate: 1.0000e-04
# Epoch 79/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.6267 - val_loss: 423.9688 - learning_rate: 1.0000e-04
# Epoch 80/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 451.7701 - val_loss: 423.9985 - learning_rate: 1.0000e-04
# Epoch 81/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 966us/step - loss: 450.8977 - val_loss: 423.9972 - learning_rate: 1.0000e-04
# Epoch 82/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 453.0328 - val_loss: 423.9538 - learning_rate: 1.0000e-04
# Epoch 83/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - loss: 460.0762 - val_loss: 424.0221 - learning_rate: 1.0000e-04
# Epoch 84/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - loss: 458.6465 - val_loss: 423.8883 - learning_rate: 1.0000e-04
# Epoch 85/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 455.0750 - val_loss: 424.1679 - learning_rate: 1.0000e-04
# Epoch 86/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 996us/step - loss: 457.3461 - val_loss: 423.9406 - learning_rate: 1.0000e-04
# Epoch 87/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - loss: 447.3705 - val_loss: 423.8814 - learning_rate: 1.0000e-04
# Epoch 88/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - loss: 445.5475 - val_loss: 423.8069 - learning_rate: 1.0000e-04
# Epoch 89/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 452.9855 - val_loss: 423.8037 - learning_rate: 1.0000e-04
# Epoch 90/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 996us/step - loss: 453.2610 - val_loss: 423.8732 - learning_rate: 1.0000e-04
# Epoch 91/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - loss: 458.4333 - val_loss: 423.9944 - learning_rate: 1.0000e-04
# Epoch 92/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.3857 - val_loss: 423.8132 - learning_rate: 1.0000e-04
# Epoch 93/150
# 440/501 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 450.2333
# Epoch 93: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - loss: 450.3760 - val_loss: 423.9801 - learning_rate: 1.0000e-04
# Epoch 94/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.3475 - val_loss: 423.7133 - learning_rate: 1.0000e-05
# Epoch 95/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - loss: 446.7814 - val_loss: 423.7003 - learning_rate: 1.0000e-05
# Epoch 96/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - loss: 453.7575 - val_loss: 423.6964 - learning_rate: 1.0000e-05
# Epoch 97/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step - loss: 452.5287 - val_loss: 423.6892 - learning_rate: 1.0000e-05
# Epoch 98/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 447.4565 - val_loss: 423.6974 - learning_rate: 1.0000e-05
# Epoch 99/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - loss: 453.3546 - val_loss: 423.7008 - learning_rate: 1.0000e-05
# Epoch 100/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 460.9420 - val_loss: 423.6980 - learning_rate: 1.0000e-05
# Epoch 101/150
# 440/501 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 462.2755
# Epoch 101: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - loss: 461.0956 - val_loss: 423.6891 - learning_rate: 1.0000e-05
# Epoch 102/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.2407 - val_loss: 423.6826 - learning_rate: 1.0000e-06
# Epoch 103/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.6308 - val_loss: 423.6776 - learning_rate: 1.0000e-06
# Epoch 104/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 459.1775 - val_loss: 423.6852 - learning_rate: 1.0000e-06
# Epoch 105/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.6797 - val_loss: 423.6800 - learning_rate: 1.0000e-06
# Epoch 106/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 983us/step - loss: 445.2244 - val_loss: 423.6832 - learning_rate: 1.0000e-06
# Epoch 107/150
# 439/501 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - loss: 459.6585
# Epoch 107: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - loss: 458.4793 - val_loss: 423.6808 - learning_rate: 1.0000e-06
# Epoch 108/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.3785 - val_loss: 423.6798 - learning_rate: 1.0000e-07
# Epoch 109/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.1045 - val_loss: 423.6804 - learning_rate: 1.0000e-07
# Epoch 110/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.3086 - val_loss: 423.6797 - learning_rate: 1.0000e-07
# Epoch 111/150
# 480/501 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 449.8531
# Epoch 111: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.8250 - val_loss: 423.6830 - learning_rate: 1.0000e-07

# %%
L1_AE.save_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.save_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')
L1_AE.load_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.load_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')

# %%
##Model Evaluation

# %%
# Pass the datasets through the model

for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue

    dict['HLT_model_outputs'] = HLT_AE.predict(dict['HLT_data'])
    #dict['HLT_latent_reps'] = HLT_encoder.predict(dict['HLT_data'])
    dict['L1_model_outputs'] = L1_AE.predict(dict['L1_data'])
    #dict['L1_latent_reps'] = L1_encoder.predict(dict['L1_data'])
# Out:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 556us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 541us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 554us/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 552us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 539us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 544us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 565us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 544us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 531us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 532us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 538us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 539us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 533us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 532us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 530us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 531us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 26s 562us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 26s 560us/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 5s 556us/step
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 5s 556us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 546us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 552us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 645us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 616us/step

# %%
def mse_loss(true, prediction):
    loss = np.mean(np.square(true - prediction), axis=-1)
    return loss

# %%
def MSE_AD_score(y, x):
    # masked mse
    mask = (y != 0) & (y != -999)
    _x = x * mask
    _y = y * mask
    return (mse_loss(y, x))

# %%
# Calculate the AD scores

for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue

    dict['HLT_AD_scores'] = MSE_AD_score(dict['HLT_data'], dict['HLT_model_outputs'])
    dict['L1_AD_scores'] = MSE_AD_score(dict['L1_data'], dict['L1_model_outputs'])

# %%
# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
# HLT_model_outputs: (10000, 60)
# L1_model_outputs: (10000, 60)
# HLT_AD_scores: (10000,)
# L1_AD_scores: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
# HLT_model_outputs: (70000, 60)
# L1_model_outputs: (70000, 60)
# HLT_AD_scores: (70000,)
# L1_AD_scores: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
# HLT_model_outputs: (50000, 60)
# L1_model_outputs: (50000, 60)
# HLT_AD_scores: (50000,)
# L1_AD_scores: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
# HLT_model_outputs: (1501347, 60)
# L1_model_outputs: (1501347, 60)
# HLT_AD_scores: (1501347,)
# L1_AD_scores: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
# HLT_model_outputs: (15255, 60)
# L1_model_outputs: (15255, 60)
# HLT_AD_scores: (15255,)
# L1_AD_scores: (15255,)
#
# jjJZ1&2&4:
# HLT_data: (300000, 60)
# L1_data: (300000, 60)
# passL1: (300000,)
# passHLT: (300000,)
# weights: (300000,)
# HLT_model_outputs: (300000, 60)
# L1_model_outputs: (300000, 60)
# HLT_AD_scores: (300000,)
# L1_AD_scores: (300000,)
#
# EB_datatrain:
# HLT_data: (301743, 60)
# L1_data: (301743, 60)
# passL1: (301743,)
# passHLT: (301743,)
# weights: (301743,)
#
# EB_datatest1:
# HLT_data: (150871, 60)
# L1_data: (150871, 60)
# passL1: (150871,)
# passHLT: (150871,)
# weights: (150871,)
# HLT_model_outputs: (150871, 60)
# L1_model_outputs: (150871, 60)
# HLT_AD_scores: (150871,)
# L1_AD_scores: (150871,)
#
# EB_datatest2:
# HLT_data: (150872, 60)
# L1_data: (150872, 60)
# passL1: (150872,)
# passHLT: (150872,)
# weights: (150872,)
# HLT_model_outputs: (150872, 60)
# L1_model_outputs: (150872, 60)
# HLT_AD_scores: (150872,)
# L1_AD_scores: (150872,)

# %%
def ROC_curve(dataset, bkg_type, target_rate=10, plot=True):
    """
    Plots ROC curve and returns AUC, TPR, FPR, and thresholds for each dataset.
    
    inputs: 
    dataset: dictionary containing dataset information
    bkg_type: the background type to calculate over
    plot: whether to plot the ROC curve or not
    
    returns:
    results: dictionary {dataset_names: {'TPR': ..., 'AUC': ..., 'FPR': ..., 'threshold': ...}}
    """
    
    bkg_tag = 'EB_datatest1'
    #target_rate = 10  # 10 Hz pure rate
    plt.figure(figsize=(8.5,6.8))
    
    results = {}
    
    for tag in dataset.keys():
        if tag != bkg_tag and tag != 'EB_datatrain':
        
            # Combine true labels, anomaly=1 and background=0
            trueVal = np.concatenate((np.ones(dataset[tag][f'{bkg_type}_AD_scores'].shape[0]), np.zeros(dataset[bkg_tag][f'{bkg_type}_AD_scores'].shape[0])))
            
            # Combine predictions from current dataset and background
            predVal_loss = np.concatenate((dataset[tag][f'{bkg_type}_AD_scores'], dataset[bkg_tag][f'{bkg_type}_AD_scores']))
        
            sample_weights = np.concatenate((dataset[tag]['weights'], dataset[bkg_tag]['weights']))
            
            for i in range(len(predVal_loss)):
                if np.isnan(predVal_loss[i]):
                    predVal_loss[i] = 0
           
            # Calculate ROC curve and AUC, including weights
            fpr_loss, tpr_loss, threshold_loss = sklearn.metrics.roc_curve(y_true=trueVal, y_score=predVal_loss, sample_weight=sample_weights)
            auc_loss = auc(fpr_loss, tpr_loss)

            # Initialize variables for early stopping
            min_diff = float('inf')
            best_idx = 0
            previous_diff = float('inf')
            
            # Iterate over thresholds with early stopping
            for idx, value in enumerate(threshold_loss):
                anomaly_idxs_bkg = dataset[bkg_tag][f'{bkg_type}_AD_scores'] > value
                bkg_rate = 100000 * np.sum(dataset[bkg_tag]['weights'] * (anomaly_idxs_bkg & ~dataset[bkg_tag]['passHLT'])) / np.sum(dataset[bkg_tag]['weights'])
                # Calculate the difference from the target rate
                diff = abs(bkg_rate - target_rate)
                
                # Check if the difference is decreasing
                if diff < min_diff:
                    min_diff = diff
                    best_idx = idx
                else:
                    # If the difference starts increasing, break the loop
                    if diff > previous_diff:
                        print(f'Background rate = {bkg_rate:.3}Hz')
                        break
                
                previous_diff = diff
            
            # Use the best index found
            selected_threshold = threshold_loss[best_idx]
            selected_fpr = fpr_loss[best_idx]
            signal_tpr = tpr_loss[best_idx]
            
            # Store the results
            results[tag] = {
                'TPR': signal_tpr,
                'AUC': auc_loss,
                'FPR': selected_fpr,
                'threshold': selected_threshold
            }
        
            # Plot ROC curve
            if plot:
                plt.plot(fpr_loss, tpr_loss, "-", label='%s (AUC = %.1f%%)' % (tag, auc_loss*100.), linewidth=1.5)

    if plot:
        # Set log scale for x and y axis
        plt.semilogx()
        plt.semilogy()
        
        # Plot aesthetics and layout
        plt.plot(np.linspace(0, 1), np.linspace(0, 1), '--', color='0.75')
        plt.plot([selected_fpr, selected_fpr], [0, 1], '--', color='r')
        plt.ylabel("True Positive Rate", fontsize=16)
        plt.xlabel("False Positive Rate", fontsize=16)
        plt.legend(loc='lower right', fontsize=6)
        plt.grid(True)
        plt.tight_layout()
        plt.title(f'Trained over {bkg_type} objects', fontsize=20)
        plt.show()

    return results

# %%
for target_rate in [10, 200, 1000]:
    print(f'TARGET (PURE) RATE::::: {target_rate}')
    HLT_results = ROC_curve(datasets, bkg_type='HLT', target_rate=target_rate)
    L1_results = ROC_curve(datasets, bkg_type='L1', target_rate=target_rate)

    # L1 Signal Efficiencies

    tags = []
    l1_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            L1_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            L1_anomaly_idxs = datasets[tag]['L1_AD_scores'] > L1_results[tag]['threshold']
            L1_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | L1_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            l1_efficiencies.append(L1_TPR)
            combined_efficiencies.append(L1_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, l1_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(l1_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, L1 Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()



    # Signal Efficiencies

    tags = []
    hlt_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            HLT_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_results[tag]['threshold']
            HLT_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | HLT_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            hlt_efficiencies.append(HLT_TPR)
            combined_efficiencies.append(HLT_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, hlt_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(hlt_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, HLT Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()
    
    # HLT overlaps
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = HLT_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['HLT_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")

    # HLT overlaps
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = L1_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")
# Out:
# TARGET (PURE) RATE::::: 10
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 33.1Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 14.3Hz
# Normalized by the left bar:
# [ 1.00004072  1.04609375  1.01183284  1.0723902   1.0046283   1.00009082
#   1.0018915   1.41269841  4.40277778 12.40262665  1.          1.0118782
#   1.00228545]
# Normalized by the left bar:
# [1.         1.00026042 1.00014583 1.0002207  1.00004594 1.
#  1.         1.         1.00925926 1.         1.         1.0000201
#  1.        ]
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 2e-05
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# A14N23LO:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 4.2857142857142856e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# qqa:
# HLT overlap: 0.0
# inverse overlap: 1.0002207018318252
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 2e-05
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# ZZ4lep:
# HLT overlap: 0.8
# inverse overlap: 1.0000114846163564
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 5e-05
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4
# -----
# Zprime2EJs:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HHbbttHadHad:
# HLT overlap: 0.0
# inverse overlap: 1.0000183641238476
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 1e-05
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ2:
# HLT overlap: 0.3333333333333333
# inverse overlap: 1.0018674136321195
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 3e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# jjJZ1:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_zerobias:
# HLT overlap: 0.0
# inverse overlap: 53.43050014693054
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 5.2619414432506276e-05
# Raw number of events that we tagged as anomalous: 79
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.00013110455588331694
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# jjJZ1&2&4:
# HLT overlap: 0.6
# inverse overlap: 1.0000200984825645
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 1.6666666666666667e-05
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# EB_datatest2:
# HLT overlap: 0.01006666005451823
# inverse overlap: 1.0320625762085331
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.00011267829683440267
# Raw number of events that we tagged as anomalous: 17
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# jjJZ4:
# HLT overlap: 0.9743589743589743
# inverse overlap: 1.000040723659428
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00156
# Raw number of events that we tagged as anomalous: 156
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 152
# -----
# A14N23LO:
# HLT overlap: 0.23706896551724138
# inverse overlap: 1.04609375
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0232
# Raw number of events that we tagged as anomalous: 232
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 55
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7199211045364892
# inverse overlap: 1.011832840298321
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.02897142857142857
# Raw number of events that we tagged as anomalous: 2028
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1460
# -----
# qqa:
# HLT overlap: 0.09141274238227147
# inverse overlap: 1.072390200838667
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00722
# Raw number of events that we tagged as anomalous: 361
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 33
# -----
# ZZ4lep:
# HLT overlap: 0.8470588235294118
# inverse overlap: 1.0046283003916254
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.02635
# Raw number of events that we tagged as anomalous: 2635
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2232
# -----
# Zprime2EJs:
# HLT overlap: 0.9157894736842105
# inverse overlap: 1.0000908182726365
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00095
# Raw number of events that we tagged as anomalous: 95
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 87
# -----
# HHbbttHadHad:
# HLT overlap: 0.4245810055865922
# inverse overlap: 1.0018915047563082
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00179
# Raw number of events that we tagged as anomalous: 179
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 76
# -----
# jjJZ2:
# HLT overlap: 0.022123893805309734
# inverse overlap: 1.4126984126984128
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00452
# Raw number of events that we tagged as anomalous: 452
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 10
# -----
# jjJZ1:
# HLT overlap: 0.013422818791946308
# inverse overlap: 4.402777777777778
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00745
# Raw number of events that we tagged as anomalous: 745
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 10
# -----
# EB_zerobias:
# HLT overlap: 0.0003000871126213009
# inverse overlap: 12.402626650668148
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 7.060326493475526e-05
# Raw number of events that we tagged as anomalous: 106
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0005244182235332678
# Raw number of events that we tagged as anomalous: 8
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 8
# -----
# jjJZ1&2&4:
# HLT overlap: 0.12767527675276752
# inverse overlap: 1.0118782031956588
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.004516666666666667
# Raw number of events that we tagged as anomalous: 1355
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 173
# -----
# EB_datatest2:
# HLT overlap: 0.3000480333539039
# inverse overlap: 1.0022854534217494
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 6.628135107906039e-05
# Raw number of events that we tagged as anomalous: 10
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# TARGET (PURE) RATE::::: 200
# /tmp/ipykernel_492741/1416309897.py:126: RuntimeWarning: invalid value encountered in scalar divide
#   HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.11e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Normalized by the left bar:
# [  1.00081447   1.34427083   1.08660056   2.16089164   1.03270819
#    1.00200935   1.04078672   7.62745098  37.84259259 166.64029988
#    1.           1.15211537   1.1574516 ]
# Normalized by the left bar:
# [1.00001018 1.00859375 1.00191659 1.00993158 1.00101065 1.00001135
#  1.00027546 1.0690943  1.61111111 1.48838478 1.         1.00208019
#  1.00065209]
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00017
# Raw number of events that we tagged as anomalous: 17
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 17
# -----
# A14N23LO:
# HLT overlap: 0.5
# inverse overlap: 1.0005208333333333
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0004
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.8260869565217391
# inverse overlap: 1.0000833298612557
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.00032857142857142856
# Raw number of events that we tagged as anomalous: 23
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 19
# -----
# qqa:
# HLT overlap: 0.2857142857142857
# inverse overlap: 1.001103509159126
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00014
# Raw number of events that we tagged as anomalous: 7
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# ZZ4lep:
# HLT overlap: 0.875
# inverse overlap: 1.0000459384654257
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00032
# Raw number of events that we tagged as anomalous: 32
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 28
# -----
# Zprime2EJs:
# HLT overlap: 0.5
# inverse overlap: 1.0000227045681591
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 4e-05
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# HHbbttHadHad:
# HLT overlap: 0.25
# inverse overlap: 1.0001652771146288
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00012
# Raw number of events that we tagged as anomalous: 12
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ2:
# HLT overlap: 0.10344827586206896
# inverse overlap: 1.0242763772175536
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00029
# Raw number of events that we tagged as anomalous: 29
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ1:
# HLT overlap: 0.021739130434782608
# inverse overlap: 1.2083333333333333
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00046
# Raw number of events that we tagged as anomalous: 46
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_zerobias:
# HLT overlap: 1.1086329295235841e-05
# inverse overlap: 625.2209533898665
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0006320990417271956
# Raw number of events that we tagged as anomalous: 949
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0009177318911832187
# Raw number of events that we tagged as anomalous: 14
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 14
# -----
# jjJZ1&2&4:
# HLT overlap: 0.23655913978494625
# inverse overlap: 1.0007134961310422
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.00031
# Raw number of events that we tagged as anomalous: 93
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# EB_datatest2:
# HLT overlap: 0.010166855656989379
# inverse overlap: 1.126973529575819
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.0009743358608621879
# Raw number of events that we tagged as anomalous: 147
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4
# -----
# jjJZ4:
# HLT overlap: 0.9787629413326254
# inverse overlap: 1.0008144731885606
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.03767
# Raw number of events that we tagged as anomalous: 3767
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3687
# -----
# A14N23LO:
# HLT overlap: 0.2975557917109458
# inverse overlap: 1.3442708333333333
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.1882
# Raw number of events that we tagged as anomalous: 1882
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 560
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.6863351693956086
# inverse overlap: 1.0866005583100704
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.18932857142857143
# Raw number of events that we tagged as anomalous: 13253
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 9096
# -----
# qqa:
# HLT overlap: 0.09699570815450644
# inverse overlap: 2.160891635400574
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.1165
# Raw number of events that we tagged as anomalous: 5825
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 565
# -----
# ZZ4lep:
# HLT overlap: 0.8430853994490358
# inverse overlap: 1.0327081873830004
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.1815
# Raw number of events that we tagged as anomalous: 18150
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 15302
# -----
# Zprime2EJs:
# HLT overlap: 0.9095554420030659
# inverse overlap: 1.0020093542820816
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.01957
# Raw number of events that we tagged as anomalous: 1957
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1780
# -----
# HHbbttHadHad:
# HLT overlap: 0.4694218824653607
# inverse overlap: 1.0407867190656335
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.04186
# Raw number of events that we tagged as anomalous: 4186
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1965
# -----
# jjJZ2:
# HLT overlap: 0.015260821309655937
# inverse overlap: 7.627450980392157
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.07208
# Raw number of events that we tagged as anomalous: 7208
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 110
# -----
# jjJZ1:
# HLT overlap: 0.006987771400049913
# inverse overlap: 37.842592592592595
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.08014
# Raw number of events that we tagged as anomalous: 8014
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 56
# -----
# EB_zerobias:
# HLT overlap: 0.00047742555030113383
# inverse overlap: 166.64029987826834
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0010430633291304409
# Raw number of events that we tagged as anomalous: 1566
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 23
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.006686332350049164
# Raw number of events that we tagged as anomalous: 102
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 102
# -----
# jjJZ1&2&4:
# HLT overlap: 0.20293823390026855
# inverse overlap: 1.1521153652899205
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.06330333333333334
# Raw number of events that we tagged as anomalous: 18991
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3854
# -----
# EB_datatest2:
# HLT overlap: 0.041537777672251724
# inverse overlap: 1.1574515958251272
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.001537727345034201
# Raw number of events that we tagged as anomalous: 232
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 21
# TARGET (PURE) RATE::::: 1000
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Normalized by the left bar:
# [  1.00587439   1.90807292   1.24246906   5.62811741   1.09034948
#    1.02538371   1.21306056  35.8907563  165.31481481 887.68833439
#    1.           1.73800623   1.93716749]
# Normalized by the left bar:
# [ 1.00007127  1.065625    1.01624932  1.10946811  1.00652326  1.00014758
#   1.00308517  1.64052288  5.65277778 17.09538702  1.          1.01703346
#   1.00358963]
# -----
# jjJZ4:
# HLT overlap: 0.9696969696969697
# inverse overlap: 1.000040723659428
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00132
# Raw number of events that we tagged as anomalous: 132
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 128
# -----
# A14N23LO:
# HLT overlap: 0.25
# inverse overlap: 1.00390625
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.002
# Raw number of events that we tagged as anomalous: 20
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7512437810945274
# inverse overlap: 1.0010416232656973
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.002871428571428571
# Raw number of events that we tagged as anomalous: 201
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 151
# -----
# qqa:
# HLT overlap: 0.22727272727272727
# inverse overlap: 1.007503862282057
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00088
# Raw number of events that we tagged as anomalous: 44
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 10
# -----
# ZZ4lep:
# HLT overlap: 0.8941605839416058
# inverse overlap: 1.0003330538743354
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00274
# Raw number of events that we tagged as anomalous: 274
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 245
# -----
# Zprime2EJs:
# HLT overlap: 0.8260869565217391
# inverse overlap: 1.0000454091363182
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00023
# Raw number of events that we tagged as anomalous: 23
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 19
# -----
# HHbbttHadHad:
# HLT overlap: 0.46938775510204084
# inverse overlap: 1.0009549344400779
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00098
# Raw number of events that we tagged as anomalous: 98
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 46
# -----
# jjJZ2:
# HLT overlap: 0.013888888888888888
# inverse overlap: 1.1988795518207283
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00216
# Raw number of events that we tagged as anomalous: 216
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ1:
# HLT overlap: 0.00411522633744856
# inverse overlap: 2.1203703703703702
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00243
# Raw number of events that we tagged as anomalous: 243
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_zerobias:
# HLT overlap: 9.347127393219885e-06
# inverse overlap: 4427.218707967821
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.004293477790277664
# Raw number of events that we tagged as anomalous: 6446
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 12
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.00812848246476565
# Raw number of events that we tagged as anomalous: 124
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 124
# -----
# jjJZ1&2&4:
# HLT overlap: 0.2233502538071066
# inverse overlap: 1.004612601748568
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.00197
# Raw number of events that we tagged as anomalous: 591
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 132
# -----
# EB_datatest2:
# HLT overlap: 0.01579624844693716
# inverse overlap: 1.548513882265776
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.006880004242006469
# Raw number of events that we tagged as anomalous: 1038
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 29
# -----
# jjJZ4:
# HLT overlap: 0.9798954703832753
# inverse overlap: 1.0058743878724943
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.287
# Raw number of events that we tagged as anomalous: 28700
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 28123
# -----
# A14N23LO:
# HLT overlap: 0.3332695984703633
# inverse overlap: 1.9080729166666666
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.523
# Raw number of events that we tagged as anomalous: 5230
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1743
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.6836368578418048
# inverse overlap: 1.2424690637890088
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.5255714285714286
# Raw number of events that we tagged as anomalous: 36790
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 25151
# -----
# qqa:
# HLT overlap: 0.09299307958477508
# inverse overlap: 5.628117413374531
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.4624
# Raw number of events that we tagged as anomalous: 23120
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2150
# -----
# ZZ4lep:
# HLT overlap: 0.8534408882596222
# inverse overlap: 1.090349476875725
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.53678
# Raw number of events that we tagged as anomalous: 53678
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 45811
# -----
# Zprime2EJs:
# HLT overlap: 0.8841030425542943
# inverse overlap: 1.025383707201889
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.19293
# Raw number of events that we tagged as anomalous: 19293
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 17057
# -----
# HHbbttHadHad:
# HLT overlap: 0.5305874737012461
# inverse overlap: 1.2130605648804496
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.24716
# Raw number of events that we tagged as anomalous: 24716
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 13114
# -----
# jjJZ2:
# HLT overlap: 0.013334037440920973
# inverse overlap: 35.890756302521005
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.37873
# Raw number of events that we tagged as anomalous: 37873
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 505
# -----
# jjJZ1:
# HLT overlap: 0.003984958186002133
# inverse overlap: 165.3148148148148
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.35634
# Raw number of events that we tagged as anomalous: 35634
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 142
# -----
# EB_zerobias:
# HLT overlap: 0.0002516481221958322
# inverse overlap: 887.6883343890743
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.004169589042373282
# Raw number of events that we tagged as anomalous: 6260
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 65
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.024188790560471976
# Raw number of events that we tagged as anomalous: 369
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 369
# -----
# jjJZ1&2&4:
# HLT overlap: 0.28148206126662034
# inverse overlap: 1.738006230529595
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.34069666666666665
# Raw number of events that we tagged as anomalous: 102209
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 28770
# -----
# EB_datatest2:
# HLT overlap: 0.02480435303820528
# inverse overlap: 1.9371674864845367
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.010737578874807785
# Raw number of events that we tagged as anomalous: 1620
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 82

# %%
#HLT
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
#HLT
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
#HLT
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n] > 1) and (HLT_electron_mults[tag][n] > 1) and (HLT_muon_mults[tag][n] > 1) and (HLT_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    ax1.hist(HLT_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1

plt.xticks(np.arange(0, 2000,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
#L1
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n] > 1) and (L1_electron_mults[tag][n] > 1) and (L1_muon_mults[tag][n] > 1) and (L1_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    ax1.hist(L1_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1
plt.xlim(0, 800)
plt.xticks(np.arange(0, 800,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
import ROOT
# Out:
# C system headers (glibc/Xcode/Windows SDK) must be installed.
# In file included from input_line_4:36:
# /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/include/c++/cassert:44:10: fatal error: 'assert.h' file not found
# #include <assert.h>
#          ^~~~~~~~~~
# input_line_35:1:10: fatal error: 'dlfcn.h' file not found
# #include "dlfcn.h"
#          ^~~~~~~~~

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "HLT" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/Root/HLT', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ4max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTA14N23LOmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTHAHMggfZdZd2l2numax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTqqamax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTZZ4lepmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTZprime2EJsmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTHHbbttHadHadmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ2max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_zerobiasmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_passHLTmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1&2&4max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_datatest1max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_datatest2max pt v ad score  _plot.png has been created

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "L1" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ4max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ4max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1A14N23LOmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1A14N23LOmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2numax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2numax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1qqamax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1qqamax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1ZZ4lepmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1ZZ4lepmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1Zprime2EJsmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1Zprime2EJsmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HHbbttHadHadmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HHbbttHadHadmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ2max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ2max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_zerobiasmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_zerobiasmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_passHLTmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_passHLTmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datatest1max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datatest1max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datatest2max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datatest2max pt v ad score  _plot.png

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "HLT" + tag + "jet mult v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_jet_mults[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ4jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ4jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTA14N23LOjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTA14N23LOjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTHAHMggfZdZd2l2nujet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTHAHMggfZdZd2l2nujet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTqqajet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTqqajet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTZZ4lepjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTZZ4lepjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTZprime2EJsjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTZprime2EJsjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTHHbbttHadHadjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTHHbbttHadHadjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ2jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ2jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_zerobiasjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_zerobiasjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_passHLTjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_passHLTjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_datatest1jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_datatest1jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_datatest2jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_datatest2jet mult v ad score  _plot.png

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "L1" + tag + "jet mult v ad score "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(L1_jet_mults[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ4jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ4jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1A14N23LOjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1A14N23LOjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2nujet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2nujet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1qqajet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1qqajet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1ZZ4lepjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1ZZ4lepjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1Zprime2EJsjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1Zprime2EJsjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HHbbttHadHadjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HHbbttHadHadjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ2jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ2jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_zerobiasjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_zerobiasjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_passHLTjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_passHLTjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datatest1jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datatest1jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datatest2jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datatest2jet mult v ad score _plot.png

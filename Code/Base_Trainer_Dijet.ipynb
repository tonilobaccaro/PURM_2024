# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import random
import sklearn
import collections
from sklearn.model_selection import train_test_split
import json
import pylab
from scipy.optimize import curve_fit
from tensorflow.keras import layers, Model
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, auc
import matplotlib
import matplotlib.patches as mpatches
#import shap
import os
import pandas as pd
#improve gpu memory usage
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# %%
# Set matplotlib default color cycle
new_color_cycle = [
#jjJZ4
    '#4f2ca8',
#A14N23LO
    '#b45f06',
#HAHMggf
    '#ff0000',
#qqa
    '#d4d400',
#ZZ4lep
    '#294a18',
#Zprime2EJs
    '#00de00',
#HHbbttHadHad
    '#5b0f00',
#jjJZ2
  '#ca7dff',
#jjJZ1
  '#d201d2',
#data
 '#3232ff', 
#zerobias
    '#002a75',
#passedHLT
    '#00cdcd',
#jjJZ124
    '#8e1d55',
#test 2
    '#7f7f7f'
]

# You can then apply this new color cycle to your matplotlib plots
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=new_color_cycle)

# %% [markdown]
# ## Read Data Files

# %%
# This is the list that will hold all of the data 
datasets = {}

# %%
# Read Monte Carlo Simulated Collisions

data_path = '/home/jovyan/MC_data/'

for filename in os.listdir(data_path):

    if filename.startswith('N') or filename.startswith('.'): continue

    dataset_tag = filename.split('_')[0]
    
    with h5py.File(data_path+filename, 'r') as hf:
        HLT_jets = hf['HLT_jets'][:]
        L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
        L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
        HLT_electrons = hf['HLT_electrons'][:]
        LRT_electrons = hf['LRT_electrons'][:]
        L1_egammas = hf['L1_egammas'][:]
        HLT_muons = hf['HLT_muons'][:]
        LRT_muons = hf['LRT_muons'][:]
        L1_muons = hf['L1_muons'][:]
        L1_eFex_taus = hf['L1_eFex_taus'][:]
        L1_jFex_taus = hf['L1_jFex_taus'][:]
        HLT_photons = hf['HLT_photons'][:]
        HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 4)  # Broadcasting MET
        L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
        pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
        pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]

        HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, [0, 2, 3]], HLT_muons[:, :3, [0, 2, 3]], HLT_photons[:, :3, [0, 2, 3]], HLT_MET[:, :, [0, 2, 3]]], axis=1)
        L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)
        
        datasets[dataset_tag] = {
            'HLT_data': HLT_objects,
            'L1_data': L1_objects,
            'passL1': pass_L1_unprescaled==1,
            'passHLT': pass_HLT_unprescaled==1,
            'weights': np.ones(len(HLT_objects)),
        }

        if len(HLT_objects) > 100000:
            datasets[dataset_tag] = {key: value[:100000] for key, value in datasets[dataset_tag].items()}

# %%
# Read 2024 EB data

with h5py.File('/home/jovyan/EB_data/EB_ntuples_08-13-2024-003.h5', 'r') as hf:
    HLT_jets = hf['HLT_jets'][:]
    ofl_jets = hf['ofl_jets'][:]
    L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
    L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
    HLT_electrons = hf['HLT_electrons'][:]
    LRT_electrons = hf['LRT_electrons'][:]
    ofl_electrons = hf['ofl_electrons'][:]
    L1_egammas = hf['L1_egammas'][:]
    HLT_muons = hf['HLT_muons'][:]
    LRT_muons = hf['LRT_muons'][:]
    ofl_muons = hf['ofl_muons'][:]
    L1_muons = hf['L1_muons'][:]
    L1_eFex_taus = hf['L1_eFex_taus'][:]
    L1_jFex_taus = hf['L1_jFex_taus'][:]
    HLT_photons = hf['HLT_photons'][:]
    ofl_photons = hf['ofl_photons'][:]
    HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 3)  # Broadcasting MET
    L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
    pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
    pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]
    EB_weights = hf["EB_weights"][:]
    event_number = hf["event_number"][:]
    run_number = hf["run_number"][:]

HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, :], HLT_muons[:, :3, :], HLT_photons[:, :3, :], HLT_MET], axis=1)
L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)



# Indices of events that passed L1
pass_L1_idxs = (pass_L1_unprescaled == 1)

# Indices of events that passed HLT
pass_HLT_idxs = (pass_HLT_unprescaled == 1)



datasets['EB_data'] = {
    'HLT_data': HLT_objects[pass_L1_idxs] ,
    'L1_data': L1_objects[pass_L1_idxs] ,
    'passL1': pass_L1_idxs[pass_L1_idxs],
    'passHLT': pass_HLT_idxs[pass_L1_idxs],
    'weights': EB_weights[pass_L1_idxs],
}

datasets['EB_zerobias'] = {
    'HLT_data': HLT_objects[~pass_L1_idxs] ,
    'L1_data': L1_objects[~pass_L1_idxs] ,
    'passL1': pass_L1_idxs[~pass_L1_idxs],
    'passHLT': pass_HLT_idxs[~pass_L1_idxs],
    'weights': EB_weights[~pass_L1_idxs],
}

datasets['EB_passHLT'] = {
    'HLT_data': HLT_objects[pass_HLT_idxs] ,
    'L1_data': L1_objects[pass_HLT_idxs] ,
    'passL1': pass_L1_idxs[pass_HLT_idxs],
    'passHLT': pass_HLT_idxs[pass_HLT_idxs],
    'weights': EB_weights[pass_HLT_idxs],
}

# %% [markdown]
# ## Data Processing

# %%
#create combo of jjJZ4 & jjJZ2 & jjJZ1

datasets['jjJZ1&2&4'] = {
    'HLT_data': np.concatenate((datasets['jjJZ1']['HLT_data'],datasets['jjJZ2']['HLT_data'],datasets['jjJZ4']['HLT_data'])),
    'L1_data': np.concatenate((datasets['jjJZ1']['L1_data'],datasets['jjJZ2']['L1_data'],datasets['jjJZ4']['L1_data'])) ,
    'passL1': np.concatenate((datasets['jjJZ1']['passL1'],datasets['jjJZ2']['passL1'],datasets['jjJZ4']['passL1'])),
    'passHLT': np.concatenate((datasets['jjJZ1']['passHLT'],datasets['jjJZ2']['passHLT'],datasets['jjJZ4']['passHLT'])),
    'weights': np.concatenate((datasets['jjJZ1']['weights'],datasets['jjJZ2']['weights'],datasets['jjJZ4']['weights'])),
}

# %%
"""Multiply the pt of the L1 muons by 1000 to get them into the right units."""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label == 'L1_data':
            data[:, 13:16, 0] *= 1000

# %%
# Split EB data in train, test

random_seed = 789247

indices = np.arange(len(datasets['jjJZ1&2&4']['HLT_data']))
train_indices, _indices = train_test_split(indices, train_size=0.5, random_state=random_seed)
test1_indices, test2_indices = train_test_split(_indices, train_size=0.5, random_state=random_seed)

datasets['jjJZ1&2&4_train'] = {key:value[train_indices] for key, value in datasets['jjJZ1&2&4'].items()}
datasets['jjJZ1&2&4_test1'] = {key:value[test1_indices] for key, value in datasets['jjJZ1&2&4'].items()}
datasets['jjJZ1&2&4_test2'] = {key:value[test2_indices] for key, value in datasets['jjJZ1&2&4'].items()}

del datasets['jjJZ1&2&4']

# %%
#save pt values before normalization for 2d histogram of max pt vs. anomaly score & efficiency plots
HLT_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['HLT_data'][i,j,0]:
                temp[i] = datasets[tag]['HLT_data'][i,j,0]
    HLT_max_pt_vals[tag] = temp
L1_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['L1_data'][i,j,0]:
                temp[i] = datasets[tag]['L1_data'][i,j,0]
    L1_max_pt_vals[tag] = temp
HLT_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_jet_mults[tag] = temp
L1_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_jet_mults[tag] = temp
HLT_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10,13):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_electron_mults[tag] = temp
L1_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10,13):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_electron_mults[tag] = temp
HLT_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(13,16):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_muon_mults[tag] = temp
L1_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(13,16):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_muon_mults[tag] = temp
HLT_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(16,19):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_photon_mults[tag] = temp
L1_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(16,19):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_photon_mults[tag] = temp

# %%
for tag, dict in datasets.items():
    print(f'\n{tag}:')
    for key, value in dict.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 20, 3)
# L1_data: (10000, 20, 3)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 20, 3)
# L1_data: (70000, 20, 3)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 20, 3)
# L1_data: (50000, 20, 3)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_data:
# HLT_data: (603486, 20, 3)
# L1_data: (603486, 20, 3)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 20, 3)
# L1_data: (1501347, 20, 3)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 20, 3)
# L1_data: (15255, 20, 3)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 20, 3)
# L1_data: (150000, 20, 3)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 20, 3)
# L1_data: (75000, 20, 3)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 20, 3)
# L1_data: (75000, 20, 3)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)

# %%
"""Met bias. For some events, MET was not calculated, so was written as -999.
We don't want this to impact training, so we map 0 --> 0.001 and -999 --> 0"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):

            # MET: 0 --> 0.001 and -999 --> 0 and nan --> 0
            MET_zeros = (data[:, 19, 0] == 0) # indices where MET=0
            MET_999 = ((data[:, 19, 0] == -999)) # indices where MET=-999 (not calculated)
            MET_nan = np.isnan(data[:, 19, 2])
            data[MET_zeros, 19, 0] = 0.001
            data[MET_999, 19, :] = 0
            data[MET_nan, 19, :] = 0

# %%
"""Normalize pt such that sum(pt) = 1 in each event"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
#             # sum of the pt and E in each event
            sum_pt = np.sum(data[:, :, 0], axis=1, keepdims=True)
        
#             # If the sum is 0, set the sum to 1 to avoid division by 0
            sum_pt[sum_pt == 0] = 1
        
#             # Divide pt and E by their respective sums, multiply by 10
            data[:, :, 0] *= (1/sum_pt)

# %% [markdown]
# ## Autoencoder Architecture

# %%
# Flatten ndarrays for use in DNN

for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
            datasets[tag][label] = np.reshape(data, newshape=(-1, 60))

# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_data:
# HLT_data: (603486, 60)
# L1_data: (603486, 60)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 60)
# L1_data: (150000, 60)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)

# %%
def create_AE(input_dim, h_dim_1, h_dim_2, latent_dim):
    
     # Encoder
    encoder_inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(h_dim_1, activation='relu')(encoder_inputs)
    x = layers.Dense(h_dim_2, activation='relu')(x)
    z = layers.Dense(latent_dim, activation='relu')(x)
    
    encoder = Model(inputs=encoder_inputs, outputs=z)

    # Decoder
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(h_dim_2, activation='relu')(decoder_inputs)
    x = layers.Dense(h_dim_1, activation='relu')(x)
    outputs = layers.Dense(input_dim)(x)

    decoder = Model(inputs=decoder_inputs, outputs=outputs)

    ae_outputs = decoder(encoder(encoder_inputs))
    ae = Model(encoder_inputs, outputs=ae_outputs)
    return ae, encoder, decoder

# %%
def loss_fn(y_true, y_pred):
    """masked mse"""
    mask0 = K.cast(K.not_equal(y_true, 0), K.floatx())
    maskMET = K.cast(K.not_equal(y_true, -999), K.floatx())
    mask = mask0 * maskMET
    squared_difference = K.square((y_pred - y_true))
    return K.mean(squared_difference)

# %%
# Initialize models
INPUT_DIM = datasets['jjJZ1&2&4_train']['HLT_data'].shape[1]
H_DIM_1 = 32
H_DIM_2 = 8
LATENT_DIM = 2

HLT_AE, HLT_encoder, HLT_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)
L1_AE, L1_encoder, L1_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)

HLT_AE.summary()
L1_AE.summary()
# Out:
# 2024-10-07 23:37:38.331135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20732 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:41:00.0, compute capability: 8.6
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_3 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_7 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_9 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# Define callbacks: early stopping and learning rate scheduler

STOP_PATIENCE = 8
LR_PATIENCE = 4

early_stopping = EarlyStopping(patience=STOP_PATIENCE, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=LR_PATIENCE, verbose=1)

callbacks = [early_stopping, reduce_lr]

# %%
NUM_EPOCHS = 150
BATCH_SIZE = 512

# %% [markdown]
# ## Model Training

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# train HLT model
history = HLT_AE.fit(
    x=datasets['jjJZ1&2&4_train']['HLT_data'], 
    y=datasets['jjJZ1&2&4_train']['HLT_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['jjJZ1&2&4_train']['weights']
)
# Out:
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728344260.737994  544046 service.cc:145] XLA service 0x7f09e80023c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728344260.738050  544046 service.cc:153]   StreamExecutor device (0): NVIDIA A10, Compute Capability 8.6
# 2024-10-07 23:37:40.766264: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-07 23:37:41.022780: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728344261.709762  544202 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_513', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1728344261.726611  544174 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_513', 8 bytes spill stores, 8 bytes spill loads
# 176/250 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 1.4398
# I0000 00:00:1728344263.466778  544046 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 1.4226 - val_loss: 1.2711 - learning_rate: 0.0010
# Epoch 2/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2629 - val_loss: 1.2472 - learning_rate: 0.0010
# Epoch 3/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2508 - val_loss: 1.2425 - learning_rate: 0.0010
# Epoch 4/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2483 - val_loss: 1.2386 - learning_rate: 0.0010
# Epoch 5/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2375 - val_loss: 1.2305 - learning_rate: 0.0010
# Epoch 6/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2308 - val_loss: 1.2188 - learning_rate: 0.0010
# Epoch 7/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2186 - val_loss: 1.2122 - learning_rate: 0.0010
# Epoch 8/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2147 - val_loss: 1.2064 - learning_rate: 0.0010
# Epoch 9/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2066 - val_loss: 1.2014 - learning_rate: 0.0010
# Epoch 10/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2027 - val_loss: 1.1999 - learning_rate: 0.0010
# Epoch 11/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1994 - val_loss: 1.1953 - learning_rate: 0.0010
# Epoch 12/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1976 - val_loss: 1.1925 - learning_rate: 0.0010
# Epoch 13/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1943 - val_loss: 1.1893 - learning_rate: 0.0010
# Epoch 14/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1912 - val_loss: 1.1877 - learning_rate: 0.0010
# Epoch 15/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1875 - val_loss: 1.1852 - learning_rate: 0.0010
# Epoch 16/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1852 - val_loss: 1.1824 - learning_rate: 0.0010
# Epoch 17/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1831 - val_loss: 1.1807 - learning_rate: 0.0010
# Epoch 18/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1808 - val_loss: 1.1782 - learning_rate: 0.0010
# Epoch 19/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1821 - val_loss: 1.1771 - learning_rate: 0.0010
# Epoch 20/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1806 - val_loss: 1.1758 - learning_rate: 0.0010
# Epoch 21/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1728 - val_loss: 1.1733 - learning_rate: 0.0010
# Epoch 22/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1705 - val_loss: 1.1724 - learning_rate: 0.0010
# Epoch 23/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1727 - val_loss: 1.1708 - learning_rate: 0.0010
# Epoch 24/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1706 - val_loss: 1.1704 - learning_rate: 0.0010
# Epoch 25/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1701 - val_loss: 1.1677 - learning_rate: 0.0010
# Epoch 26/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1705 - val_loss: 1.1657 - learning_rate: 0.0010
# Epoch 27/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1640 - val_loss: 1.1653 - learning_rate: 0.0010
# Epoch 28/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1655 - val_loss: 1.1633 - learning_rate: 0.0010
# Epoch 29/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1644 - val_loss: 1.1619 - learning_rate: 0.0010
# Epoch 30/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1610 - val_loss: 1.1617 - learning_rate: 0.0010
# Epoch 31/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1623 - val_loss: 1.1570 - learning_rate: 0.0010
# Epoch 32/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1586 - val_loss: 1.1576 - learning_rate: 0.0010
# Epoch 33/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1578 - val_loss: 1.1537 - learning_rate: 0.0010
# Epoch 34/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1563 - val_loss: 1.1547 - learning_rate: 0.0010
# Epoch 35/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1576 - val_loss: 1.1528 - learning_rate: 0.0010
# Epoch 36/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1550 - val_loss: 1.1513 - learning_rate: 0.0010
# Epoch 37/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1508 - val_loss: 1.1507 - learning_rate: 0.0010
# Epoch 38/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1519 - val_loss: 1.1484 - learning_rate: 0.0010
# Epoch 39/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1481 - val_loss: 1.1469 - learning_rate: 0.0010
# Epoch 40/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1500 - val_loss: 1.1495 - learning_rate: 0.0010
# Epoch 41/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1468 - val_loss: 1.1445 - learning_rate: 0.0010
# Epoch 42/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1471 - val_loss: 1.1444 - learning_rate: 0.0010
# Epoch 43/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1488 - val_loss: 1.1424 - learning_rate: 0.0010
# Epoch 44/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1437 - val_loss: 1.1450 - learning_rate: 0.0010
# Epoch 45/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1450 - val_loss: 1.1400 - learning_rate: 0.0010
# Epoch 46/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1406 - val_loss: 1.1385 - learning_rate: 0.0010
# Epoch 47/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1404 - val_loss: 1.1378 - learning_rate: 0.0010
# Epoch 48/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1386 - val_loss: 1.1391 - learning_rate: 0.0010
# Epoch 49/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1407 - val_loss: 1.1376 - learning_rate: 0.0010
# Epoch 50/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1403 - val_loss: 1.1382 - learning_rate: 0.0010
# Epoch 51/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1391 - val_loss: 1.1371 - learning_rate: 0.0010
# Epoch 52/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1395 - val_loss: 1.1344 - learning_rate: 0.0010
# Epoch 53/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1357 - val_loss: 1.1362 - learning_rate: 0.0010
# Epoch 54/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1368 - val_loss: 1.1351 - learning_rate: 0.0010
# Epoch 55/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1370 - val_loss: 1.1327 - learning_rate: 0.0010
# Epoch 56/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1356 - val_loss: 1.1326 - learning_rate: 0.0010
# Epoch 57/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1323 - val_loss: 1.1311 - learning_rate: 0.0010
# Epoch 58/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1358 - val_loss: 1.1344 - learning_rate: 0.0010
# Epoch 59/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1332 - val_loss: 1.1316 - learning_rate: 0.0010
# Epoch 60/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1333 - val_loss: 1.1301 - learning_rate: 0.0010
# Epoch 61/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1302 - val_loss: 1.1293 - learning_rate: 0.0010
# Epoch 62/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1315 - val_loss: 1.1317 - learning_rate: 0.0010
# Epoch 63/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1327 - val_loss: 1.1352 - learning_rate: 0.0010
# Epoch 64/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1300 - val_loss: 1.1279 - learning_rate: 0.0010
# Epoch 65/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1277 - val_loss: 1.1264 - learning_rate: 0.0010
# Epoch 66/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1284 - val_loss: 1.1321 - learning_rate: 0.0010
# Epoch 67/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1273 - val_loss: 1.1262 - learning_rate: 0.0010
# Epoch 68/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1273 - val_loss: 1.1255 - learning_rate: 0.0010
# Epoch 69/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1264 - val_loss: 1.1235 - learning_rate: 0.0010
# Epoch 70/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1245 - val_loss: 1.1326 - learning_rate: 0.0010
# Epoch 71/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1280 - val_loss: 1.1220 - learning_rate: 0.0010
# Epoch 72/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1232 - val_loss: 1.1213 - learning_rate: 0.0010
# Epoch 73/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1243 - val_loss: 1.1226 - learning_rate: 0.0010
# Epoch 74/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1231 - val_loss: 1.1206 - learning_rate: 0.0010
# Epoch 75/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1229 - val_loss: 1.1214 - learning_rate: 0.0010
# Epoch 76/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1215 - val_loss: 1.1220 - learning_rate: 0.0010
# Epoch 77/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1196 - val_loss: 1.1191 - learning_rate: 0.0010
# Epoch 78/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1191 - val_loss: 1.1201 - learning_rate: 0.0010
# Epoch 79/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1182 - val_loss: 1.1178 - learning_rate: 0.0010
# Epoch 80/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1195 - val_loss: 1.1269 - learning_rate: 0.0010
# Epoch 81/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1203 - val_loss: 1.1201 - learning_rate: 0.0010
# Epoch 82/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1216 - val_loss: 1.1167 - learning_rate: 0.0010
# Epoch 83/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1223 - val_loss: 1.1195 - learning_rate: 0.0010
# Epoch 84/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1173 - val_loss: 1.1174 - learning_rate: 0.0010
# Epoch 85/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1183 - val_loss: 1.1216 - learning_rate: 0.0010
# Epoch 86/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1214 - val_loss: 1.1163 - learning_rate: 0.0010
# Epoch 87/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1185 - val_loss: 1.1161 - learning_rate: 0.0010
# Epoch 88/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1152 - val_loss: 1.1147 - learning_rate: 0.0010
# Epoch 89/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1160 - val_loss: 1.1156 - learning_rate: 0.0010
# Epoch 90/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1172 - val_loss: 1.1150 - learning_rate: 0.0010
# Epoch 91/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1135 - val_loss: 1.1151 - learning_rate: 0.0010
# Epoch 92/150
# 247/250 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 1.1182
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1182 - val_loss: 1.1151 - learning_rate: 0.0010
# Epoch 93/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1142 - val_loss: 1.1128 - learning_rate: 1.0000e-04
# Epoch 94/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1140 - val_loss: 1.1128 - learning_rate: 1.0000e-04
# Epoch 95/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1146 - val_loss: 1.1129 - learning_rate: 1.0000e-04
# Epoch 96/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1152 - val_loss: 1.1130 - learning_rate: 1.0000e-04
# Epoch 97/150
# 248/250 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 1.1103
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1104 - val_loss: 1.1128 - learning_rate: 1.0000e-04
# Epoch 98/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1140 - val_loss: 1.1127 - learning_rate: 1.0000e-05
# Epoch 99/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1106 - val_loss: 1.1127 - learning_rate: 1.0000e-05
# Epoch 100/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1111 - val_loss: 1.1126 - learning_rate: 1.0000e-05
# Epoch 101/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1104 - val_loss: 1.1126 - learning_rate: 1.0000e-05
# Epoch 102/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1109 - val_loss: 1.1126 - learning_rate: 1.0000e-05
# Epoch 103/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1123 - val_loss: 1.1126 - learning_rate: 1.0000e-05
# Epoch 104/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1124 - val_loss: 1.1125 - learning_rate: 1.0000e-05
# Epoch 105/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1150 - val_loss: 1.1125 - learning_rate: 1.0000e-05
# Epoch 106/150
# 241/250 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 1.1129
# Epoch 106: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1128 - val_loss: 1.1125 - learning_rate: 1.0000e-05
# Epoch 107/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1116 - val_loss: 1.1125 - learning_rate: 1.0000e-06
# Epoch 108/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1111 - val_loss: 1.1125 - learning_rate: 1.0000e-06
# Epoch 109/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1122 - val_loss: 1.1125 - learning_rate: 1.0000e-06
# Epoch 110/150
# 233/250 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 1.1127
# Epoch 110: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1126 - val_loss: 1.1125 - learning_rate: 1.0000e-06
# Epoch 111/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1124 - val_loss: 1.1125 - learning_rate: 1.0000e-07
# Epoch 112/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1111 - val_loss: 1.1125 - learning_rate: 1.0000e-07
# Epoch 113/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1112 - val_loss: 1.1125 - learning_rate: 1.0000e-07
# Epoch 114/150
# 245/250 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 1.1117
# Epoch 114: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1117 - val_loss: 1.1125 - learning_rate: 1.0000e-07
# Epoch 115/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1118 - val_loss: 1.1125 - learning_rate: 1.0000e-08
# Epoch 116/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1132 - val_loss: 1.1125 - learning_rate: 1.0000e-08
# Epoch 117/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1099 - val_loss: 1.1125 - learning_rate: 1.0000e-08
# Epoch 118/150
# 240/250 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 1.1118
# Epoch 118: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1118 - val_loss: 1.1125 - learning_rate: 1.0000e-08
# Epoch 119/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1098 - val_loss: 1.1125 - learning_rate: 1.0000e-09
# Epoch 120/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1135 - val_loss: 1.1125 - learning_rate: 1.0000e-09
# Epoch 121/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1106 - val_loss: 1.1125 - learning_rate: 1.0000e-09
# Epoch 122/150
# 238/250 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 1.1143
# Epoch 122: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1142 - val_loss: 1.1125 - learning_rate: 1.0000e-09
# Epoch 123/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1080 - val_loss: 1.1125 - learning_rate: 1.0000e-10
# Epoch 124/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1136 - val_loss: 1.1125 - learning_rate: 1.0000e-10
# Epoch 125/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1130 - val_loss: 1.1125 - learning_rate: 1.0000e-10

# %%
HLT_AE.save_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.save_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')
HLT_AE.load_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.load_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')

# %%
# train L1 model
# train HLT model
history = L1_AE.fit(
    x=datasets['jjJZ1&2&4_train']['L1_data'], 
    y=datasets['jjJZ1&2&4_train']['L1_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['jjJZ1&2&4_train']['weights']
)
# Out:
# Epoch 1/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 1.6019 - val_loss: 1.4144 - learning_rate: 0.0010
# Epoch 2/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4103 - val_loss: 1.4009 - learning_rate: 0.0010
# Epoch 3/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3989 - val_loss: 1.3982 - learning_rate: 0.0010
# Epoch 4/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3982 - val_loss: 1.3939 - learning_rate: 0.0010
# Epoch 5/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3922 - val_loss: 1.3862 - learning_rate: 0.0010
# Epoch 6/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3829 - val_loss: 1.3776 - learning_rate: 0.0010
# Epoch 7/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3735 - val_loss: 1.3690 - learning_rate: 0.0010
# Epoch 8/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3659 - val_loss: 1.3620 - learning_rate: 0.0010

# %%
L1_AE.save_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.save_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')
L1_AE.load_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.load_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')

# %% [markdown]
# ## Model Evaluation

# %%
# Pass the datasets through the model

for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue

    dict['HLT_model_outputs'] = HLT_AE.predict(dict['HLT_data'])
    #dict['HLT_latent_reps'] = HLT_encoder.predict(dict['HLT_data'])
    dict['L1_model_outputs'] = L1_AE.predict(dict['L1_data'])
    #dict['L1_latent_reps'] = L1_encoder.predict(dict['L1_data'])
# Out:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 558us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 568us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 560us/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 558us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 559us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 555us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 540us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 553us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 540us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 539us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 563us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 560us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 587us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 581us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 561us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 551us/step
# 18859/18859 ━━━━━━━━━━━━━━━━━━━━ 11s 580us/step
# 18859/18859 ━━━━━━━━━━━━━━━━━━━━ 11s 579us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 26s 561us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 26s 561us/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 2s 753us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 2s 690us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 1s 547us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 1s 562us/step

# %%
def mse_loss(true, prediction):
    loss = np.mean(np.square(true - prediction), axis=-1)
    return loss

# %%
def MSE_AD_score(y, x):
    # masked mse
    mask = (y != 0) & (y != -999)
    _x = x * mask
    _y = y * mask
    return (mse_loss(y, x))

# %%
# Calculate the AD scores

for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue

    dict['HLT_AD_scores'] = MSE_AD_score(dict['HLT_data'], dict['HLT_model_outputs'])
    dict['L1_AD_scores'] = MSE_AD_score(dict['L1_data'], dict['L1_model_outputs'])

# %%
# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
# HLT_model_outputs: (10000, 60)
# L1_model_outputs: (10000, 60)
# HLT_AD_scores: (10000,)
# L1_AD_scores: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
# HLT_model_outputs: (70000, 60)
# L1_model_outputs: (70000, 60)
# HLT_AD_scores: (70000,)
# L1_AD_scores: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
# HLT_model_outputs: (50000, 60)
# L1_model_outputs: (50000, 60)
# HLT_AD_scores: (50000,)
# L1_AD_scores: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# EB_data:
# HLT_data: (603486, 60)
# L1_data: (603486, 60)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
# HLT_model_outputs: (603486, 60)
# L1_model_outputs: (603486, 60)
# HLT_AD_scores: (603486,)
# L1_AD_scores: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
# HLT_model_outputs: (1501347, 60)
# L1_model_outputs: (1501347, 60)
# HLT_AD_scores: (1501347,)
# L1_AD_scores: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
# HLT_model_outputs: (15255, 60)
# L1_model_outputs: (15255, 60)
# HLT_AD_scores: (15255,)
# L1_AD_scores: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 60)
# L1_data: (150000, 60)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
# HLT_model_outputs: (75000, 60)
# L1_model_outputs: (75000, 60)
# HLT_AD_scores: (75000,)
# L1_AD_scores: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
# HLT_model_outputs: (75000, 60)
# L1_model_outputs: (75000, 60)
# HLT_AD_scores: (75000,)
# L1_AD_scores: (75000,)

# %%
def ROC_curve(dataset, bkg_type, target_rate=10, plot=True):
    """
    Plots ROC curve and returns AUC, TPR, FPR, and thresholds for each dataset.
    
    inputs: 
    dataset: dictionary containing dataset information
    bkg_type: the background type to calculate over
    plot: whether to plot the ROC curve or not
    
    returns:
    results: dictionary {dataset_names: {'TPR': ..., 'AUC': ..., 'FPR': ..., 'threshold': ...}}
    """
    
    bkg_tag = 'jjJZ1&2&4_test1'
    #target_rate = 10  # 10 Hz pure rate
    plt.figure(figsize=(8.5,6.8))
    
    results = {}
    
    for tag in dataset.keys():
        if tag != bkg_tag and tag != 'jjJZ1&2&4_train':
        
            # Combine true labels, anomaly=1 and background=0
            trueVal = np.concatenate((np.ones(dataset[tag][f'{bkg_type}_AD_scores'].shape[0]), np.zeros(dataset[bkg_tag][f'{bkg_type}_AD_scores'].shape[0])))
            
            # Combine predictions from current dataset and background
            predVal_loss = np.concatenate((dataset[tag][f'{bkg_type}_AD_scores'], dataset[bkg_tag][f'{bkg_type}_AD_scores']))
        
            sample_weights = np.concatenate((dataset[tag]['weights'], dataset[bkg_tag]['weights']))
            
            for i in range(len(predVal_loss)):
                if np.isnan(predVal_loss[i]):
                    predVal_loss[i] = 0
           
            # Calculate ROC curve and AUC, including weights
            fpr_loss, tpr_loss, threshold_loss = sklearn.metrics.roc_curve(y_true=trueVal, y_score=predVal_loss, sample_weight=sample_weights)
            auc_loss = auc(fpr_loss, tpr_loss)

            # Initialize variables for early stopping
            min_diff = float('inf')
            best_idx = 0
            previous_diff = float('inf')
            
            # Iterate over thresholds with early stopping
            for idx, value in enumerate(threshold_loss):
                anomaly_idxs_bkg = dataset[bkg_tag][f'{bkg_type}_AD_scores'] > value
                bkg_rate = 100000 * np.sum(dataset[bkg_tag]['weights'] * (anomaly_idxs_bkg & ~dataset[bkg_tag]['passHLT'])) / np.sum(dataset[bkg_tag]['weights'])
                # Calculate the difference from the target rate
                diff = abs(bkg_rate - target_rate)
                
                # Check if the difference is decreasing
                if diff < min_diff:
                    min_diff = diff
                    best_idx = idx
                else:
                    # If the difference starts increasing, break the loop
                    if diff > previous_diff:
                        print(f'Background rate = {bkg_rate:.3}Hz')
                        break
                
                previous_diff = diff
            
            # Use the best index found
            selected_threshold = threshold_loss[best_idx]
            selected_fpr = fpr_loss[best_idx]
            signal_tpr = tpr_loss[best_idx]
            
            # Store the results
            results[tag] = {
                'TPR': signal_tpr,
                'AUC': auc_loss,
                'FPR': selected_fpr,
                'threshold': selected_threshold
            }
        
            # Plot ROC curve
            if plot:
                plt.plot(fpr_loss, tpr_loss, "-", label='%s (AUC = %.1f%%)' % (tag, auc_loss*100.), linewidth=1.5)

    if plot:
        # Set log scale for x and y axis
        plt.semilogx()
        plt.semilogy()
        
        # Plot aesthetics and layout
        plt.plot(np.linspace(0, 1), np.linspace(0, 1), '--', color='0.75')
        plt.plot([selected_fpr, selected_fpr], [0, 1], '--', color='r')
        plt.ylabel("True Positive Rate", fontsize=16)
        plt.xlabel("False Positive Rate", fontsize=16)
        plt.legend(loc='lower right', fontsize=6)
        plt.grid(True)
        plt.tight_layout()
        plt.title(f'Trained over {bkg_type} objects', fontsize=20)
        plt.show()

    return results

# %%
for target_rate in [10, 200, 1000]:
    print(f'TARGET (PURE) RATE::::: {target_rate}')
    HLT_results = ROC_curve(datasets, bkg_type='HLT', target_rate=target_rate)
    L1_results = ROC_curve(datasets, bkg_type='L1', target_rate=target_rate)

    # L1 Signal Efficiencies

    tags = []
    l1_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            L1_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            L1_anomaly_idxs = datasets[tag]['L1_AD_scores'] > L1_results[tag]['threshold']
            L1_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | L1_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            l1_efficiencies.append(L1_TPR)
            combined_efficiencies.append(L1_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, l1_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(l1_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, L1 Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()



    # Signal Efficiencies

    tags = []
    hlt_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            HLT_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_results[tag]['threshold']
            HLT_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | HLT_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            hlt_efficiencies.append(HLT_TPR)
            combined_efficiencies.append(HLT_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, hlt_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(hlt_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, HLT Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()
    
    # HLT overlaps
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = HLT_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['HLT_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")

    # HLT overlaps
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = L1_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")
# Out:
# TARGET (PURE) RATE::::: 10
# Background rate = 12.0Hz
# Background rate = 13.3Hz
# Background rate = 12.0Hz
# Background rate = 13.3Hz
# Background rate = 12.0Hz
# Background rate = 13.3Hz
# Background rate = 13.3Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 13.3Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 22.7Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 21.3Hz
# Background rate = 12.0Hz
# Background rate = 77.3Hz
# Background rate = 12.0Hz
# Normalized by the left bar:
# [1.         1.00104167 1.00039582 1.00176561 1.00021821 1.
#  1.00001836 1.00746965 1.0787037  1.         1.         1.
#  1.00020014]
# Normalized by the left bar:
# [1.         1.0015625  1.00043748 1.00375193 1.00022969 1.
#  1.00005509 1.01027077 1.09722222 1.         1.         1.
#  1.00036024]
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 4e-05
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4
# -----
# A14N23LO:
# HLT overlap: 0.0
# inverse overlap: 1.0002604166666667
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0001
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.8
# inverse overlap: 1.0000624973959418
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.00021428571428571427
# Raw number of events that we tagged as anomalous: 15
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 12
# -----
# qqa:
# HLT overlap: 0.0
# inverse overlap: 1.0002207018318252
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 2e-05
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# ZZ4lep:
# HLT overlap: 0.8888888888888888
# inverse overlap: 1.0000229692327127
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00018
# Raw number of events that we tagged as anomalous: 18
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 16
# -----
# Zprime2EJs:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 1e-05
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# HHbbttHadHad:
# HLT overlap: 0.6666666666666666
# inverse overlap: 1.0000183641238476
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 3e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# jjJZ2:
# HLT overlap: 0.0
# inverse overlap: 1.007469654528478
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 8e-05
# Raw number of events that we tagged as anomalous: 8
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.0
# inverse overlap: 1.0555555555555556
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00012
# Raw number of events that we tagged as anomalous: 12
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_data:
# HLT overlap: 0.00839224744550212
# inverse overlap: 1.0873902165714695
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.0006329890005733356
# Raw number of events that we tagged as anomalous: 382
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 9
# -----
# EB_zerobias:
# HLT overlap: 1.5411203584958755e-05
# inverse overlap: 448.97440418055857
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.00041829104131156885
# Raw number of events that we tagged as anomalous: 628
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0007210750573582432
# Raw number of events that we tagged as anomalous: 11
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 11
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.25
# inverse overlap: 1.0002401633110516
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.00010666666666666667
# Raw number of events that we tagged as anomalous: 8
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 3e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# A14N23LO:
# HLT overlap: 0.0
# inverse overlap: 1.0010416666666666
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0004
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7710843373493976
# inverse overlap: 1.000395816840965
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.0011857142857142858
# Raw number of events that we tagged as anomalous: 83
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 64
# -----
# qqa:
# HLT overlap: 0.0
# inverse overlap: 1.0017656146546017
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00016
# Raw number of events that we tagged as anomalous: 8
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# ZZ4lep:
# HLT overlap: 0.8429752066115702
# inverse overlap: 1.0002182077107715
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00121
# Raw number of events that we tagged as anomalous: 121
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 102
# -----
# Zprime2EJs:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 2e-05
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# HHbbttHadHad:
# HLT overlap: 0.75
# inverse overlap: 1.0000183641238476
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 4e-05
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ2:
# HLT overlap: 0.0
# inverse overlap: 1.007469654528478
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 8e-05
# Raw number of events that we tagged as anomalous: 8
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.05555555555555555
# inverse overlap: 1.0787037037037037
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00018
# Raw number of events that we tagged as anomalous: 18
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_data:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_zerobias:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_passHLT:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.0
# inverse overlap: 1.000200136092543
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 6.666666666666667e-05
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# TARGET (PURE) RATE::::: 200
# /tmp/ipykernel_543738/3559298588.py:155: RuntimeWarning: invalid value encountered in scalar divide
#   HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
# Background rate = 2.01e+02Hz
# Background rate = 2.07e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.05e+02Hz
# Background rate = 2.07e+02Hz
# Background rate = 2.07e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.03e+02Hz
# Normalized by the left bar:
# [1.00002036 1.0203125  1.00606225 1.03906422 1.00213614 1.00004541
#  1.00075293 1.23529412 2.49537037 1.00220643 6.44961405 1.
#  1.00572389]
# Normalized by the left bar:
# [ 1.0000509   1.04427083  1.01231199  1.0957846   1.00421485  1.00009082
#   1.00244243  1.52661064  4.34722222  1.00654356 13.39485479  1.
#   1.01392947]
# -----
# jjJZ4:
# HLT overlap: 0.9699248120300752
# inverse overlap: 1.000040723659428
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00133
# Raw number of events that we tagged as anomalous: 133
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 129
# -----
# A14N23LO:
# HLT overlap: 0.3225806451612903
# inverse overlap: 1.00546875
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0031
# Raw number of events that we tagged as anomalous: 31
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 10
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7669172932330827
# inverse overlap: 1.0012916128494647
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.0038
# Raw number of events that we tagged as anomalous: 266
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 204
# -----
# qqa:
# HLT overlap: 0.08771929824561403
# inverse overlap: 1.0114764952549107
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00114
# Raw number of events that we tagged as anomalous: 57
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# ZZ4lep:
# HLT overlap: 0.8942065491183879
# inverse overlap: 1.0004823538869685
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00397
# Raw number of events that we tagged as anomalous: 397
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 355
# -----
# Zprime2EJs:
# HLT overlap: 0.8666666666666667
# inverse overlap: 1.0000227045681591
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00015
# Raw number of events that we tagged as anomalous: 15
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 13
# -----
# HHbbttHadHad:
# HLT overlap: 0.3870967741935484
# inverse overlap: 1.001046755059316
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00093
# Raw number of events that we tagged as anomalous: 93
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 36
# -----
# jjJZ2:
# HLT overlap: 0.015625
# inverse overlap: 1.2352941176470589
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00256
# Raw number of events that we tagged as anomalous: 256
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4
# -----
# jjJZ1:
# HLT overlap: 0.006389776357827476
# inverse overlap: 2.439814814814815
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00313
# Raw number of events that we tagged as anomalous: 313
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# EB_data:
# HLT overlap: 0.013618757845674578
# inverse overlap: 1.9309716265103376
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.01038466509579344
# Raw number of events that we tagged as anomalous: 6267
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 164
# -----
# EB_zerobias:
# HLT overlap: 7.491273666308973e-06
# inverse overlap: 6893.217707166806
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.006797229421312994
# Raw number of events that we tagged as anomalous: 10205
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 15
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.011733857751556867
# Raw number of events that we tagged as anomalous: 179
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 179
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.1902439024390244
# inverse overlap: 1.0066445182724253
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.0027333333333333333
# Raw number of events that we tagged as anomalous: 205
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 39
# -----
# jjJZ4:
# HLT overlap: 0.979381443298969
# inverse overlap: 1.000020361829714
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00097
# Raw number of events that we tagged as anomalous: 97
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 95
# -----
# A14N23LO:
# HLT overlap: 0.36065573770491804
# inverse overlap: 1.0203125
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0122
# Raw number of events that we tagged as anomalous: 122
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 44
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7347310847766636
# inverse overlap: 1.006062247406358
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.015671428571428572
# Raw number of events that we tagged as anomalous: 1097
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 806
# -----
# qqa:
# HLT overlap: 0.078125
# inverse overlap: 1.0390642242330612
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00384
# Raw number of events that we tagged as anomalous: 192
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 15
# -----
# ZZ4lep:
# HLT overlap: 0.8673323823109843
# inverse overlap: 1.0021361386422887
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.01402
# Raw number of events that we tagged as anomalous: 1402
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1216
# -----
# Zprime2EJs:
# HLT overlap: 0.9285714285714286
# inverse overlap: 1.0000454091363182
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00056
# Raw number of events that we tagged as anomalous: 56
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 52
# -----
# HHbbttHadHad:
# HLT overlap: 0.49382716049382713
# inverse overlap: 1.0007529290777537
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00081
# Raw number of events that we tagged as anomalous: 81
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 40
# -----
# jjJZ2:
# HLT overlap: 0.011764705882352941
# inverse overlap: 1.2352941176470589
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00255
# Raw number of events that we tagged as anomalous: 255
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ1:
# HLT overlap: 0.009202453987730062
# inverse overlap: 2.4953703703703702
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00326
# Raw number of events that we tagged as anomalous: 326
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# EB_data:
# HLT overlap: 0.09868048576457904
# inverse overlap: 1.002206430678072
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 4.971117805549756e-05
# Raw number of events that we tagged as anomalous: 30
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# EB_zerobias:
# HLT overlap: 0.0012545894800475347
# inverse overlap: 6.449614050646656
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 2.8640947096174304e-05
# Raw number of events that we tagged as anomalous: 43
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.00032776138970829236
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.13855421686746988
# inverse overlap: 1.0057238922467278
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.002213333333333333
# Raw number of events that we tagged as anomalous: 166
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 23
# TARGET (PURE) RATE::::: 1000
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.02e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Normalized by the left bar:
# [ 1.00020362  1.09192708  1.02576976  1.24519974  1.00816556  1.00027245
#   1.00642744  2.31746032  8.61574074  1.02554883 29.6376472   1.
#   1.03198175]
# Normalized by the left bar:
# [ 1.00044796  1.15859375  1.04376901  1.48421982  1.01397678  1.00079466
#   1.01500349  3.74509804 15.62037037  1.06832169 70.81726157  1.
#   1.06180203]
# -----
# jjJZ4:
# HLT overlap: 0.981838819523269
# inverse overlap: 1.0001628946377121
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00881
# Raw number of events that we tagged as anomalous: 881
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 865
# -----
# A14N23LO:
# HLT overlap: 0.4782608695652174
# inverse overlap: 1.01875
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0138
# Raw number of events that we tagged as anomalous: 138
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 66
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7423146473779385
# inverse overlap: 1.0059372526144743
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.0158
# Raw number of events that we tagged as anomalous: 1106
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 821
# -----
# qqa:
# HLT overlap: 0.1345707656612529
# inverse overlap: 1.0823217832708012
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00862
# Raw number of events that we tagged as anomalous: 431
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 58
# -----
# ZZ4lep:
# HLT overlap: 0.8888888888888888
# inverse overlap: 1.0023084078876345
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.01809
# Raw number of events that we tagged as anomalous: 1809
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1608
# -----
# Zprime2EJs:
# HLT overlap: 0.8270676691729323
# inverse overlap: 1.0002611025338297
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00133
# Raw number of events that we tagged as anomalous: 133
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 110
# -----
# HHbbttHadHad:
# HLT overlap: 0.5032010243277849
# inverse overlap: 1.0071252800528887
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00781
# Raw number of events that we tagged as anomalous: 781
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 393
# -----
# jjJZ2:
# HLT overlap: 0.01430615164520744
# inverse overlap: 2.2866479925303453
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.01398
# Raw number of events that we tagged as anomalous: 1398
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 20
# -----
# jjJZ1:
# HLT overlap: 0.005242463958060288
# inverse overlap: 8.027777777777779
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.01526
# Raw number of events that we tagged as anomalous: 1526
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 8
# -----
# EB_data:
# HLT overlap: 0.01285645350371911
# inverse overlap: 4.457254741614508
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.04140941132022947
# Raw number of events that we tagged as anomalous: 24990
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 591
# -----
# EB_zerobias:
# HLT overlap: 7.231059397621121e-06
# inverse overlap: 22759.84733346599
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.02398646015877742
# Raw number of events that we tagged as anomalous: 36012
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 48
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.04188790560471976
# Raw number of events that we tagged as anomalous: 639
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 639
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.24370594159113795
# inverse overlap: 1.0300604410999479
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.01324
# Raw number of events that we tagged as anomalous: 993
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 242
# -----
# jjJZ4:
# HLT overlap: 0.9703703703703703
# inverse overlap: 1.00020361829714
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00675
# Raw number of events that we tagged as anomalous: 675
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 655
# -----
# A14N23LO:
# HLT overlap: 0.33646616541353386
# inverse overlap: 1.0919270833333334
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0532
# Raw number of events that we tagged as anomalous: 532
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 179
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7004842615012107
# inverse overlap: 1.0257697595933504
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.059
# Raw number of events that we tagged as anomalous: 4130
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2893
# -----
# qqa:
# HLT overlap: 0.09967585089141005
# inverse overlap: 1.245199735157802
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.02468
# Raw number of events that we tagged as anomalous: 1234
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 123
# -----
# ZZ4lep:
# HLT overlap: 0.8660764739122245
# inverse overlap: 1.0081655622293937
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.05309
# Raw number of events that we tagged as anomalous: 5309
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4598
# -----
# Zprime2EJs:
# HLT overlap: 0.9294117647058824
# inverse overlap: 1.0002724548179094
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.0034
# Raw number of events that we tagged as anomalous: 340
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 316
# -----
# HHbbttHadHad:
# HLT overlap: 0.46236559139784944
# inverse overlap: 1.006427443346678
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00651
# Raw number of events that we tagged as anomalous: 651
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 301
# -----
# jjJZ2:
# HLT overlap: 0.014664804469273743
# inverse overlap: 2.3174603174603177
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.01432
# Raw number of events that we tagged as anomalous: 1432
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 21
# -----
# jjJZ1:
# HLT overlap: 0.008438818565400843
# inverse overlap: 8.61574074074074
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.01659
# Raw number of events that we tagged as anomalous: 1659
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 14
# -----
# EB_data:
# HLT overlap: 0.05132351905319817
# inverse overlap: 1.0255488310900933
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.00034300712858293314
# Raw number of events that we tagged as anomalous: 207
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 17
# -----
# EB_zerobias:
# HLT overlap: 0.0008380382312737168
# inverse overlap: 29.637647197505302
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.00019915449259897945
# Raw number of events that we tagged as anomalous: 299
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 7
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0015732546705998034
# Raw number of events that we tagged as anomalous: 24
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 24
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.17628865979381445
# inverse overlap: 1.0319817475883601
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.012933333333333333
# Raw number of events that we tagged as anomalous: 970
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 171

# %%
#HLT
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
#HLT
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
#HLT
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n] > 1) and (HLT_electron_mults[tag][n] > 1) and (HLT_muon_mults[tag][n] > 1) and (HLT_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    ax1.hist(HLT_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1

plt.xticks(np.arange(0, 2000,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
#L1
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n] > 1) and (L1_electron_mults[tag][n] > 1) and (L1_muon_mults[tag][n] > 1) and (L1_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    ax1.hist(L1_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1
plt.xlim(0, 800)
plt.xticks(np.arange(0, 800,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
import ROOT
# Out:
# C system headers (glibc/Xcode/Windows SDK) must be installed.
# In file included from input_line_4:36:
# /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/include/c++/cassert:44:10: fatal error: 'assert.h' file not found
# #include <assert.h>
#          ^~~~~~~~~~
# input_line_35:1:10: fatal error: 'dlfcn.h' file not found
# #include "dlfcn.h"
#          ^~~~~~~~~

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "HLT" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/Root/HLT', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ4max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTA14N23LOmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTHAHMggfZdZd2l2numax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTqqamax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTZZ4lepmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTZprime2EJsmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTHHbbttHadHadmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ2max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_datamax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_zerobiasmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_passHLTmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1&2&4_test1max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1&2&4_test2max pt v ad score  _plot.png has been created

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "L1" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ4max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ4max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1A14N23LOmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1A14N23LOmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2numax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2numax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1qqamax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1qqamax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1ZZ4lepmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1ZZ4lepmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1Zprime2EJsmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1Zprime2EJsmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HHbbttHadHadmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HHbbttHadHadmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ2max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ2max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datamax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datamax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_zerobiasmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_zerobiasmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_passHLTmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_passHLTmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2max pt v ad score  _plot.png

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "HLT" + tag + "jet mult v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_jet_mults[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ4jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ4jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTA14N23LOjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTA14N23LOjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTHAHMggfZdZd2l2nujet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTHAHMggfZdZd2l2nujet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTqqajet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTqqajet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTZZ4lepjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTZZ4lepjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTZprime2EJsjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTZprime2EJsjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTHHbbttHadHadjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTHHbbttHadHadjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ2jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ2jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_datajet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_datajet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_zerobiasjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_zerobiasjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_passHLTjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_passHLTjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test1jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test1jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test2jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test2jet mult v ad score  _plot.png

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "L1" + tag + "jet mult v ad score "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(L1_jet_mults[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ4jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ4jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1A14N23LOjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1A14N23LOjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2nujet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2nujet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1qqajet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1qqajet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1ZZ4lepjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1ZZ4lepjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1Zprime2EJsjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1Zprime2EJsjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HHbbttHadHadjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HHbbttHadHadjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ2jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ2jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datajet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datajet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_zerobiasjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_zerobiasjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_passHLTjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_passHLTjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2jet mult v ad score _plot.png

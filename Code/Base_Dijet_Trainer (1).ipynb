# %%
##Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import random
import sklearn
import collections
from sklearn.model_selection import train_test_split
import json
import pylab
from scipy.optimize import curve_fit
from tensorflow.keras import layers, Model
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, auc
import matplotlib
import matplotlib.patches as mpatches
#import shap
import os
import pandas as pd
#improve gpu memory usage
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 2024-10-05 00:11:45.784039: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-05 00:11:46.786407: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Set matplotlib default color cycle
new_color_cycle = [
#jjJZ4
    '#4f2ca8',
#A14N23LO
    '#b45f06',
#HAHMggf
    '#ff0000',
#qqa
    '#d4d400',
#ZZ4lep
    '#294a18',
#Zprime2EJs
    '#00de00',
#HHbbttHadHad
    '#5b0f00',
#jjJZ2
  '#ca7dff',
#jjJZ1
  '#d201d2',
#data
 '#3232ff', 
#zerobias
    '#002a75',
#passedHLT
    '#00cdcd',
#jjJZ124
#    '#8e1d55',
#test 2
    '#7f7f7f'
]

# You can then apply this new color cycle to your matplotlib plots
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=new_color_cycle)

# %%
##Read Data Files

# %%
# This is the list that will hold all of the data 
datasets = {}

# %%
# Read Monte Carlo Simulated Collisions

data_path = '/home/jovyan/MC_data/'

for filename in os.listdir(data_path):

    if filename.startswith('N') or filename.startswith('.'): continue

    dataset_tag = filename.split('_')[0]
    
    with h5py.File(data_path+filename, 'r') as hf:
        HLT_jets = hf['HLT_jets'][:]
        L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
        L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
        HLT_electrons = hf['HLT_electrons'][:]
        LRT_electrons = hf['LRT_electrons'][:]
        L1_egammas = hf['L1_egammas'][:]
        HLT_muons = hf['HLT_muons'][:]
        LRT_muons = hf['LRT_muons'][:]
        L1_muons = hf['L1_muons'][:]
        L1_eFex_taus = hf['L1_eFex_taus'][:]
        L1_jFex_taus = hf['L1_jFex_taus'][:]
        HLT_photons = hf['HLT_photons'][:]
        HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 4)  # Broadcasting MET
        L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
        pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
        pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]

        HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, [0, 2, 3]], HLT_muons[:, :3, [0, 2, 3]], HLT_photons[:, :3, [0, 2, 3]], HLT_MET[:, :, [0, 2, 3]]], axis=1)
        L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)
        
        datasets[dataset_tag] = {
            'HLT_data': HLT_objects,
            'L1_data': L1_objects,
            'passL1': pass_L1_unprescaled==1,
            'passHLT': pass_HLT_unprescaled==1,
            'weights': np.ones(len(HLT_objects)),
        }

        if len(HLT_objects) > 100000:
            datasets[dataset_tag] = {key: value[:100000] for key, value in datasets[dataset_tag].items()}

# %%
# Read 2024 EB data

with h5py.File('/home/jovyan/EB_data/EB_ntuples_08-13-2024-003.h5', 'r') as hf:
    HLT_jets = hf['HLT_jets'][:]
    ofl_jets = hf['ofl_jets'][:]
    L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
    L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
    HLT_electrons = hf['HLT_electrons'][:]
    LRT_electrons = hf['LRT_electrons'][:]
    ofl_electrons = hf['ofl_electrons'][:]
    L1_egammas = hf['L1_egammas'][:]
    HLT_muons = hf['HLT_muons'][:]
    LRT_muons = hf['LRT_muons'][:]
    ofl_muons = hf['ofl_muons'][:]
    L1_muons = hf['L1_muons'][:]
    L1_eFex_taus = hf['L1_eFex_taus'][:]
    L1_jFex_taus = hf['L1_jFex_taus'][:]
    HLT_photons = hf['HLT_photons'][:]
    ofl_photons = hf['ofl_photons'][:]
    HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 3)  # Broadcasting MET
    L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
    pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
    pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]
    EB_weights = hf["EB_weights"][:]
    event_number = hf["event_number"][:]
    run_number = hf["run_number"][:]

HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, :], HLT_muons[:, :3, :], HLT_photons[:, :3, :], HLT_MET], axis=1)
L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)



# Indices of events that passed L1
pass_L1_idxs = (pass_L1_unprescaled == 1)

# Indices of events that passed HLT
pass_HLT_idxs = (pass_HLT_unprescaled == 1)



datasets['EB_data'] = {
    'HLT_data': HLT_objects[pass_L1_idxs] ,
    'L1_data': L1_objects[pass_L1_idxs] ,
    'passL1': pass_L1_idxs[pass_L1_idxs],
    'passHLT': pass_HLT_idxs[pass_L1_idxs],
    'weights': EB_weights[pass_L1_idxs],
}

datasets['EB_zerobias'] = {
    'HLT_data': HLT_objects[~pass_L1_idxs] ,
    'L1_data': L1_objects[~pass_L1_idxs] ,
    'passL1': pass_L1_idxs[~pass_L1_idxs],
    'passHLT': pass_HLT_idxs[~pass_L1_idxs],
    'weights': EB_weights[~pass_L1_idxs],
}

datasets['EB_passHLT'] = {
    'HLT_data': HLT_objects[pass_HLT_idxs] ,
    'L1_data': L1_objects[pass_HLT_idxs] ,
    'passL1': pass_L1_idxs[pass_HLT_idxs],
    'passHLT': pass_HLT_idxs[pass_HLT_idxs],
    'weights': EB_weights[pass_HLT_idxs],
}

# %%
#Data Preprocessing

# %%
#create combo of jjJZ4 & jjJZ2 & jjJZ1

datasets['jjJZ1&2&4'] = {
    'HLT_data': np.concatenate((datasets['jjJZ1']['HLT_data'],datasets['jjJZ2']['HLT_data'],datasets['jjJZ4']['HLT_data'])),
    'L1_data': np.concatenate((datasets['jjJZ1']['L1_data'],datasets['jjJZ2']['L1_data'],datasets['jjJZ4']['L1_data'])) ,
    'passL1': np.concatenate((datasets['jjJZ1']['passL1'],datasets['jjJZ2']['passL1'],datasets['jjJZ4']['passL1'])),
    'passHLT': np.concatenate((datasets['jjJZ1']['passHLT'],datasets['jjJZ2']['passHLT'],datasets['jjJZ4']['passHLT'])),
    'weights': np.concatenate((datasets['jjJZ1']['weights'],datasets['jjJZ2']['weights'],datasets['jjJZ4']['weights'])),
}

# %%
"""Multiply the pt of the L1 muons by 1000 to get them into the right units."""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label == 'L1_data':
            data[:, 13:16, 0] *= 1000

# %%
# Split EB data in train, test

random_seed = 789247

indices = np.arange(len(datasets['jjJZ1&2&4']['HLT_data']))
train_indices, _indices = train_test_split(indices, train_size=0.5, random_state=random_seed)
test1_indices, test2_indices = train_test_split(_indices, train_size=0.5, random_state=random_seed)

datasets['jjJZ1&2&4_train'] = {key:value[train_indices] for key, value in datasets['jjJZ1&2&4'].items()}
datasets['jjJZ1&2&4_test1'] = {key:value[test1_indices] for key, value in datasets['jjJZ1&2&4'].items()}
datasets['jjJZ1&2&4_test2'] = {key:value[test2_indices] for key, value in datasets['jjJZ1&2&4'].items()}

del datasets['jjJZ1&2&4']

# %%
#save pt values before normalization for 2d histogram of max pt vs. anomaly score & efficiency plots
HLT_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['HLT_data'][i,j,0]:
                temp[i] = datasets[tag]['HLT_data'][i,j,0]
    HLT_max_pt_vals[tag] = temp
L1_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['L1_data'][i,j,0]:
                temp[i] = datasets[tag]['L1_data'][i,j,0]
    L1_max_pt_vals[tag] = temp
HLT_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_jet_mults[tag] = temp
L1_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_jet_mults[tag] = temp
HLT_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10,13):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_electron_mults[tag] = temp
L1_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10,13):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_electron_mults[tag] = temp
HLT_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(13,16):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_muon_mults[tag] = temp
L1_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(13,16):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_muon_mults[tag] = temp
HLT_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(16,19):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_photon_mults[tag] = temp
L1_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(16,19):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_photon_mults[tag] = temp

# %%
for tag, dict in datasets.items():
    print(f'\n{tag}:')
    for key, value in dict.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 20, 3)
# L1_data: (10000, 20, 3)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 20, 3)
# L1_data: (70000, 20, 3)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 20, 3)
# L1_data: (50000, 20, 3)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_data:
# HLT_data: (603486, 20, 3)
# L1_data: (603486, 20, 3)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 20, 3)
# L1_data: (1501347, 20, 3)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 20, 3)
# L1_data: (15255, 20, 3)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 20, 3)
# L1_data: (150000, 20, 3)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 20, 3)
# L1_data: (75000, 20, 3)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 20, 3)
# L1_data: (75000, 20, 3)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)

# %%
"""Met bias. For some events, MET was not calculated, so was written as -999.
We don't want this to impact training, so we map 0 --> 0.001 and -999 --> 0"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):

            # MET: 0 --> 0.001 and -999 --> 0 and nan --> 0
            MET_zeros = (data[:, 19, 0] == 0) # indices where MET=0
            MET_999 = ((data[:, 19, 0] == -999)) # indices where MET=-999 (not calculated)
            MET_nan = np.isnan(data[:, 19, 2])
            data[MET_zeros, 19, 0] = 0.001
            data[MET_999, 19, :] = 0
            data[MET_nan, 19, :] = 0

# %%
"""Normalize pt such that sum(pt) = 1 in each event"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
#             # sum of the pt and E in each event
            sum_pt = np.sum(data[:, :, 0], axis=1, keepdims=True)
        
#             # If the sum is 0, set the sum to 1 to avoid division by 0
            sum_pt[sum_pt == 0] = 1
        
#             # Divide pt and E by their respective sums, multiply by 10
            data[:, :, 0] *= (1/sum_pt)

# %%
##Autoencoder Architecture

# %%
# Flatten ndarrays for use in DNN

for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
            datasets[tag][label] = np.reshape(data, newshape=(-1, 60))

# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_data:
# HLT_data: (603486, 60)
# L1_data: (603486, 60)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 60)
# L1_data: (150000, 60)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)

# %%
def create_AE(input_dim, h_dim_1, h_dim_2, latent_dim):
    
     # Encoder
    encoder_inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(h_dim_1, activation='relu')(encoder_inputs)
    x = layers.Dense(h_dim_2, activation='relu')(x)
    z = layers.Dense(latent_dim, activation='relu')(x)
    
    encoder = Model(inputs=encoder_inputs, outputs=z)

    # Decoder
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(h_dim_2, activation='relu')(decoder_inputs)
    x = layers.Dense(h_dim_1, activation='relu')(x)
    outputs = layers.Dense(input_dim)(x)

    decoder = Model(inputs=decoder_inputs, outputs=outputs)

    ae_outputs = decoder(encoder(encoder_inputs))
    ae = Model(encoder_inputs, outputs=ae_outputs)
    return ae, encoder, decoder

# %%
def loss_fn(y_true, y_pred):
    """masked mse"""
    # mask0 = K.cast(K.not_equal(y_true, 0), K.floatx())
    # maskMET = K.cast(K.not_equal(y_true, -999), K.floatx())
    # mask = mask0 * maskMET
    # squared_difference = K.square(mask * (y_pred - y_true))
    squared_difference = K.square((y_pred - y_true))
    return K.mean(squared_difference)

# %%
# Initialize models
INPUT_DIM = datasets['jjJZ1&2&4_train']['HLT_data'].shape[1]
H_DIM_1 = 32
H_DIM_2 = 8
LATENT_DIM = 2

HLT_AE, HLT_encoder, HLT_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)
L1_AE, L1_encoder, L1_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)

HLT_AE.summary()
L1_AE.summary()
# Out:
# 2024-10-05 00:17:25.967701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20732 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_3 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_7 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_9 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# Define callbacks: early stopping and learning rate scheduler

STOP_PATIENCE = 8
LR_PATIENCE = 4

early_stopping = EarlyStopping(patience=STOP_PATIENCE, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=LR_PATIENCE, verbose=1)

callbacks = [early_stopping, reduce_lr]

# %%
NUM_EPOCHS = 150
BATCH_SIZE = 512

# %%
#Model Training

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# train HLT model
history = HLT_AE.fit(
    x=datasets['jjJZ1&2&4_train']['HLT_data'], 
    y=datasets['jjJZ1&2&4_train']['HLT_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['jjJZ1&2&4_train']['weights']
)
# Out:
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728087448.343349     575 service.cc:145] XLA service 0x7f9e7800b840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728087448.343394     575 service.cc:153]   StreamExecutor device (0): NVIDIA A10, Compute Capability 8.6
# 2024-10-05 00:17:28.371396: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-05 00:17:28.615357: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728087449.306130     746 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_504', 8 bytes spill stores, 8 bytes spill loads
#
# I0000 00:00:1728087449.400239     763 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_504', 12 bytes spill stores, 12 bytes spill loads
# 180/250 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 1.4260
# I0000 00:00:1728087451.037481     575 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 1.4043 - val_loss: 1.2560 - learning_rate: 0.0010
# Epoch 2/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2534 - val_loss: 1.2427 - learning_rate: 0.0010
# Epoch 3/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2438 - val_loss: 1.2345 - learning_rate: 0.0010
# Epoch 4/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2350 - val_loss: 1.2266 - learning_rate: 0.0010
# Epoch 5/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2266 - val_loss: 1.2180 - learning_rate: 0.0010
# Epoch 6/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2188 - val_loss: 1.2104 - learning_rate: 0.0010
# Epoch 7/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2139 - val_loss: 1.2041 - learning_rate: 0.0010
# Epoch 8/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2053 - val_loss: 1.1985 - learning_rate: 0.0010
# Epoch 9/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2004 - val_loss: 1.1933 - learning_rate: 0.0010
# Epoch 10/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1941 - val_loss: 1.1900 - learning_rate: 0.0010
# Epoch 11/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1901 - val_loss: 1.1857 - learning_rate: 0.0010
# Epoch 12/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1860 - val_loss: 1.1824 - learning_rate: 0.0010
# Epoch 13/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1828 - val_loss: 1.1798 - learning_rate: 0.0010
# Epoch 14/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1797 - val_loss: 1.1771 - learning_rate: 0.0010
# Epoch 15/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1772 - val_loss: 1.1752 - learning_rate: 0.0010
# Epoch 16/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1749 - val_loss: 1.1732 - learning_rate: 0.0010
# Epoch 17/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1719 - val_loss: 1.1716 - learning_rate: 0.0010
# Epoch 18/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1713 - val_loss: 1.1690 - learning_rate: 0.0010
# Epoch 19/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1699 - val_loss: 1.1685 - learning_rate: 0.0010
# Epoch 20/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1709 - val_loss: 1.1665 - learning_rate: 0.0010
# Epoch 21/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1702 - val_loss: 1.1650 - learning_rate: 0.0010
# Epoch 22/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1668 - val_loss: 1.1634 - learning_rate: 0.0010
# Epoch 23/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1652 - val_loss: 1.1619 - learning_rate: 0.0010
# Epoch 24/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1629 - val_loss: 1.1614 - learning_rate: 0.0010
# Epoch 25/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1609 - val_loss: 1.1604 - learning_rate: 0.0010
# Epoch 26/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1624 - val_loss: 1.1591 - learning_rate: 0.0010
# Epoch 27/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1614 - val_loss: 1.1576 - learning_rate: 0.0010
# Epoch 28/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1585 - val_loss: 1.1571 - learning_rate: 0.0010
# Epoch 29/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1561 - val_loss: 1.1563 - learning_rate: 0.0010
# Epoch 30/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1579 - val_loss: 1.1552 - learning_rate: 0.0010
# Epoch 31/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1568 - val_loss: 1.1541 - learning_rate: 0.0010
# Epoch 32/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1571 - val_loss: 1.1532 - learning_rate: 0.0010
# Epoch 33/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1553 - val_loss: 1.1523 - learning_rate: 0.0010
# Epoch 34/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1532 - val_loss: 1.1511 - learning_rate: 0.0010
# Epoch 35/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1541 - val_loss: 1.1502 - learning_rate: 0.0010
# Epoch 36/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1509 - val_loss: 1.1499 - learning_rate: 0.0010
# Epoch 37/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1523 - val_loss: 1.1489 - learning_rate: 0.0010
# Epoch 38/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1494 - val_loss: 1.1478 - learning_rate: 0.0010
# Epoch 39/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1489 - val_loss: 1.1465 - learning_rate: 0.0010
# Epoch 40/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1483 - val_loss: 1.1455 - learning_rate: 0.0010
# Epoch 41/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1461 - val_loss: 1.1435 - learning_rate: 0.0010
# Epoch 42/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1417 - val_loss: 1.1424 - learning_rate: 0.0010
# Epoch 43/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1437 - val_loss: 1.1417 - learning_rate: 0.0010
# Epoch 44/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1432 - val_loss: 1.1417 - learning_rate: 0.0010
# Epoch 45/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1415 - val_loss: 1.1385 - learning_rate: 0.0010
# Epoch 46/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1389 - val_loss: 1.1381 - learning_rate: 0.0010
# Epoch 47/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1356 - val_loss: 1.1349 - learning_rate: 0.0010
# Epoch 48/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1389 - val_loss: 1.1332 - learning_rate: 0.0010
# Epoch 49/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1358 - val_loss: 1.1327 - learning_rate: 0.0010
# Epoch 50/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1347 - val_loss: 1.1321 - learning_rate: 0.0010
# Epoch 51/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1322 - val_loss: 1.1298 - learning_rate: 0.0010
# Epoch 52/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1323 - val_loss: 1.1286 - learning_rate: 0.0010
# Epoch 53/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1297 - val_loss: 1.1261 - learning_rate: 0.0010
# Epoch 54/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1318 - val_loss: 1.1256 - learning_rate: 0.0010
# Epoch 55/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1265 - val_loss: 1.1245 - learning_rate: 0.0010
# Epoch 56/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1219 - val_loss: 1.1240 - learning_rate: 0.0010
# Epoch 57/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1259 - val_loss: 1.1238 - learning_rate: 0.0010
# Epoch 58/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1253 - val_loss: 1.1221 - learning_rate: 0.0010
# Epoch 59/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1217 - val_loss: 1.1213 - learning_rate: 0.0010
# Epoch 60/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1219 - val_loss: 1.1199 - learning_rate: 0.0010
# Epoch 61/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1241 - val_loss: 1.1191 - learning_rate: 0.0010
# Epoch 62/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1221 - val_loss: 1.1171 - learning_rate: 0.0010
# Epoch 63/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1168 - val_loss: 1.1169 - learning_rate: 0.0010
# Epoch 64/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1165 - val_loss: 1.1175 - learning_rate: 0.0010
# Epoch 65/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1157 - val_loss: 1.1167 - learning_rate: 0.0010
# Epoch 66/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1170 - val_loss: 1.1156 - learning_rate: 0.0010
# Epoch 67/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1185 - val_loss: 1.1137 - learning_rate: 0.0010
# Epoch 68/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1168 - val_loss: 1.1132 - learning_rate: 0.0010
# Epoch 69/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1168 - val_loss: 1.1156 - learning_rate: 0.0010
# Epoch 70/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1136 - val_loss: 1.1115 - learning_rate: 0.0010
# Epoch 71/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1151 - val_loss: 1.1126 - learning_rate: 0.0010
# Epoch 72/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1155 - val_loss: 1.1108 - learning_rate: 0.0010
# Epoch 73/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1113 - val_loss: 1.1101 - learning_rate: 0.0010
# Epoch 74/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1098 - val_loss: 1.1093 - learning_rate: 0.0010
# Epoch 75/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1098 - val_loss: 1.1072 - learning_rate: 0.0010
# Epoch 76/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1103 - val_loss: 1.1063 - learning_rate: 0.0010
# Epoch 77/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1089 - val_loss: 1.1067 - learning_rate: 0.0010
# Epoch 78/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1093 - val_loss: 1.1072 - learning_rate: 0.0010
# Epoch 79/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1097 - val_loss: 1.1052 - learning_rate: 0.0010
# Epoch 80/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1068 - val_loss: 1.1051 - learning_rate: 0.0010
# Epoch 81/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1085 - val_loss: 1.1038 - learning_rate: 0.0010
# Epoch 82/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1058 - val_loss: 1.1031 - learning_rate: 0.0010
# Epoch 83/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1052 - val_loss: 1.1031 - learning_rate: 0.0010
# Epoch 84/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1024 - val_loss: 1.1039 - learning_rate: 0.0010
# Epoch 85/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1053 - val_loss: 1.1039 - learning_rate: 0.0010
# Epoch 86/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1060 - val_loss: 1.1011 - learning_rate: 0.0010
# Epoch 87/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1033 - val_loss: 1.1009 - learning_rate: 0.0010
# Epoch 88/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1012 - val_loss: 1.1011 - learning_rate: 0.0010
# Epoch 89/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0998 - val_loss: 1.0991 - learning_rate: 0.0010
# Epoch 90/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1035 - val_loss: 1.0995 - learning_rate: 0.0010
# Epoch 91/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0979 - val_loss: 1.0990 - learning_rate: 0.0010
# Epoch 92/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1026 - val_loss: 1.0976 - learning_rate: 0.0010
# Epoch 93/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1015 - val_loss: 1.0987 - learning_rate: 0.0010
# Epoch 94/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0996 - val_loss: 1.1024 - learning_rate: 0.0010
# Epoch 95/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1003 - val_loss: 1.0956 - learning_rate: 0.0010
# Epoch 96/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0966 - val_loss: 1.0965 - learning_rate: 0.0010
# Epoch 97/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0971 - val_loss: 1.1025 - learning_rate: 0.0010
# Epoch 98/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0968 - val_loss: 1.0951 - learning_rate: 0.0010
# Epoch 99/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0955 - val_loss: 1.1001 - learning_rate: 0.0010
# Epoch 100/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0949 - val_loss: 1.0936 - learning_rate: 0.0010
# Epoch 101/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0977 - val_loss: 1.0957 - learning_rate: 0.0010
# Epoch 102/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0934 - val_loss: 1.0912 - learning_rate: 0.0010
# Epoch 103/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0937 - val_loss: 1.0906 - learning_rate: 0.0010
# Epoch 104/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0932 - val_loss: 1.0933 - learning_rate: 0.0010
# Epoch 105/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0943 - val_loss: 1.0930 - learning_rate: 0.0010
# Epoch 106/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0917 - val_loss: 1.0940 - learning_rate: 0.0010
# Epoch 107/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0947 - val_loss: 1.0905 - learning_rate: 0.0010
# Epoch 108/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0902 - val_loss: 1.0915 - learning_rate: 0.0010
# Epoch 109/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0935 - val_loss: 1.0917 - learning_rate: 0.0010
# Epoch 110/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0921 - val_loss: 1.0879 - learning_rate: 0.0010
# Epoch 111/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0931 - val_loss: 1.0911 - learning_rate: 0.0010
# Epoch 112/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0941 - val_loss: 1.0885 - learning_rate: 0.0010
# Epoch 113/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0911 - val_loss: 1.0900 - learning_rate: 0.0010
# Epoch 114/150
# 237/250 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 1.0912
# Epoch 114: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0912 - val_loss: 1.0905 - learning_rate: 0.0010
# Epoch 115/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0919 - val_loss: 1.0864 - learning_rate: 1.0000e-04
# Epoch 116/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0877 - val_loss: 1.0855 - learning_rate: 1.0000e-04
# Epoch 117/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0862 - val_loss: 1.0853 - learning_rate: 1.0000e-04
# Epoch 118/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0859 - val_loss: 1.0858 - learning_rate: 1.0000e-04
# Epoch 119/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0857 - val_loss: 1.0854 - learning_rate: 1.0000e-04
# Epoch 120/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0878 - val_loss: 1.0856 - learning_rate: 1.0000e-04
# Epoch 121/150
# 236/250 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 1.0851
# Epoch 121: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0851 - val_loss: 1.0852 - learning_rate: 1.0000e-04
# Epoch 122/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0863 - val_loss: 1.0850 - learning_rate: 1.0000e-05
# Epoch 123/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0872 - val_loss: 1.0851 - learning_rate: 1.0000e-05
# Epoch 124/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0838 - val_loss: 1.0850 - learning_rate: 1.0000e-05
# Epoch 125/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0829 - val_loss: 1.0851 - learning_rate: 1.0000e-05
# Epoch 126/150
# 239/250 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 1.0827
# Epoch 126: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0828 - val_loss: 1.0851 - learning_rate: 1.0000e-05
# Epoch 127/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0864 - val_loss: 1.0850 - learning_rate: 1.0000e-06
# Epoch 128/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0846 - val_loss: 1.0850 - learning_rate: 1.0000e-06
# Epoch 129/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0844 - val_loss: 1.0850 - learning_rate: 1.0000e-06
# Epoch 130/150
# 232/250 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 1.0858
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0858 - val_loss: 1.0851 - learning_rate: 1.0000e-06
# Epoch 131/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0872 - val_loss: 1.0850 - learning_rate: 1.0000e-07
# Epoch 132/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0843 - val_loss: 1.0850 - learning_rate: 1.0000e-07
# Epoch 133/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0837 - val_loss: 1.0850 - learning_rate: 1.0000e-07
# Epoch 134/150
# 191/250 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 1.0832
# Epoch 134: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0837 - val_loss: 1.0850 - learning_rate: 1.0000e-07
# Epoch 135/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0867 - val_loss: 1.0850 - learning_rate: 1.0000e-08
# Epoch 136/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0846 - val_loss: 1.0850 - learning_rate: 1.0000e-08

# %%
HLT_AE.save_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.save_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')
HLT_AE.load_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.load_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')

# %%
# train L1 model
# train HLT model
history = L1_AE.fit(
    x=datasets['jjJZ1&2&4_train']['L1_data'], 
    y=datasets['jjJZ1&2&4_train']['L1_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['jjJZ1&2&4_train']['weights']
)
# Out:
# Epoch 1/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 1.6004 - val_loss: 1.4199 - learning_rate: 0.0010
# Epoch 2/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4111 - val_loss: 1.3988 - learning_rate: 0.0010
# Epoch 3/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3974 - val_loss: 1.3911 - learning_rate: 0.0010
# Epoch 4/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3903 - val_loss: 1.3842 - learning_rate: 0.0010
# Epoch 5/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3791 - val_loss: 1.3758 - learning_rate: 0.0010
# Epoch 6/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3744 - val_loss: 1.3663 - learning_rate: 0.0010
# Epoch 7/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3620 - val_loss: 1.3581 - learning_rate: 0.0010
# Epoch 8/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3543 - val_loss: 1.3529 - learning_rate: 0.0010

# %%
L1_AE.save_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.save_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')
L1_AE.load_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.load_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')

# %%
##Model Evaluation

# %%
# Pass the datasets through the model

for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue

    dict['HLT_model_outputs'] = HLT_AE.predict(dict['HLT_data'])
    #dict['HLT_latent_reps'] = HLT_encoder.predict(dict['HLT_data'])
    dict['L1_model_outputs'] = L1_AE.predict(dict['L1_data'])
    #dict['L1_latent_reps'] = L1_encoder.predict(dict['L1_data'])
# Out:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 545us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 548us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 537us/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 551us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 544us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 548us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 559us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 547us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 553us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 546us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 545us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 551us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 553us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 546us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 545us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 546us/step
# 18859/18859 ━━━━━━━━━━━━━━━━━━━━ 11s 574us/step
# 18859/18859 ━━━━━━━━━━━━━━━━━━━━ 11s 560us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 26s 563us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 26s 562us/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 2s 740us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 1s 554us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 1s 550us/step

# %%
def mse_loss(true, prediction):
    loss = np.mean(np.square(true - prediction), axis=-1)
    return loss

# %%
def MSE_AD_score(y, x):
    # masked mse
    mask = (y != 0) & (y != -999)
    _x = x * mask
    _y = y * mask
    # return (mse_loss(_y, _x))
    return (mse_loss(y, x))

# %%
# Calculate the AD scores

for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue

    dict['HLT_AD_scores'] = MSE_AD_score(dict['HLT_data'], dict['HLT_model_outputs'])
    dict['L1_AD_scores'] = MSE_AD_score(dict['L1_data'], dict['L1_model_outputs'])

# %%
# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
# HLT_model_outputs: (10000, 60)
# L1_model_outputs: (10000, 60)
# HLT_AD_scores: (10000,)
# L1_AD_scores: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
# HLT_model_outputs: (70000, 60)
# L1_model_outputs: (70000, 60)
# HLT_AD_scores: (70000,)
# L1_AD_scores: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
# HLT_model_outputs: (50000, 60)
# L1_model_outputs: (50000, 60)
# HLT_AD_scores: (50000,)
# L1_AD_scores: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# EB_data:
# HLT_data: (603486, 60)
# L1_data: (603486, 60)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
# HLT_model_outputs: (603486, 60)
# L1_model_outputs: (603486, 60)
# HLT_AD_scores: (603486,)
# L1_AD_scores: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
# HLT_model_outputs: (1501347, 60)
# L1_model_outputs: (1501347, 60)
# HLT_AD_scores: (1501347,)
# L1_AD_scores: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
# HLT_model_outputs: (15255, 60)
# L1_model_outputs: (15255, 60)
# HLT_AD_scores: (15255,)
# L1_AD_scores: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 60)
# L1_data: (150000, 60)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
# HLT_model_outputs: (75000, 60)
# L1_model_outputs: (75000, 60)
# HLT_AD_scores: (75000,)
# L1_AD_scores: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
# HLT_model_outputs: (75000, 60)
# L1_model_outputs: (75000, 60)
# HLT_AD_scores: (75000,)
# L1_AD_scores: (75000,)

# %%
def ROC_curve(dataset, bkg_type, target_rate=10, plot=True):
    """
    Plots ROC curve and returns AUC, TPR, FPR, and thresholds for each dataset.
    
    inputs: 
    dataset: dictionary containing dataset information
    bkg_type: the background type to calculate over
    plot: whether to plot the ROC curve or not
    
    returns:
    results: dictionary {dataset_names: {'TPR': ..., 'AUC': ..., 'FPR': ..., 'threshold': ...}}
    """
    
    bkg_tag = 'jjJZ1&2&4_test1'
    #target_rate = 10  # 10 Hz pure rate
    plt.figure(figsize=(8.5,6.8))
    
    results = {}
    
    for tag in dataset.keys():
        if tag != bkg_tag and tag != 'jjJZ1&2&4_train':
        
            # Combine true labels, anomaly=1 and background=0
            trueVal = np.concatenate((np.ones(dataset[tag][f'{bkg_type}_AD_scores'].shape[0]), np.zeros(dataset[bkg_tag][f'{bkg_type}_AD_scores'].shape[0])))
            
            # Combine predictions from current dataset and background
            predVal_loss = np.concatenate((dataset[tag][f'{bkg_type}_AD_scores'], dataset[bkg_tag][f'{bkg_type}_AD_scores']))
        
            sample_weights = np.concatenate((dataset[tag]['weights'], dataset[bkg_tag]['weights']))
            
            for i in range(len(predVal_loss)):
                if np.isnan(predVal_loss[i]):
                    predVal_loss[i] = 0
           
            # Calculate ROC curve and AUC, including weights
            fpr_loss, tpr_loss, threshold_loss = sklearn.metrics.roc_curve(y_true=trueVal, y_score=predVal_loss, sample_weight=sample_weights)
            auc_loss = auc(fpr_loss, tpr_loss)

            # Initialize variables for early stopping
            min_diff = float('inf')
            best_idx = 0
            previous_diff = float('inf')
            
            # Iterate over thresholds with early stopping
            for idx, value in enumerate(threshold_loss):
                anomaly_idxs_bkg = dataset[bkg_tag][f'{bkg_type}_AD_scores'] > value
                bkg_rate = 100000 * np.sum(dataset[bkg_tag]['weights'] * (anomaly_idxs_bkg & ~dataset[bkg_tag]['passHLT'])) / np.sum(dataset[bkg_tag]['weights'])
                # Calculate the difference from the target rate
                diff = abs(bkg_rate - target_rate)
                
                # Check if the difference is decreasing
                if diff < min_diff:
                    min_diff = diff
                    best_idx = idx
                else:
                    # If the difference starts increasing, break the loop
                    if diff > previous_diff:
                        print(f'Background rate = {bkg_rate:.3}Hz')
                        break
                
                previous_diff = diff
            
            # Use the best index found
            selected_threshold = threshold_loss[best_idx]
            selected_fpr = fpr_loss[best_idx]
            signal_tpr = tpr_loss[best_idx]
            
            # Store the results
            results[tag] = {
                'TPR': signal_tpr,
                'AUC': auc_loss,
                'FPR': selected_fpr,
                'threshold': selected_threshold
            }
        
            # Plot ROC curve
            if plot:
                plt.plot(fpr_loss, tpr_loss, "-", label='%s (AUC = %.1f%%)' % (tag, auc_loss*100.), linewidth=1.5)

    if plot:
        # Set log scale for x and y axis
        plt.semilogx()
        plt.semilogy()
        
        # Plot aesthetics and layout
        plt.plot(np.linspace(0, 1), np.linspace(0, 1), '--', color='0.75')
        plt.plot([selected_fpr, selected_fpr], [0, 1], '--', color='r')
        plt.ylabel("True Positive Rate", fontsize=16)
        plt.xlabel("False Positive Rate", fontsize=16)
        plt.legend(loc='lower right', fontsize=6)
        plt.grid(True)
        plt.tight_layout()
        plt.title(f'Trained over {bkg_type} objects', fontsize=20)
        plt.show()

    return results

# %%
for target_rate in [10, 200, 1000]:
    print(f'TARGET (PURE) RATE::::: {target_rate}')
    HLT_results = ROC_curve(datasets, bkg_type='HLT', target_rate=target_rate)
    L1_results = ROC_curve(datasets, bkg_type='L1', target_rate=target_rate)

    # L1 Signal Efficiencies

    tags = []
    l1_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            L1_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            L1_anomaly_idxs = datasets[tag]['L1_AD_scores'] > L1_results[tag]['threshold']
            L1_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | L1_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            l1_efficiencies.append(L1_TPR)
            combined_efficiencies.append(L1_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, l1_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(l1_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, L1 Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()



    # Signal Efficiencies

    tags = []
    hlt_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            HLT_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_results[tag]['threshold']
            HLT_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | HLT_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            hlt_efficiencies.append(HLT_TPR)
            combined_efficiencies.append(HLT_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, hlt_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(hlt_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, HLT Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()
    
    # HLT overlaps
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = HLT_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['HLT_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")

    # HLT overlaps
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = L1_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")
# Out:
# TARGET (PURE) RATE::::: 10
# Background rate = 12.0Hz
# Background rate = 20.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 17.3Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 25.3Hz
# Background rate = 12.0Hz
# Background rate = 14.7Hz
# Background rate = 42.7Hz
# Background rate = 26.7Hz
# Background rate = 89.3Hz
# Background rate = 17.3Hz
# Normalized by the left bar:
# [1.         1.00130208 1.00039582 1.00110351 1.00018375 1.
#  1.00003673 1.00746965 1.07407407 1.         1.         1.
#  1.00020014]
# Normalized by the left bar:
# [1.         1.00130208 1.00108329 1.00485544 1.00051681 1.
#  1.00009182 1.02240896 1.21296296 1.         3.68708296 1.
#  1.00056038]
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 3e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# A14N23LO:
# HLT overlap: 0.3333333333333333
# inverse overlap: 1.0005208333333333
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0003
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.8421052631578947
# inverse overlap: 1.0000624973959418
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.00027142857142857144
# Raw number of events that we tagged as anomalous: 19
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 16
# -----
# qqa:
# HLT overlap: 0.0
# inverse overlap: 1.001103509159126
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.0001
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# ZZ4lep:
# HLT overlap: 0.92
# inverse overlap: 1.0000459384654257
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.0005
# Raw number of events that we tagged as anomalous: 50
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 46
# -----
# Zprime2EJs:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 1e-05
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# HHbbttHadHad:
# HLT overlap: 0.5555555555555556
# inverse overlap: 1.0000734564953906
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 9e-05
# Raw number of events that we tagged as anomalous: 9
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# jjJZ2:
# HLT overlap: 0.0
# inverse overlap: 1.0140056022408963
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00015
# Raw number of events that we tagged as anomalous: 15
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.0
# inverse overlap: 1.0694444444444444
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00015
# Raw number of events that we tagged as anomalous: 15
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_data:
# HLT overlap: 0.010827399368648892
# inverse overlap: 1.1197055527983442
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.001183126037720842
# Raw number of events that we tagged as anomalous: 714
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 16
# -----
# EB_zerobias:
# HLT overlap: 3.3448545784053266e-06
# inverse overlap: 1029.2245420846898
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0009484815968593536
# Raw number of events that we tagged as anomalous: 1424
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0010488364470665355
# Raw number of events that we tagged as anomalous: 16
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 16
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.14285714285714285
# inverse overlap: 1.000480326622103
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.00018666666666666666
# Raw number of events that we tagged as anomalous: 14
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 3e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# A14N23LO:
# HLT overlap: 0.16666666666666666
# inverse overlap: 1.0013020833333333
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0006
# Raw number of events that we tagged as anomalous: 6
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7840909090909091
# inverse overlap: 1.000395816840965
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.001257142857142857
# Raw number of events that we tagged as anomalous: 88
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 69
# -----
# qqa:
# HLT overlap: 0.16666666666666666
# inverse overlap: 1.001103509159126
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00012
# Raw number of events that we tagged as anomalous: 6
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# ZZ4lep:
# HLT overlap: 0.8740157480314961
# inverse overlap: 1.0001837538617022
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00127
# Raw number of events that we tagged as anomalous: 127
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 111
# -----
# Zprime2EJs:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HHbbttHadHad:
# HLT overlap: 0.5
# inverse overlap: 1.0000367282476954
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 4e-05
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# jjJZ2:
# HLT overlap: 0.0
# inverse overlap: 1.007469654528478
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 8e-05
# Raw number of events that we tagged as anomalous: 8
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.0
# inverse overlap: 1.0740740740740742
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00016
# Raw number of events that we tagged as anomalous: 16
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_data:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_zerobias:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_passHLT:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.0
# inverse overlap: 1.000200136092543
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 6.666666666666667e-05
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# TARGET (PURE) RATE::::: 200
# /tmp/ipykernel_207/3559298588.py:155: RuntimeWarning: invalid value encountered in scalar divide
#   HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
# Background rate = 2.01e+02Hz
# Background rate = 2.05e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.05e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.17e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.6e+02Hz
# Background rate = 2.01e+02Hz
# Normalized by the left bar:
# [1.00001018 1.02109375 1.00643723 1.04987861 1.00196387 1.00003406
#  1.00099166 1.22128852 2.55092593 1.00229854 6.38116932 1.
#  1.00564384]
# Normalized by the left bar:
# [ 1.00007127  1.05546875  1.01649931  1.14676672  1.00527144  1.00014758
#   1.0036361   1.76470588  5.66666667  1.01570196 19.44735915  1.
#   1.01965336]
# -----
# jjJZ4:
# HLT overlap: 0.9785714285714285
# inverse overlap: 1.000030542744571
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.0014
# Raw number of events that we tagged as anomalous: 140
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 137
# -----
# A14N23LO:
# HLT overlap: 0.325
# inverse overlap: 1.00703125
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.004
# Raw number of events that we tagged as anomalous: 40
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 13
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7576601671309192
# inverse overlap: 1.0018124244823132
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.0051285714285714285
# Raw number of events that we tagged as anomalous: 359
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 272
# -----
# qqa:
# HLT overlap: 0.16326530612244897
# inverse overlap: 1.0180975502096667
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00196
# Raw number of events that we tagged as anomalous: 98
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 16
# -----
# ZZ4lep:
# HLT overlap: 0.8851224105461394
# inverse overlap: 1.0007005615977398
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00531
# Raw number of events that we tagged as anomalous: 531
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 470
# -----
# Zprime2EJs:
# HLT overlap: 0.8275862068965517
# inverse overlap: 1.0000567614203977
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00029
# Raw number of events that we tagged as anomalous: 29
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 24
# -----
# HHbbttHadHad:
# HLT overlap: 0.4752475247524752
# inverse overlap: 1.001946597127851
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00202
# Raw number of events that we tagged as anomalous: 202
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 96
# -----
# jjJZ2:
# HLT overlap: 0.014492753623188406
# inverse overlap: 1.253968253968254
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00276
# Raw number of events that we tagged as anomalous: 276
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4
# -----
# jjJZ1:
# HLT overlap: 0.006024096385542169
# inverse overlap: 2.5277777777777777
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00332
# Raw number of events that we tagged as anomalous: 332
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# EB_data:
# HLT overlap: 0.012559985841687238
# inverse overlap: 2.2417380626456214
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.013262942305206749
# Raw number of events that we tagged as anomalous: 8004
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 198
# -----
# EB_zerobias:
# HLT overlap: 8.350879402818435e-06
# inverse overlap: 9037.42593564446
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.009029891157740349
# Raw number of events that we tagged as anomalous: 13557
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.014421501147164863
# Raw number of events that we tagged as anomalous: 220
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 220
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.19724770642201836
# inverse overlap: 1.0070047632390025
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.0029066666666666668
# Raw number of events that we tagged as anomalous: 218
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 43
# -----
# jjJZ4:
# HLT overlap: 0.9902912621359223
# inverse overlap: 1.000010180914857
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00103
# Raw number of events that we tagged as anomalous: 103
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 102
# -----
# A14N23LO:
# HLT overlap: 0.36220472440944884
# inverse overlap: 1.02109375
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0127
# Raw number of events that we tagged as anomalous: 127
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 46
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.718065693430657
# inverse overlap: 1.0064372317820092
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.015657142857142856
# Raw number of events that we tagged as anomalous: 1096
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 787
# -----
# qqa:
# HLT overlap: 0.08870967741935484
# inverse overlap: 1.049878613992496
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00496
# Raw number of events that we tagged as anomalous: 248
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# ZZ4lep:
# HLT overlap: 0.8775071633237822
# inverse overlap: 1.0019638693969428
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.01396
# Raw number of events that we tagged as anomalous: 1396
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1225
# -----
# Zprime2EJs:
# HLT overlap: 0.9491525423728814
# inverse overlap: 1.0000340568522386
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00059
# Raw number of events that we tagged as anomalous: 59
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 56
# -----
# HHbbttHadHad:
# HLT overlap: 0.44329896907216493
# inverse overlap: 1.000991662687773
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00097
# Raw number of events that we tagged as anomalous: 97
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 43
# -----
# jjJZ2:
# HLT overlap: 0.0125
# inverse overlap: 1.2212885154061626
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.0024
# Raw number of events that we tagged as anomalous: 240
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ1:
# HLT overlap: 0.017595307917888565
# inverse overlap: 2.550925925925926
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00341
# Raw number of events that we tagged as anomalous: 341
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 6
# -----
# EB_data:
# HLT overlap: 0.09510210125141445
# inverse overlap: 1.002298541022499
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 5.1368217324014145e-05
# Raw number of events that we tagged as anomalous: 31
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# EB_zerobias:
# HLT overlap: 0.0006356671715666868
# inverse overlap: 6.3811693204262125
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 2.4644535873452308e-05
# Raw number of events that we tagged as anomalous: 37
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.00019665683382497542
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.16071428571428573
# inverse overlap: 1.0056438378097106
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.00224
# Raw number of events that we tagged as anomalous: 168
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 27
# TARGET (PURE) RATE::::: 1000
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.03e+03Hz
# Background rate = 1e+03Hz
# Normalized by the left bar:
# [ 1.00019344  1.08619792  1.0247698   1.24828956  1.00782102  1.00030651
#   1.00622544  2.33706816  8.5462963   1.0209357  29.56150227  1.
#   1.03246207]
# Normalized by the left bar:
# [ 1.00051923  1.16875     1.04628974  1.55153388  1.01491852  1.00088548
#   1.01715209  4.3015873  17.46759259  1.07073305 70.00155165  1.
#   1.07208902]
# -----
# jjJZ4:
# HLT overlap: 0.9793103448275862
# inverse overlap: 1.0001832564674262
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.0087
# Raw number of events that we tagged as anomalous: 870
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 852
# -----
# A14N23LO:
# HLT overlap: 0.45517241379310347
# inverse overlap: 1.0205729166666666
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0145
# Raw number of events that we tagged as anomalous: 145
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 66
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7485428809325562
# inverse overlap: 1.0062914045248115
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.017157142857142857
# Raw number of events that we tagged as anomalous: 1201
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 899
# -----
# qqa:
# HLT overlap: 0.14396887159533073
# inverse overlap: 1.0971088060030898
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.01028
# Raw number of events that we tagged as anomalous: 514
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 74
# -----
# ZZ4lep:
# HLT overlap: 0.8935
# inverse overlap: 1.0024462232839113
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.02
# Raw number of events that we tagged as anomalous: 2000
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1787
# -----
# Zprime2EJs:
# HLT overlap: 0.8578947368421053
# inverse overlap: 1.000306511670148
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.0019
# Raw number of events that we tagged as anomalous: 190
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 163
# -----
# HHbbttHadHad:
# HLT overlap: 0.5096339113680154
# inverse overlap: 1.0093473390384544
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.01038
# Raw number of events that we tagged as anomalous: 1038
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 529
# -----
# jjJZ2:
# HLT overlap: 0.01619718309859155
# inverse overlap: 2.3043884220354807
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.0142
# Raw number of events that we tagged as anomalous: 1420
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 23
# -----
# jjJZ1:
# HLT overlap: 0.006802721088435374
# inverse overlap: 7.7592592592592595
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.0147
# Raw number of events that we tagged as anomalous: 1470
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 10
# -----
# EB_data:
# HLT overlap: 0.012146367394577764
# inverse overlap: 4.815116249243011
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.044315858197207555
# Raw number of events that we tagged as anomalous: 26744
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 614
# -----
# EB_zerobias:
# HLT overlap: 6.692967646521633e-06
# inverse overlap: 25620.194018736067
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.026558816849136142
# Raw number of events that we tagged as anomalous: 39874
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 50
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.043526712553261224
# Raw number of events that we tagged as anomalous: 664
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 664
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.24098867147270855
# inverse overlap: 1.0295000600408277
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.012946666666666667
# Raw number of events that we tagged as anomalous: 971
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 234
# -----
# jjJZ4:
# HLT overlap: 0.9737569060773481
# inverse overlap: 1.0001934373822832
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00724
# Raw number of events that we tagged as anomalous: 724
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 705
# -----
# A14N23LO:
# HLT overlap: 0.3597678916827853
# inverse overlap: 1.0861979166666667
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0517
# Raw number of events that we tagged as anomalous: 517
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 186
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.6945800154122784
# inverse overlap: 1.0247698012582809
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.05561428571428571
# Raw number of events that we tagged as anomalous: 3893
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2704
# -----
# qqa:
# HLT overlap: 0.10501193317422435
# inverse overlap: 1.2482895608033546
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.02514
# Raw number of events that we tagged as anomalous: 1257
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 132
# -----
# ZZ4lep:
# HLT overlap: 0.8687102371312898
# inverse overlap: 1.007821023738702
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.05187
# Raw number of events that we tagged as anomalous: 5187
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4506
# -----
# Zprime2EJs:
# HLT overlap: 0.9243697478991597
# inverse overlap: 1.000306511670148
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00357
# Raw number of events that we tagged as anomalous: 357
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 330
# -----
# HHbbttHadHad:
# HLT overlap: 0.46614173228346456
# inverse overlap: 1.0062254379843538
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00635
# Raw number of events that we tagged as anomalous: 635
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 296
# -----
# jjJZ2:
# HLT overlap: 0.016483516483516484
# inverse overlap: 2.3370681605975725
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.01456
# Raw number of events that we tagged as anomalous: 1456
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 24
# -----
# jjJZ1:
# HLT overlap: 0.010321797207043109
# inverse overlap: 8.546296296296296
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.01647
# Raw number of events that we tagged as anomalous: 1647
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 17
# -----
# EB_data:
# HLT overlap: 0.058448486598188645
# inverse overlap: 1.0209357046846372
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.0002949529897959522
# Raw number of events that we tagged as anomalous: 178
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 16
# -----
# EB_zerobias:
# HLT overlap: 0.0007194663520189021
# inverse overlap: 29.561502267402066
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0001898295330792948
# Raw number of events that we tagged as anomalous: 285
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 6
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0014421501147164864
# Raw number of events that we tagged as anomalous: 22
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.18655967903711135
# inverse overlap: 1.032462074210463
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.013293333333333334
# Raw number of events that we tagged as anomalous: 997
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 186

# %%
#HLT
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
#HLT
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
#HLT
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n] > 1) and (HLT_electron_mults[tag][n] > 1) and (HLT_muon_mults[tag][n] > 1) and (HLT_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    ax1.hist(HLT_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1

plt.xticks(np.arange(0, 2000,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
#L1
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n] > 1) and (L1_electron_mults[tag][n] > 1) and (L1_muon_mults[tag][n] > 1) and (L1_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    ax1.hist(L1_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1
plt.xlim(0, 800)
plt.xticks(np.arange(0, 800,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
import ROOT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 import ROOT
#
# ModuleNotFoundError: No module named 'ROOT'

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "HLT" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/Root/HLT', f"{title}_plot.png")
    canvas.SaveAs(output_path)

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "L1" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "HLT" + tag + "jet mult v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_jet_mults[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "L1" + tag + "jet mult v ad score "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(L1_jet_mults[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)

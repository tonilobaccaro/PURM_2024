# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import random
import sklearn
import collections
from sklearn.model_selection import train_test_split
import json
import pylab
from scipy.optimize import curve_fit
from tensorflow.keras import layers, Model
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, auc
import matplotlib
import matplotlib.patches as mpatches
#import shap
import os
import pandas as pd
#improve gpu memory usage
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# %%
# Set matplotlib default color cycle
new_color_cycle = [
#jjJZ4
    '#4f2ca8',
#A14N23LO
    '#b45f06',
#HAHMggf
    '#ff0000',
#qqa
    '#d4d400',
#ZZ4lep
    '#294a18',
#Zprime2EJs
    '#00de00',
#HHbbttHadHad
    '#5b0f00',
#jjJZ2
  '#ca7dff',
#jjJZ1
  '#d201d2',
#data
 '#3232ff', 
#zerobias
    '#002a75',
#passedHLT
    '#00cdcd',
#jjJZ124
    '#8e1d55',
#test 2
    '#7f7f7f'
]

# You can then apply this new color cycle to your matplotlib plots
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=new_color_cycle)

# %% [markdown]
# ## Read Data Files

# %%
# This is the list that will hold all of the data 
datasets = {}

# %%
# Read Monte Carlo Simulated Collisions

data_path = '/home/jovyan/MC_data/'

for filename in os.listdir(data_path):

    if filename.startswith('N') or filename.startswith('.'): continue

    dataset_tag = filename.split('_')[0]
    
    with h5py.File(data_path+filename, 'r') as hf:
        HLT_jets = hf['HLT_jets'][:]
        L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
        L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
        HLT_electrons = hf['HLT_electrons'][:]
        LRT_electrons = hf['LRT_electrons'][:]
        L1_egammas = hf['L1_egammas'][:]
        HLT_muons = hf['HLT_muons'][:]
        LRT_muons = hf['LRT_muons'][:]
        L1_muons = hf['L1_muons'][:]
        L1_eFex_taus = hf['L1_eFex_taus'][:]
        L1_jFex_taus = hf['L1_jFex_taus'][:]
        HLT_photons = hf['HLT_photons'][:]
        HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 4)  # Broadcasting MET
        L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
        pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
        pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]

        HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, [0, 2, 3]], HLT_muons[:, :3, [0, 2, 3]], HLT_photons[:, :3, [0, 2, 3]], HLT_MET[:, :, [0, 2, 3]]], axis=1)
        L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)
        
        datasets[dataset_tag] = {
            'HLT_data': HLT_objects,
            'L1_data': L1_objects,
            'passL1': pass_L1_unprescaled==1,
            'passHLT': pass_HLT_unprescaled==1,
            'weights': np.ones(len(HLT_objects)),
        }

        if len(HLT_objects) > 100000:
            datasets[dataset_tag] = {key: value[:100000] for key, value in datasets[dataset_tag].items()}

# %%
# Read 2024 EB data

with h5py.File('/home/jovyan/EB_data/EB_ntuples_08-13-2024-003.h5', 'r') as hf:
    HLT_jets = hf['HLT_jets'][:]
    ofl_jets = hf['ofl_jets'][:]
    L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
    L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
    HLT_electrons = hf['HLT_electrons'][:]
    LRT_electrons = hf['LRT_electrons'][:]
    ofl_electrons = hf['ofl_electrons'][:]
    L1_egammas = hf['L1_egammas'][:]
    HLT_muons = hf['HLT_muons'][:]
    LRT_muons = hf['LRT_muons'][:]
    ofl_muons = hf['ofl_muons'][:]
    L1_muons = hf['L1_muons'][:]
    L1_eFex_taus = hf['L1_eFex_taus'][:]
    L1_jFex_taus = hf['L1_jFex_taus'][:]
    HLT_photons = hf['HLT_photons'][:]
    ofl_photons = hf['ofl_photons'][:]
    HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 3)  # Broadcasting MET
    L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
    pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
    pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]
    EB_weights = hf["EB_weights"][:]
    event_number = hf["event_number"][:]
    run_number = hf["run_number"][:]

HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, :], HLT_muons[:, :3, :], HLT_photons[:, :3, :], HLT_MET], axis=1)
L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)



# Indices of events that passed L1
pass_L1_idxs = (pass_L1_unprescaled == 1)

# Indices of events that passed HLT
pass_HLT_idxs = (pass_HLT_unprescaled == 1)



datasets['EB_data'] = {
    'HLT_data': HLT_objects[pass_L1_idxs] ,
    'L1_data': L1_objects[pass_L1_idxs] ,
    'passL1': pass_L1_idxs[pass_L1_idxs],
    'passHLT': pass_HLT_idxs[pass_L1_idxs],
    'weights': EB_weights[pass_L1_idxs],
}

datasets['EB_zerobias'] = {
    'HLT_data': HLT_objects[~pass_L1_idxs] ,
    'L1_data': L1_objects[~pass_L1_idxs] ,
    'passL1': pass_L1_idxs[~pass_L1_idxs],
    'passHLT': pass_HLT_idxs[~pass_L1_idxs],
    'weights': EB_weights[~pass_L1_idxs],
}

datasets['EB_passHLT'] = {
    'HLT_data': HLT_objects[pass_HLT_idxs] ,
    'L1_data': L1_objects[pass_HLT_idxs] ,
    'passL1': pass_L1_idxs[pass_HLT_idxs],
    'passHLT': pass_HLT_idxs[pass_HLT_idxs],
    'weights': EB_weights[pass_HLT_idxs],
}

# %% [markdown]
# ## Data Processing

# %%
#create combo of jjJZ4 & jjJZ2 & jjJZ1

datasets['jjJZ1&2&4'] = {
    'HLT_data': np.concatenate((datasets['jjJZ1']['HLT_data'],datasets['jjJZ2']['HLT_data'],datasets['jjJZ4']['HLT_data'])),
    'L1_data': np.concatenate((datasets['jjJZ1']['L1_data'],datasets['jjJZ2']['L1_data'],datasets['jjJZ4']['L1_data'])) ,
    'passL1': np.concatenate((datasets['jjJZ1']['passL1'],datasets['jjJZ2']['passL1'],datasets['jjJZ4']['passL1'])),
    'passHLT': np.concatenate((datasets['jjJZ1']['passHLT'],datasets['jjJZ2']['passHLT'],datasets['jjJZ4']['passHLT'])),
    'weights': np.concatenate((datasets['jjJZ1']['weights'],datasets['jjJZ2']['weights'],datasets['jjJZ4']['weights'])),
}

# %%
"""Multiply the pt of the L1 muons by 1000 to get them into the right units."""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label == 'L1_data':
            data[:, 13:16, 0] *= 1000

# %%
# Split EB data in train, test

random_seed = 789247

indices = np.arange(len(datasets['jjJZ1&2&4']['HLT_data']))
train_indices, _indices = train_test_split(indices, train_size=0.5, random_state=random_seed)
test1_indices, test2_indices = train_test_split(_indices, train_size=0.5, random_state=random_seed)

datasets['jjJZ1&2&4_train'] = {key:value[train_indices] for key, value in datasets['jjJZ1&2&4'].items()}
datasets['jjJZ1&2&4_test1'] = {key:value[test1_indices] for key, value in datasets['jjJZ1&2&4'].items()}
datasets['jjJZ1&2&4_test2'] = {key:value[test2_indices] for key, value in datasets['jjJZ1&2&4'].items()}

del datasets['jjJZ1&2&4']

# %%
#save pt values before normalization for 2d histogram of max pt vs. anomaly score & efficiency plots
HLT_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['HLT_data'][i,j,0]:
                temp[i] = datasets[tag]['HLT_data'][i,j,0]
    HLT_max_pt_vals[tag] = temp
L1_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['L1_data'][i,j,0]:
                temp[i] = datasets[tag]['L1_data'][i,j,0]
    L1_max_pt_vals[tag] = temp
HLT_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_jet_mults[tag] = temp
L1_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_jet_mults[tag] = temp
HLT_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10,13):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_electron_mults[tag] = temp
L1_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10,13):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_electron_mults[tag] = temp
HLT_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(13,16):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_muon_mults[tag] = temp
L1_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(13,16):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_muon_mults[tag] = temp
HLT_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(16,19):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_photon_mults[tag] = temp
L1_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(16,19):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_photon_mults[tag] = temp

# %%
for tag, dict in datasets.items():
    print(f'\n{tag}:')
    for key, value in dict.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 20, 3)
# L1_data: (10000, 20, 3)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 20, 3)
# L1_data: (70000, 20, 3)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 20, 3)
# L1_data: (50000, 20, 3)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_data:
# HLT_data: (603486, 20, 3)
# L1_data: (603486, 20, 3)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 20, 3)
# L1_data: (1501347, 20, 3)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 20, 3)
# L1_data: (15255, 20, 3)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 20, 3)
# L1_data: (150000, 20, 3)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 20, 3)
# L1_data: (75000, 20, 3)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 20, 3)
# L1_data: (75000, 20, 3)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)

# %%
"""Met bias. For some events, MET was not calculated, so was written as -999.
We don't want this to impact training, so we map 0 --> 0.001 and -999 --> 0"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):

            # MET: 0 --> 0.001 and -999 --> 0 and nan --> 0
            MET_zeros = (data[:, 19, 0] == 0) # indices where MET=0
            MET_999 = ((data[:, 19, 0] == -999)) # indices where MET=-999 (not calculated)
            MET_nan = np.isnan(data[:, 19, 2])
            data[MET_zeros, 19, 0] = 0.001
            data[MET_999, 19, :] = 0
            data[MET_nan, 19, :] = 0

# %%
"""Normalize pt such that sum(pt) = 1 in each event"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
#             # sum of the pt and E in each event
            sum_pt = np.sum(data[:, :, 0], axis=1, keepdims=True)
        
#             # If the sum is 0, set the sum to 1 to avoid division by 0
            sum_pt[sum_pt == 0] = 1
        
#             # Divide pt and E by their respective sums, multiply by 10
            data[:, :, 0] *= (1/sum_pt)

# %% [markdown]
# ## Autoencoder Architecture

# %%
# Flatten ndarrays for use in DNN

for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
            datasets[tag][label] = np.reshape(data, newshape=(-1, 60))

# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_data:
# HLT_data: (603486, 60)
# L1_data: (603486, 60)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 60)
# L1_data: (150000, 60)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)

# %%
def create_AE(input_dim, h_dim_1, h_dim_2, latent_dim):
    
     # Encoder
    encoder_inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(h_dim_1, activation='relu')(encoder_inputs)
    x = layers.Dense(h_dim_2, activation='relu')(x)
    z = layers.Dense(latent_dim, activation='relu')(x)
    
    encoder = Model(inputs=encoder_inputs, outputs=z)

    # Decoder
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(h_dim_2, activation='relu')(decoder_inputs)
    x = layers.Dense(h_dim_1, activation='relu')(x)
    outputs = layers.Dense(input_dim)(x)

    decoder = Model(inputs=decoder_inputs, outputs=outputs)

    ae_outputs = decoder(encoder(encoder_inputs))
    ae = Model(encoder_inputs, outputs=ae_outputs)
    return ae, encoder, decoder

# %%
def loss_fn(y_true, y_pred):
    """masked mse"""
    # mask0 = K.cast(K.not_equal(y_true, 0), K.floatx())
    # maskMET = K.cast(K.not_equal(y_true, -999), K.floatx())
    # mask = mask0 * maskMET
    # squared_difference = K.square(mask * (y_pred - y_true))
    squared_difference = K.square((y_pred - y_true))
    return K.mean(squared_difference)

# %%
# Initialize models
INPUT_DIM = datasets['jjJZ1&2&4_train']['HLT_data'].shape[1]
H_DIM_1 = 32
H_DIM_2 = 8
LATENT_DIM = 2

HLT_AE, HLT_encoder, HLT_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)
L1_AE, L1_encoder, L1_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)

HLT_AE.summary()
L1_AE.summary()
# Out:
# 2024-10-05 15:28:50.926772: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20732 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:41:00.0, compute capability: 8.6
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_3 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_7 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_9 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# Define callbacks: early stopping and learning rate scheduler

STOP_PATIENCE = 8
LR_PATIENCE = 4

early_stopping = EarlyStopping(patience=STOP_PATIENCE, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=LR_PATIENCE, verbose=1)

callbacks = [early_stopping, reduce_lr]

# %%
NUM_EPOCHS = 150
BATCH_SIZE = 512

# %% [markdown]
# ## Model Training

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# train HLT model
history = HLT_AE.fit(
    x=datasets['jjJZ1&2&4_train']['HLT_data'], 
    y=datasets['jjJZ1&2&4_train']['HLT_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['jjJZ1&2&4_train']['weights']
)
# Out:
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728142134.210792   63519 service.cc:145] XLA service 0x7fcc5c00e580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728142134.210835   63519 service.cc:153]   StreamExecutor device (0): NVIDIA A10, Compute Capability 8.6
# 2024-10-05 15:28:54.241055: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-05 15:28:54.476372: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728142134.996678   63681 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_504', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1728142135.066717   63679 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_504', 8 bytes spill stores, 8 bytes spill loads
# 186/250 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - loss: 1.4326
# I0000 00:00:1728142136.906368   63519 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 1.4181 - val_loss: 1.2722 - learning_rate: 0.0010
# Epoch 2/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2631 - val_loss: 1.2479 - learning_rate: 0.0010
# Epoch 3/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2500 - val_loss: 1.2410 - learning_rate: 0.0010
# Epoch 4/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2422 - val_loss: 1.2341 - learning_rate: 0.0010
# Epoch 5/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2354 - val_loss: 1.2278 - learning_rate: 0.0010
# Epoch 6/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2293 - val_loss: 1.2210 - learning_rate: 0.0010
# Epoch 7/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2223 - val_loss: 1.2154 - learning_rate: 0.0010
# Epoch 8/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2160 - val_loss: 1.2108 - learning_rate: 0.0010
# Epoch 9/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2129 - val_loss: 1.2049 - learning_rate: 0.0010
# Epoch 10/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2060 - val_loss: 1.2006 - learning_rate: 0.0010
# Epoch 11/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2004 - val_loss: 1.1956 - learning_rate: 0.0010
# Epoch 12/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1957 - val_loss: 1.1919 - learning_rate: 0.0010
# Epoch 13/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1943 - val_loss: 1.1892 - learning_rate: 0.0010
# Epoch 14/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1907 - val_loss: 1.1868 - learning_rate: 0.0010
# Epoch 15/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1874 - val_loss: 1.1860 - learning_rate: 0.0010
# Epoch 16/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1891 - val_loss: 1.1828 - learning_rate: 0.0010
# Epoch 17/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1848 - val_loss: 1.1810 - learning_rate: 0.0010
# Epoch 18/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1845 - val_loss: 1.1802 - learning_rate: 0.0010
# Epoch 19/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1824 - val_loss: 1.1774 - learning_rate: 0.0010
# Epoch 20/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1780 - val_loss: 1.1765 - learning_rate: 0.0010
# Epoch 21/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1806 - val_loss: 1.1755 - learning_rate: 0.0010
# Epoch 22/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1783 - val_loss: 1.1739 - learning_rate: 0.0010
# Epoch 23/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1773 - val_loss: 1.1728 - learning_rate: 0.0010
# Epoch 24/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1777 - val_loss: 1.1723 - learning_rate: 0.0010
# Epoch 25/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1738 - val_loss: 1.1721 - learning_rate: 0.0010
# Epoch 26/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1719 - val_loss: 1.1722 - learning_rate: 0.0010
# Epoch 27/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1758 - val_loss: 1.1699 - learning_rate: 0.0010
# Epoch 28/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1723 - val_loss: 1.1679 - learning_rate: 0.0010
# Epoch 29/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1707 - val_loss: 1.1669 - learning_rate: 0.0010
# Epoch 30/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1696 - val_loss: 1.1666 - learning_rate: 0.0010
# Epoch 31/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1681 - val_loss: 1.1645 - learning_rate: 0.0010
# Epoch 32/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1667 - val_loss: 1.1623 - learning_rate: 0.0010
# Epoch 33/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1651 - val_loss: 1.1601 - learning_rate: 0.0010
# Epoch 34/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1617 - val_loss: 1.1586 - learning_rate: 0.0010
# Epoch 35/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1607 - val_loss: 1.1569 - learning_rate: 0.0010
# Epoch 36/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1625 - val_loss: 1.1550 - learning_rate: 0.0010
# Epoch 37/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1527 - val_loss: 1.1533 - learning_rate: 0.0010
# Epoch 38/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1576 - val_loss: 1.1519 - learning_rate: 0.0010
# Epoch 39/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1545 - val_loss: 1.1502 - learning_rate: 0.0010
# Epoch 40/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1536 - val_loss: 1.1505 - learning_rate: 0.0010
# Epoch 41/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1517 - val_loss: 1.1486 - learning_rate: 0.0010
# Epoch 42/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1494 - val_loss: 1.1498 - learning_rate: 0.0010
# Epoch 43/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1509 - val_loss: 1.1491 - learning_rate: 0.0010
# Epoch 44/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1504 - val_loss: 1.1472 - learning_rate: 0.0010
# Epoch 45/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1486 - val_loss: 1.1460 - learning_rate: 0.0010
# Epoch 46/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1447 - val_loss: 1.1456 - learning_rate: 0.0010
# Epoch 47/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1459 - val_loss: 1.1439 - learning_rate: 0.0010
# Epoch 48/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1464 - val_loss: 1.1423 - learning_rate: 0.0010
# Epoch 49/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1426 - val_loss: 1.1447 - learning_rate: 0.0010
# Epoch 50/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1443 - val_loss: 1.1416 - learning_rate: 0.0010
# Epoch 51/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1440 - val_loss: 1.1426 - learning_rate: 0.0010
# Epoch 52/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1427 - val_loss: 1.1404 - learning_rate: 0.0010
# Epoch 53/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1434 - val_loss: 1.1414 - learning_rate: 0.0010
# Epoch 54/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1426 - val_loss: 1.1395 - learning_rate: 0.0010
# Epoch 55/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1413 - val_loss: 1.1392 - learning_rate: 0.0010
# Epoch 56/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1406 - val_loss: 1.1399 - learning_rate: 0.0010
# Epoch 57/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1400 - val_loss: 1.1407 - learning_rate: 0.0010
# Epoch 58/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1409 - val_loss: 1.1387 - learning_rate: 0.0010
# Epoch 59/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1407 - val_loss: 1.1370 - learning_rate: 0.0010
# Epoch 60/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1384 - val_loss: 1.1369 - learning_rate: 0.0010
# Epoch 61/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1378 - val_loss: 1.1380 - learning_rate: 0.0010
# Epoch 62/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1376 - val_loss: 1.1348 - learning_rate: 0.0010
# Epoch 63/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1364 - val_loss: 1.1392 - learning_rate: 0.0010
# Epoch 64/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 1.1375 - val_loss: 1.1331 - learning_rate: 0.0010
# Epoch 65/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1373 - val_loss: 1.1345 - learning_rate: 0.0010
# Epoch 66/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1355 - val_loss: 1.1337 - learning_rate: 0.0010
# Epoch 67/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1329 - val_loss: 1.1328 - learning_rate: 0.0010
# Epoch 68/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1351 - val_loss: 1.1329 - learning_rate: 0.0010
# Epoch 69/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1343 - val_loss: 1.1324 - learning_rate: 0.0010
# Epoch 70/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1323 - val_loss: 1.1328 - learning_rate: 0.0010
# Epoch 71/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1325 - val_loss: 1.1342 - learning_rate: 0.0010
# Epoch 72/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1356 - val_loss: 1.1307 - learning_rate: 0.0010
# Epoch 73/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1350 - val_loss: 1.1314 - learning_rate: 0.0010
# Epoch 74/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1335 - val_loss: 1.1319 - learning_rate: 0.0010
# Epoch 75/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1301 - val_loss: 1.1303 - learning_rate: 0.0010
# Epoch 76/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1311 - val_loss: 1.1300 - learning_rate: 0.0010
# Epoch 77/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1301 - val_loss: 1.1302 - learning_rate: 0.0010
# Epoch 78/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1318 - val_loss: 1.1307 - learning_rate: 0.0010
# Epoch 79/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1313 - val_loss: 1.1317 - learning_rate: 0.0010
# Epoch 80/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1307 - val_loss: 1.1289 - learning_rate: 0.0010
# Epoch 81/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1321 - val_loss: 1.1288 - learning_rate: 0.0010
# Epoch 82/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1301 - val_loss: 1.1295 - learning_rate: 0.0010
# Epoch 83/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1293 - val_loss: 1.1294 - learning_rate: 0.0010
# Epoch 84/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1286 - val_loss: 1.1272 - learning_rate: 0.0010
# Epoch 85/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1296 - val_loss: 1.1268 - learning_rate: 0.0010
# Epoch 86/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1280 - val_loss: 1.1269 - learning_rate: 0.0010
# Epoch 87/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1308 - val_loss: 1.1273 - learning_rate: 0.0010
# Epoch 88/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1288 - val_loss: 1.1272 - learning_rate: 0.0010
# Epoch 89/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1289 - val_loss: 1.1265 - learning_rate: 0.0010
# Epoch 90/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1272 - val_loss: 1.1280 - learning_rate: 0.0010
# Epoch 91/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1300 - val_loss: 1.1255 - learning_rate: 0.0010
# Epoch 92/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1287 - val_loss: 1.1251 - learning_rate: 0.0010
# Epoch 93/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1257 - val_loss: 1.1239 - learning_rate: 0.0010
# Epoch 94/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1270 - val_loss: 1.1309 - learning_rate: 0.0010
# Epoch 95/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1263 - val_loss: 1.1231 - learning_rate: 0.0010
# Epoch 96/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1284 - val_loss: 1.1270 - learning_rate: 0.0010
# Epoch 97/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1298 - val_loss: 1.1280 - learning_rate: 0.0010
# Epoch 98/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1289 - val_loss: 1.1262 - learning_rate: 0.0010
# Epoch 99/150
# 224/250 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 1.1286
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1285 - val_loss: 1.1302 - learning_rate: 0.0010
# Epoch 100/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1267 - val_loss: 1.1221 - learning_rate: 1.0000e-04
# Epoch 101/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1240 - val_loss: 1.1221 - learning_rate: 1.0000e-04
# Epoch 102/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1210 - val_loss: 1.1219 - learning_rate: 1.0000e-04
# Epoch 103/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1233 - val_loss: 1.1221 - learning_rate: 1.0000e-04
# Epoch 104/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1237 - val_loss: 1.1218 - learning_rate: 1.0000e-04
# Epoch 105/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1233 - val_loss: 1.1217 - learning_rate: 1.0000e-04
# Epoch 106/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1211 - val_loss: 1.1215 - learning_rate: 1.0000e-04
# Epoch 107/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1249 - val_loss: 1.1213 - learning_rate: 1.0000e-04
# Epoch 108/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1235 - val_loss: 1.1216 - learning_rate: 1.0000e-04
# Epoch 109/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1242 - val_loss: 1.1213 - learning_rate: 1.0000e-04
# Epoch 110/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1211 - val_loss: 1.1213 - learning_rate: 1.0000e-04
# Epoch 111/150
# 230/250 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 1.1234
# Epoch 111: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1233 - val_loss: 1.1215 - learning_rate: 1.0000e-04
# Epoch 112/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1227 - val_loss: 1.1211 - learning_rate: 1.0000e-05
# Epoch 113/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1223 - val_loss: 1.1210 - learning_rate: 1.0000e-05
# Epoch 114/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1217 - val_loss: 1.1210 - learning_rate: 1.0000e-05
# Epoch 115/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1243 - val_loss: 1.1210 - learning_rate: 1.0000e-05
# Epoch 116/150
# 236/250 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 1.1228
# Epoch 116: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1227 - val_loss: 1.1210 - learning_rate: 1.0000e-05
# Epoch 117/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1250 - val_loss: 1.1210 - learning_rate: 1.0000e-06
# Epoch 118/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1215 - val_loss: 1.1210 - learning_rate: 1.0000e-06
# Epoch 119/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1198 - val_loss: 1.1210 - learning_rate: 1.0000e-06
# Epoch 120/150
# 241/250 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 1.1236
# Epoch 120: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1236 - val_loss: 1.1210 - learning_rate: 1.0000e-06
# Epoch 121/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1214 - val_loss: 1.1210 - learning_rate: 1.0000e-07
# Epoch 122/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1224 - val_loss: 1.1210 - learning_rate: 1.0000e-07
# Epoch 123/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1216 - val_loss: 1.1210 - learning_rate: 1.0000e-07
# Epoch 124/150
# 241/250 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 1.1221
# Epoch 124: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1221 - val_loss: 1.1210 - learning_rate: 1.0000e-07
# Epoch 125/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1219 - val_loss: 1.1210 - learning_rate: 1.0000e-08
# Epoch 126/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1239 - val_loss: 1.1210 - learning_rate: 1.0000e-08
# Epoch 127/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1219 - val_loss: 1.1210 - learning_rate: 1.0000e-08
# Epoch 128/150
# 237/250 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 1.1231
# Epoch 128: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1231 - val_loss: 1.1210 - learning_rate: 1.0000e-08
# Epoch 129/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1230 - val_loss: 1.1210 - learning_rate: 1.0000e-09
# Epoch 130/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1212 - val_loss: 1.1210 - learning_rate: 1.0000e-09
# Epoch 131/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1219 - val_loss: 1.1210 - learning_rate: 1.0000e-09

# %%
HLT_AE.save_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.save_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')
HLT_AE.load_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.load_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')

# %%
# train L1 model
# train HLT model
history = L1_AE.fit(
    x=datasets['jjJZ1&2&4_train']['L1_data'], 
    y=datasets['jjJZ1&2&4_train']['L1_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['jjJZ1&2&4_train']['weights']
)
# Out:
# Epoch 1/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 1.5992 - val_loss: 1.4184 - learning_rate: 0.0010
# Epoch 2/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4120 - val_loss: 1.4012 - learning_rate: 0.0010
# Epoch 3/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4023 - val_loss: 1.3954 - learning_rate: 0.0010
# Epoch 4/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3924 - val_loss: 1.3863 - learning_rate: 0.0010
# Epoch 5/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3854 - val_loss: 1.3803 - learning_rate: 0.0010
# Epoch 6/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3781 - val_loss: 1.3753 - learning_rate: 0.0010
# Epoch 7/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3733 - val_loss: 1.3692 - learning_rate: 0.0010
# Epoch 8/150
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3675 - val_loss: 1.3636 - learning_rate: 0.0010

# %%
L1_AE.save_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.save_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')
L1_AE.load_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.load_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')

# %% [markdown]
# ## Model Evaluation

# %%
# Pass the datasets through the model

for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue

    dict['HLT_model_outputs'] = HLT_AE.predict(dict['HLT_data'])
    #dict['HLT_latent_reps'] = HLT_encoder.predict(dict['HLT_data'])
    dict['L1_model_outputs'] = L1_AE.predict(dict['L1_data'])
    #dict['L1_latent_reps'] = L1_encoder.predict(dict['L1_data'])
# Out:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 546us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 537us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 537us/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 530us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 541us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 546us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 531us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 539us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 526us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 547us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 541us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 531us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 539us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 539us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 544us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 542us/step
# 18859/18859 ━━━━━━━━━━━━━━━━━━━━ 11s 566us/step
# 18859/18859 ━━━━━━━━━━━━━━━━━━━━ 11s 568us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 27s 568us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 26s 559us/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 2s 750us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 2s 685us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 1s 539us/step
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 1s 546us/step

# %%
def mse_loss(true, prediction):
    loss = np.mean(np.square(true - prediction), axis=-1)
    return loss

# %%
def MSE_AD_score(y, x):
    # masked mse
    mask = (y != 0) & (y != -999)
    _x = x * mask
    _y = y * mask
    # return (mse_loss(_y, _x))
    return (mse_loss(y, x))

# %%
# Calculate the AD scores

for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue

    dict['HLT_AD_scores'] = MSE_AD_score(dict['HLT_data'], dict['HLT_model_outputs'])
    dict['L1_AD_scores'] = MSE_AD_score(dict['L1_data'], dict['L1_model_outputs'])

# %%
# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
# HLT_model_outputs: (10000, 60)
# L1_model_outputs: (10000, 60)
# HLT_AD_scores: (10000,)
# L1_AD_scores: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
# HLT_model_outputs: (70000, 60)
# L1_model_outputs: (70000, 60)
# HLT_AD_scores: (70000,)
# L1_AD_scores: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
# HLT_model_outputs: (50000, 60)
# L1_model_outputs: (50000, 60)
# HLT_AD_scores: (50000,)
# L1_AD_scores: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# EB_data:
# HLT_data: (603486, 60)
# L1_data: (603486, 60)
# passL1: (603486,)
# passHLT: (603486,)
# weights: (603486,)
# HLT_model_outputs: (603486, 60)
# L1_model_outputs: (603486, 60)
# HLT_AD_scores: (603486,)
# L1_AD_scores: (603486,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
# HLT_model_outputs: (1501347, 60)
# L1_model_outputs: (1501347, 60)
# HLT_AD_scores: (1501347,)
# L1_AD_scores: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
# HLT_model_outputs: (15255, 60)
# L1_model_outputs: (15255, 60)
# HLT_AD_scores: (15255,)
# L1_AD_scores: (15255,)
#
# jjJZ1&2&4_train:
# HLT_data: (150000, 60)
# L1_data: (150000, 60)
# passL1: (150000,)
# passHLT: (150000,)
# weights: (150000,)
#
# jjJZ1&2&4_test1:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
# HLT_model_outputs: (75000, 60)
# L1_model_outputs: (75000, 60)
# HLT_AD_scores: (75000,)
# L1_AD_scores: (75000,)
#
# jjJZ1&2&4_test2:
# HLT_data: (75000, 60)
# L1_data: (75000, 60)
# passL1: (75000,)
# passHLT: (75000,)
# weights: (75000,)
# HLT_model_outputs: (75000, 60)
# L1_model_outputs: (75000, 60)
# HLT_AD_scores: (75000,)
# L1_AD_scores: (75000,)

# %%
def ROC_curve(dataset, bkg_type, target_rate=10, plot=True):
    """
    Plots ROC curve and returns AUC, TPR, FPR, and thresholds for each dataset.
    
    inputs: 
    dataset: dictionary containing dataset information
    bkg_type: the background type to calculate over
    plot: whether to plot the ROC curve or not
    
    returns:
    results: dictionary {dataset_names: {'TPR': ..., 'AUC': ..., 'FPR': ..., 'threshold': ...}}
    """
    
    bkg_tag = 'jjJZ1&2&4_test1'
    #target_rate = 10  # 10 Hz pure rate
    plt.figure(figsize=(8.5,6.8))
    
    results = {}
    
    for tag in dataset.keys():
        if tag != bkg_tag and tag != 'jjJZ1&2&4_train':
        
            # Combine true labels, anomaly=1 and background=0
            trueVal = np.concatenate((np.ones(dataset[tag][f'{bkg_type}_AD_scores'].shape[0]), np.zeros(dataset[bkg_tag][f'{bkg_type}_AD_scores'].shape[0])))
            
            # Combine predictions from current dataset and background
            predVal_loss = np.concatenate((dataset[tag][f'{bkg_type}_AD_scores'], dataset[bkg_tag][f'{bkg_type}_AD_scores']))
        
            sample_weights = np.concatenate((dataset[tag]['weights'], dataset[bkg_tag]['weights']))
            
            for i in range(len(predVal_loss)):
                if np.isnan(predVal_loss[i]):
                    predVal_loss[i] = 0
           
            # Calculate ROC curve and AUC, including weights
            fpr_loss, tpr_loss, threshold_loss = sklearn.metrics.roc_curve(y_true=trueVal, y_score=predVal_loss, sample_weight=sample_weights)
            auc_loss = auc(fpr_loss, tpr_loss)

            # Initialize variables for early stopping
            min_diff = float('inf')
            best_idx = 0
            previous_diff = float('inf')
            
            # Iterate over thresholds with early stopping
            for idx, value in enumerate(threshold_loss):
                anomaly_idxs_bkg = dataset[bkg_tag][f'{bkg_type}_AD_scores'] > value
                bkg_rate = 100000 * np.sum(dataset[bkg_tag]['weights'] * (anomaly_idxs_bkg & ~dataset[bkg_tag]['passHLT'])) / np.sum(dataset[bkg_tag]['weights'])
                # Calculate the difference from the target rate
                diff = abs(bkg_rate - target_rate)
                
                # Check if the difference is decreasing
                if diff < min_diff:
                    min_diff = diff
                    best_idx = idx
                else:
                    # If the difference starts increasing, break the loop
                    if diff > previous_diff:
                        print(f'Background rate = {bkg_rate:.3}Hz')
                        break
                
                previous_diff = diff
            
            # Use the best index found
            selected_threshold = threshold_loss[best_idx]
            selected_fpr = fpr_loss[best_idx]
            signal_tpr = tpr_loss[best_idx]
            
            # Store the results
            results[tag] = {
                'TPR': signal_tpr,
                'AUC': auc_loss,
                'FPR': selected_fpr,
                'threshold': selected_threshold
            }
        
            # Plot ROC curve
            if plot:
                plt.plot(fpr_loss, tpr_loss, "-", label='%s (AUC = %.1f%%)' % (tag, auc_loss*100.), linewidth=1.5)

    if plot:
        # Set log scale for x and y axis
        plt.semilogx()
        plt.semilogy()
        
        # Plot aesthetics and layout
        plt.plot(np.linspace(0, 1), np.linspace(0, 1), '--', color='0.75')
        plt.plot([selected_fpr, selected_fpr], [0, 1], '--', color='r')
        plt.ylabel("True Positive Rate", fontsize=16)
        plt.xlabel("False Positive Rate", fontsize=16)
        plt.legend(loc='lower right', fontsize=6)
        plt.grid(True)
        plt.tight_layout()
        plt.title(f'Trained over {bkg_type} objects', fontsize=20)
        plt.show()

    return results

# %%
for target_rate in [10, 200, 1000]:
    print(f'TARGET (PURE) RATE::::: {target_rate}')
    HLT_results = ROC_curve(datasets, bkg_type='HLT', target_rate=target_rate)
    L1_results = ROC_curve(datasets, bkg_type='L1', target_rate=target_rate)

    # L1 Signal Efficiencies

    tags = []
    l1_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            L1_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            L1_anomaly_idxs = datasets[tag]['L1_AD_scores'] > L1_results[tag]['threshold']
            L1_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | L1_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            l1_efficiencies.append(L1_TPR)
            combined_efficiencies.append(L1_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, l1_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(l1_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, L1 Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()



    # Signal Efficiencies

    tags = []
    hlt_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            HLT_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_results[tag]['threshold']
            HLT_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | HLT_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            hlt_efficiencies.append(HLT_TPR)
            combined_efficiencies.append(HLT_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, hlt_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(hlt_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, HLT Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()
    
    # HLT overlaps
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = HLT_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['HLT_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")

    # HLT overlaps
    skip_tags = ['jjJZ1&2&4_train', 'jjJZ1&2&4_test1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = L1_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")
# Out:
# TARGET (PURE) RATE::::: 10
# Background rate = 12.0Hz
# Background rate = 17.3Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 18.7Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 12.0Hz
# Background rate = 37.3Hz
# Background rate = 40.0Hz
# Background rate = 97.3Hz
# Background rate = 12.0Hz
# Normalized by the left bar:
# [1.         1.00052083 1.00031249 1.00154491 1.00019524 1.
#  1.00003673 1.00746965 1.08333333 1.         1.         1.
#  1.00028019]
# Normalized by the left bar:
# [1.         1.00052083 1.00039582 1.00198632 1.00022969 1.
#  1.00003673 1.01493931 1.10648148 1.         3.40146337 1.
#  1.00036024]
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 2e-05
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# A14N23LO:
# HLT overlap: 0.0
# inverse overlap: 1.0002604166666667
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0001
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.85
# inverse overlap: 1.0000624973959418
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.00028571428571428574
# Raw number of events that we tagged as anomalous: 20
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 17
# -----
# qqa:
# HLT overlap: 0.0
# inverse overlap: 1.0004414036636504
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 4e-05
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# ZZ4lep:
# HLT overlap: 0.88
# inverse overlap: 1.000034453849069
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00025
# Raw number of events that we tagged as anomalous: 25
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# Zprime2EJs:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HHbbttHadHad:
# HLT overlap: 0.4
# inverse overlap: 1.000055092371543
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 5e-05
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# jjJZ2:
# HLT overlap: 0.0
# inverse overlap: 1.0102707749766573
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00011
# Raw number of events that we tagged as anomalous: 11
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.1
# inverse overlap: 1.0833333333333333
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.0002
# Raw number of events that we tagged as anomalous: 20
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# EB_data:
# HLT overlap: 0.006725930351134908
# inverse overlap: 1.0961462692874027
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.0007406965530269136
# Raw number of events that we tagged as anomalous: 447
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 8
# -----
# EB_zerobias:
# HLT overlap: 0.0
# inverse overlap: 757.4614769444098
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0006574096461377683
# Raw number of events that we tagged as anomalous: 987
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0006555227794165847
# Raw number of events that we tagged as anomalous: 10
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 10
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.07692307692307693
# inverse overlap: 1.000480326622103
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.00017333333333333334
# Raw number of events that we tagged as anomalous: 13
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# jjJZ4:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 3e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# A14N23LO:
# HLT overlap: 0.0
# inverse overlap: 1.0005208333333333
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0002
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.8125
# inverse overlap: 1.000312486979709
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.001142857142857143
# Raw number of events that we tagged as anomalous: 80
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 65
# -----
# qqa:
# HLT overlap: 0.0
# inverse overlap: 1.0015449128227765
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00014
# Raw number of events that we tagged as anomalous: 7
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# ZZ4lep:
# HLT overlap: 0.853448275862069
# inverse overlap: 1.0001952384780586
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00116
# Raw number of events that we tagged as anomalous: 116
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 99
# -----
# Zprime2EJs:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HHbbttHadHad:
# HLT overlap: 0.5
# inverse overlap: 1.0000367282476954
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 4e-05
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# jjJZ2:
# HLT overlap: 0.0
# inverse overlap: 1.007469654528478
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 8e-05
# Raw number of events that we tagged as anomalous: 8
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.05263157894736842
# inverse overlap: 1.0833333333333333
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00019
# Raw number of events that we tagged as anomalous: 19
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_data:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_zerobias:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_passHLT:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.0
# inverse overlap: 1.0002801905295602
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 9.333333333333333e-05
# Raw number of events that we tagged as anomalous: 7
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# TARGET (PURE) RATE::::: 200
# /tmp/ipykernel_63206/3559298588.py:126: RuntimeWarning: invalid value encountered in scalar divide
#   HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
# /tmp/ipykernel_63206/3559298588.py:155: RuntimeWarning: invalid value encountered in scalar divide
#   HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
# Background rate = 2.01e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.04e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.07e+02Hz
# Background rate = 2.05e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.01e+02Hz
# Background rate = 2.03e+02Hz
# Background rate = 2.07e+02Hz
# Background rate = 2.09e+02Hz
# Background rate = 2.01e+02Hz
# Normalized by the left bar:
# [1.00003054 1.02447917 1.00706221 1.04921651 1.00231989 1.00003406
#  1.00091821 1.23902894 2.68055556 1.00238151 6.80985045 1.
#  1.00648441]
# Normalized by the left bar:
# [1.00003054 1.03515625 1.00954127 1.07525932 1.00318124 1.00007947
#  1.00157931 1.37815126 3.60185185 1.00385323 9.47978952 1.
#  1.00972661]
# -----
# jjJZ4:
# HLT overlap: 0.9722222222222222
# inverse overlap: 1.000020361829714
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00072
# Raw number of events that we tagged as anomalous: 72
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 70
# -----
# A14N23LO:
# HLT overlap: 0.3888888888888889
# inverse overlap: 1.0028645833333334
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0018
# Raw number of events that we tagged as anomalous: 18
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 7
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7557251908396947
# inverse overlap: 1.0013332777800925
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.003742857142857143
# Raw number of events that we tagged as anomalous: 262
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 198
# -----
# qqa:
# HLT overlap: 0.09523809523809523
# inverse overlap: 1.0083866696093577
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00084
# Raw number of events that we tagged as anomalous: 42
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4
# -----
# ZZ4lep:
# HLT overlap: 0.8763440860215054
# inverse overlap: 1.000528292352394
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00372
# Raw number of events that we tagged as anomalous: 372
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 326
# -----
# Zprime2EJs:
# HLT overlap: 0.8333333333333334
# inverse overlap: 1.0000227045681591
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00012
# Raw number of events that we tagged as anomalous: 12
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 10
# -----
# HHbbttHadHad:
# HLT overlap: 0.4155844155844156
# inverse overlap: 1.0008263855731443
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00077
# Raw number of events that we tagged as anomalous: 77
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 32
# -----
# jjJZ2:
# HLT overlap: 0.0136986301369863
# inverse overlap: 1.2016806722689075
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00219
# Raw number of events that we tagged as anomalous: 219
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ1:
# HLT overlap: 0.00847457627118644
# inverse overlap: 2.625
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00354
# Raw number of events that we tagged as anomalous: 354
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# EB_data:
# HLT overlap: 0.013237137444967143
# inverse overlap: 1.8848042303559622
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.009198224979535565
# Raw number of events that we tagged as anomalous: 5551
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 148
# -----
# EB_zerobias:
# HLT overlap: 6.418985605679472e-06
# inverse overlap: 7527.012691988404
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.007028355203693749
# Raw number of events that we tagged as anomalous: 10552
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 14
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.010619469026548672
# Raw number of events that we tagged as anomalous: 162
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 162
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.11956521739130435
# inverse overlap: 1.006484409398391
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.0024533333333333334
# Raw number of events that we tagged as anomalous: 184
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# jjJZ4:
# HLT overlap: 0.9651162790697675
# inverse overlap: 1.000030542744571
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00086
# Raw number of events that we tagged as anomalous: 86
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 83
# -----
# A14N23LO:
# HLT overlap: 0.3088235294117647
# inverse overlap: 1.0244791666666666
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0136
# Raw number of events that we tagged as anomalous: 136
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 42
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7165551839464883
# inverse overlap: 1.0070622057414274
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.017085714285714287
# Raw number of events that we tagged as anomalous: 1196
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 857
# -----
# qqa:
# HLT overlap: 0.06694560669456066
# inverse overlap: 1.0492165084970204
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00478
# Raw number of events that we tagged as anomalous: 239
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 16
# -----
# ZZ4lep:
# HLT overlap: 0.8644295302013423
# inverse overlap: 1.002319892503991
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.0149
# Raw number of events that we tagged as anomalous: 1490
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1288
# -----
# Zprime2EJs:
# HLT overlap: 0.9473684210526315
# inverse overlap: 1.0000340568522386
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00057
# Raw number of events that we tagged as anomalous: 57
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 54
# -----
# HHbbttHadHad:
# HLT overlap: 0.4791666666666667
# inverse overlap: 1.0009182061923825
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00096
# Raw number of events that we tagged as anomalous: 96
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 46
# -----
# jjJZ2:
# HLT overlap: 0.011583011583011582
# inverse overlap: 1.239028944911298
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00259
# Raw number of events that we tagged as anomalous: 259
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# jjJZ1:
# HLT overlap: 0.016260162601626018
# inverse overlap: 2.6805555555555554
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00369
# Raw number of events that we tagged as anomalous: 369
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 6
# -----
# EB_data:
# HLT overlap: 0.09209397951013244
# inverse overlap: 1.0023815102120792
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 5.302525659253073e-05
# Raw number of events that we tagged as anomalous: 32
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# EB_zerobias:
# HLT overlap: 0.0011768909391567212
# inverse overlap: 6.809850450207613
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 2.7974878559053968e-05
# Raw number of events that we tagged as anomalous: 42
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.00032776138970829236
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.10989010989010989
# inverse overlap: 1.006484409398391
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.002426666666666667
# Raw number of events that we tagged as anomalous: 182
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 20
# TARGET (PURE) RATE::::: 1000
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1.04e+03Hz
# Background rate = 1e+03Hz
# Normalized by the left bar:
# [ 1.00015271  1.09166667  1.02608225  1.24983447  1.00868237  1.00030651
#   1.00662945  2.3155929   8.8287037   1.02085073 24.73281102  1.
#   1.03310251]
# Normalized by the left bar:
# [ 1.00031561  1.13854167  1.03758177  1.39836681  1.01248378  1.00055626
#   1.01155103  3.22408964 13.30555556  1.03216639 46.69424135  1.
#   1.05219549]
# -----
# jjJZ4:
# HLT overlap: 0.9777777777777777
# inverse overlap: 1.000142532807998
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.0063
# Raw number of events that we tagged as anomalous: 630
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 616
# -----
# A14N23LO:
# HLT overlap: 0.3968253968253968
# inverse overlap: 1.0197916666666667
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0126
# Raw number of events that we tagged as anomalous: 126
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 50
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7389380530973452
# inverse overlap: 1.0061455772676138
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.016142857142857143
# Raw number of events that we tagged as anomalous: 1130
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 835
# -----
# qqa:
# HLT overlap: 0.14942528735632185
# inverse overlap: 1.0653277422202605
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00696
# Raw number of events that we tagged as anomalous: 348
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 52
# -----
# ZZ4lep:
# HLT overlap: 0.8798988621997471
# inverse overlap: 1.0021820771077141
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.01582
# Raw number of events that we tagged as anomalous: 1582
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1392
# -----
# Zprime2EJs:
# HLT overlap: 0.7954545454545454
# inverse overlap: 1.000204341113432
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00088
# Raw number of events that we tagged as anomalous: 88
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 70
# -----
# HHbbttHadHad:
# HLT overlap: 0.46415770609318996
# inverse overlap: 1.0054908730304477
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00558
# Raw number of events that we tagged as anomalous: 558
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 259
# -----
# jjJZ2:
# HLT overlap: 0.012859304084720122
# inverse overlap: 2.2184873949579833
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.01322
# Raw number of events that we tagged as anomalous: 1322
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 17
# -----
# jjJZ1:
# HLT overlap: 0.005541871921182266
# inverse overlap: 8.476851851851851
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.01624
# Raw number of events that we tagged as anomalous: 1624
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 9
# -----
# EB_data:
# HLT overlap: 0.011740550569627107
# inverse overlap: 4.1301812847148
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.03687078076376254
# Raw number of events that we tagged as anomalous: 22251
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 477
# -----
# EB_zerobias:
# HLT overlap: 5.940714572256149e-06
# inverse overlap: 23747.761247618917
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.023979799473406213
# Raw number of events that we tagged as anomalous: 36002
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 41
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.03389052769583743
# Raw number of events that we tagged as anomalous: 517
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 517
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.1783783783783784
# inverse overlap: 1.0304206860665253
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.012333333333333333
# Raw number of events that we tagged as anomalous: 925
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 165
# -----
# jjJZ4:
# HLT overlap: 0.9759229534510433
# inverse overlap: 1.0001527137228552
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00623
# Raw number of events that we tagged as anomalous: 623
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 608
# -----
# A14N23LO:
# HLT overlap: 0.3282442748091603
# inverse overlap: 1.0916666666666666
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0524
# Raw number of events that we tagged as anomalous: 524
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 172
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.6979493365500603
# inverse overlap: 1.0260822465730595
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.05921428571428571
# Raw number of events that we tagged as anomalous: 4145
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2893
# -----
# qqa:
# HLT overlap: 0.09800796812749003
# inverse overlap: 1.249834473626131
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.0251
# Raw number of events that we tagged as anomalous: 1255
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 123
# -----
# ZZ4lep:
# HLT overlap: 0.8581081081081081
# inverse overlap: 1.0086823699654313
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.05328
# Raw number of events that we tagged as anomalous: 5328
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4572
# -----
# Zprime2EJs:
# HLT overlap: 0.9137380191693291
# inverse overlap: 1.000306511670148
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00313
# Raw number of events that we tagged as anomalous: 313
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 286
# -----
# HHbbttHadHad:
# HLT overlap: 0.44716692189892804
# inverse overlap: 1.0066294487090022
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00653
# Raw number of events that we tagged as anomalous: 653
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 292
# -----
# jjJZ2:
# HLT overlap: 0.015373864430468204
# inverse overlap: 2.315592903828198
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.01431
# Raw number of events that we tagged as anomalous: 1431
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# jjJZ1:
# HLT overlap: 0.007046388725778039
# inverse overlap: 8.828703703703704
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.01703
# Raw number of events that we tagged as anomalous: 1703
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 12
# -----
# EB_data:
# HLT overlap: 0.07240947949424532
# inverse overlap: 1.0208507339167217
# Weighted percentage of events that passed some HLT trigger: 0.02475948075017482
# Weighted percentage of events that we tagged as anomalous: 0.00029992410760150195
# Raw number of events that we tagged as anomalous: 181
# Raw number of events that passed some HLT trigger: 14942
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 20
# -----
# EB_zerobias:
# HLT overlap: 0.000721728883783219
# inverse overlap: 24.73281102387139
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.00017850636794824914
# Raw number of events that we tagged as anomalous: 268
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0016388069485414618
# Raw number of events that we tagged as anomalous: 25
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 25
# -----
# jjJZ1&2&4_test2:
# HLT overlap: 0.16548940464177597
# inverse overlap: 1.0331025097066004
# Weighted percentage of events that passed some HLT trigger: 0.33310666666666666
# Weighted percentage of events that we tagged as anomalous: 0.013213333333333334
# Raw number of events that we tagged as anomalous: 991
# Raw number of events that passed some HLT trigger: 24983
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 164

# %%
#HLT
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
#HLT
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
#HLT
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n] > 1) and (HLT_electron_mults[tag][n] > 1) and (HLT_muon_mults[tag][n] > 1) and (HLT_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    ax1.hist(HLT_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1

plt.xticks(np.arange(0, 2000,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
#L1
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n] > 1) and (L1_electron_mults[tag][n] > 1) and (L1_muon_mults[tag][n] > 1) and (L1_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_test1': continue
    if tag == 'jjJZ1&2&4_train': continue
    ax1.hist(L1_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1
plt.xlim(0, 800)
plt.xticks(np.arange(0, 800,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
import ROOT
# Out:
# C system headers (glibc/Xcode/Windows SDK) must be installed.
# In file included from input_line_4:36:
# /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/include/c++/cassert:44:10: fatal error: 'assert.h' file not found
# #include <assert.h>
#          ^~~~~~~~~~
# input_line_35:1:10: fatal error: 'dlfcn.h' file not found
# #include "dlfcn.h"
#          ^~~~~~~~~

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "HLT" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/Root/HLT', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ4max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTA14N23LOmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTHAHMggfZdZd2l2numax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTqqamax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTZZ4lepmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTZprime2EJsmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTHHbbttHadHadmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ2max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_datamax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_zerobiasmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTEB_passHLTmax pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1&2&4_test1max pt v ad score  _plot.png has been created
# Info in <TCanvas::Print>: png file /home/jovyan/Root/HLT/HLTjjJZ1&2&4_test2max pt v ad score  _plot.png has been created

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "L1" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ4max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ4max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1A14N23LOmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1A14N23LOmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2numax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2numax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1qqamax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1qqamax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1ZZ4lepmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1ZZ4lepmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1Zprime2EJsmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1Zprime2EJsmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HHbbttHadHadmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HHbbttHadHadmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ2max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ2max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datamax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datamax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_zerobiasmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_zerobiasmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_passHLTmax pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_passHLTmax pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1max pt v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2max pt v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2max pt v ad score  _plot.png

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "HLT" + tag + "jet mult v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_jet_mults[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ4jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ4jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTA14N23LOjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTA14N23LOjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTHAHMggfZdZd2l2nujet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTHAHMggfZdZd2l2nujet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTqqajet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTqqajet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTZZ4lepjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTZZ4lepjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTZprime2EJsjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTZprime2EJsjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTHHbbttHadHadjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTHHbbttHadHadjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ2jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ2jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_datajet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_datajet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_zerobiasjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_zerobiasjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTEB_passHLTjet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTEB_passHLTjet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test1jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test1jet mult v ad score  _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test2jet mult v ad score  _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/HLTjjJZ1&2&4_test2jet mult v ad score  _plot.png

# %%
for tag, dict in datasets.items():
    if tag == 'jjJZ1&2&4_train': continue
    title = "L1" + tag + "jet mult v ad score "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(L1_jet_mults[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
# Out:
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ4jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ4jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1A14N23LOjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1A14N23LOjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2nujet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HAHMggfZdZd2l2nujet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1qqajet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1qqajet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1ZZ4lepjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1ZZ4lepjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1Zprime2EJsjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1Zprime2EJsjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1HHbbttHadHadjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1HHbbttHadHadjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ2jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ2jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_datajet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_datajet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_zerobiasjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_zerobiasjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1EB_passHLTjet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1EB_passHLTjet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test1jet mult v ad score _plot.png
# python ERROR: cannot open image file "/home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2jet mult v ad score _plot.png" for writing. Please check permissions.
# Error in <TASImage::WriteImage>: error writing file /home/jovyan/RootPlots/Final5/L1jjJZ1&2&4_test2jet mult v ad score _plot.png

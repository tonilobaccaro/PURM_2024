# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import random
import sklearn
import collections
from sklearn.model_selection import train_test_split
import json
import pylab
from scipy.optimize import curve_fit
from tensorflow.keras import layers, Model
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from sklearn.metrics import roc_curve, auc
import matplotlib
import matplotlib.patches as mpatches
#import shap
import os
import pandas as pd
#improve gpu memory usage
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 2024-10-05 15:08:17.893699: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-05 15:08:18.998362: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Set matplotlib default color cycle
new_color_cycle = [
#jjJZ4
    '#4f2ca8',
#A14N23LO
    '#b45f06',
#HAHMggf
    '#ff0000',
#qqa
    '#d4d400',
#ZZ4lep
    '#294a18',
#Zprime2EJs
    '#00de00',
#HHbbttHadHad
    '#5b0f00',
#jjJZ2
  '#ca7dff',
#jjJZ1
  '#d201d2',
#data
# '#3232ff', 
#zerobias
    '#002a75',
#passedHLT
    '#00cdcd',
#jjJZ124
    '#8e1d55',
#test 2
    '#7f7f7f'
]

# You can then apply this new color cycle to your matplotlib plots
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=new_color_cycle)

# %% [markdown]
# ## Read Data Files

# %%
# This is the list that will hold all of the data 
datasets = {}

# %%
# Read Monte Carlo Simulated Collisions

data_path = '/home/jovyan/MC_data/'

for filename in os.listdir(data_path):

    if filename.startswith('N') or filename.startswith('.'): continue

    dataset_tag = filename.split('_')[0]
    
    with h5py.File(data_path+filename, 'r') as hf:
        HLT_jets = hf['HLT_jets'][:]
        L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
        L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
        HLT_electrons = hf['HLT_electrons'][:]
        LRT_electrons = hf['LRT_electrons'][:]
        L1_egammas = hf['L1_egammas'][:]
        HLT_muons = hf['HLT_muons'][:]
        LRT_muons = hf['LRT_muons'][:]
        L1_muons = hf['L1_muons'][:]
        L1_eFex_taus = hf['L1_eFex_taus'][:]
        L1_jFex_taus = hf['L1_jFex_taus'][:]
        HLT_photons = hf['HLT_photons'][:]
        HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 4)  # Broadcasting MET
        L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
        pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
        pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]

        HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, [0, 2, 3]], HLT_muons[:, :3, [0, 2, 3]], HLT_photons[:, :3, [0, 2, 3]], HLT_MET[:, :, [0, 2, 3]]], axis=1)
        L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)
        
        datasets[dataset_tag] = {
            'HLT_data': HLT_objects,
            'L1_data': L1_objects,
            'passL1': pass_L1_unprescaled==1,
            'passHLT': pass_HLT_unprescaled==1,
            'weights': np.ones(len(HLT_objects)),
        }

        if len(HLT_objects) > 100000:
            datasets[dataset_tag] = {key: value[:100000] for key, value in datasets[dataset_tag].items()}

# %%
# Read 2024 EB data

with h5py.File('/home/jovyan/EB_data/EB_ntuples_08-13-2024-003.h5', 'r') as hf:
    HLT_jets = hf['HLT_jets'][:]
    ofl_jets = hf['ofl_jets'][:]
    L1_jFexSR_jets = hf['L1_jFexSR_jets'][:]
    L1_jFexLR_jets = hf['L1_jFexLR_jets'][:]
    HLT_electrons = hf['HLT_electrons'][:]
    LRT_electrons = hf['LRT_electrons'][:]
    ofl_electrons = hf['ofl_electrons'][:]
    L1_egammas = hf['L1_egammas'][:]
    HLT_muons = hf['HLT_muons'][:]
    LRT_muons = hf['LRT_muons'][:]
    ofl_muons = hf['ofl_muons'][:]
    L1_muons = hf['L1_muons'][:]
    L1_eFex_taus = hf['L1_eFex_taus'][:]
    L1_jFex_taus = hf['L1_jFex_taus'][:]
    HLT_photons = hf['HLT_photons'][:]
    ofl_photons = hf['ofl_photons'][:]
    HLT_MET = hf['HLT_MET'][:].reshape(-1, 1, 3)  # Broadcasting MET
    L1_MET = hf['L1_MET'][:].reshape(-1, 1, 3)
    pass_L1_unprescaled = hf["pass_L1_unprescaled"][:]
    pass_HLT_unprescaled = hf["pass_HLT_unprescaled"][:]
    EB_weights = hf["EB_weights"][:]
    event_number = hf["event_number"][:]
    run_number = hf["run_number"][:]

HLT_objects = np.concatenate([HLT_jets[:, :, [0, 2, 3]], HLT_electrons[:, :3, :], HLT_muons[:, :3, :], HLT_photons[:, :3, :], HLT_MET], axis=1)
L1_objects = np.concatenate([L1_jFexSR_jets[:, :, :], L1_egammas[:, :3, :], L1_muons[:, :3, :], L1_eFex_taus[:, :3, :], L1_MET], axis=1)



# Indices of events that passed L1
pass_L1_idxs = (pass_L1_unprescaled == 1)

# Indices of events that passed HLT
pass_HLT_idxs = (pass_HLT_unprescaled == 1)



datasets['EB_data'] = {
    'HLT_data': HLT_objects[pass_L1_idxs] ,
    'L1_data': L1_objects[pass_L1_idxs] ,
    'passL1': pass_L1_idxs[pass_L1_idxs],
    'passHLT': pass_HLT_idxs[pass_L1_idxs],
    'weights': EB_weights[pass_L1_idxs],
}

datasets['EB_zerobias'] = {
    'HLT_data': HLT_objects[~pass_L1_idxs] ,
    'L1_data': L1_objects[~pass_L1_idxs] ,
    'passL1': pass_L1_idxs[~pass_L1_idxs],
    'passHLT': pass_HLT_idxs[~pass_L1_idxs],
    'weights': EB_weights[~pass_L1_idxs],
}

datasets['EB_passHLT'] = {
    'HLT_data': HLT_objects[pass_HLT_idxs] ,
    'L1_data': L1_objects[pass_HLT_idxs] ,
    'passL1': pass_L1_idxs[pass_HLT_idxs],
    'passHLT': pass_HLT_idxs[pass_HLT_idxs],
    'weights': EB_weights[pass_HLT_idxs],
}

# %% [markdown]
# ## Data Processing

# %%
#create combo of jjJZ4 & jjJZ2 & jjJZ1

datasets['jjJZ1&2&4'] = {
    'HLT_data': np.concatenate((datasets['jjJZ1']['HLT_data'],datasets['jjJZ2']['HLT_data'],datasets['jjJZ4']['HLT_data'])),
    'L1_data': np.concatenate((datasets['jjJZ1']['L1_data'],datasets['jjJZ2']['L1_data'],datasets['jjJZ4']['L1_data'])) ,
    'passL1': np.concatenate((datasets['jjJZ1']['passL1'],datasets['jjJZ2']['passL1'],datasets['jjJZ4']['passL1'])),
    'passHLT': np.concatenate((datasets['jjJZ1']['passHLT'],datasets['jjJZ2']['passHLT'],datasets['jjJZ4']['passHLT'])),
    'weights': np.concatenate((datasets['jjJZ1']['weights'],datasets['jjJZ2']['weights'],datasets['jjJZ4']['weights'])),
}

# %%
"""Multiply the pt of the L1 muons by 1000 to get them into the right units."""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label == 'L1_data':
            data[:, 13:16, 0] *= 1000

# %%
# Split EB data in train, test

random_seed = 789247

indices = np.arange(len(datasets['EB_data']['HLT_data']))
train_indices, _indices = train_test_split(indices, train_size=0.5, random_state=random_seed)
test1_indices, test2_indices = train_test_split(_indices, train_size=0.5, random_state=random_seed)

datasets['EB_datatrain'] = {key:value[train_indices] for key, value in datasets['EB_data'].items()}
datasets['EB_datatest1'] = {key:value[test1_indices] for key, value in datasets['EB_data'].items()}
datasets['EB_datatest2'] = {key:value[test2_indices] for key, value in datasets['EB_data'].items()}

del datasets['EB_data']

# %%
#save pt values before normalization for 2d histogram of max pt vs. anomaly score & efficiency plots
HLT_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['HLT_data'][i,j,0]:
                temp[i] = datasets[tag]['HLT_data'][i,j,0]
    HLT_max_pt_vals[tag] = temp
L1_max_pt_vals = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(20):
            if temp[i] < datasets[tag]['L1_data'][i,j,0]:
                temp[i] = datasets[tag]['L1_data'][i,j,0]
    L1_max_pt_vals[tag] = temp
HLT_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_jet_mults[tag] = temp
L1_jet_mults = {}
for tag,dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_jet_mults[tag] = temp
HLT_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(10,13):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_electron_mults[tag] = temp
L1_electron_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(10,13):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_electron_mults[tag] = temp
HLT_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(13,16):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_muon_mults[tag] = temp
L1_muon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(13,16):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_muon_mults[tag] = temp
HLT_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['HLT_data']))
    for i in range(len(datasets[tag]['HLT_data'])):
        for j in range(16,19):
            if datasets[tag]['HLT_data'][i][j][0] > 0:
                temp[i] += 1
    HLT_photon_mults[tag] = temp
L1_photon_mults = {}
for tag, dict in datasets.items():
    temp = np.zeros(len(datasets[tag]['L1_data']))
    for i in range(len(datasets[tag]['L1_data'])):
        for j in range(16,19):
            if datasets[tag]['L1_data'][i][j][0] > 0:
                temp[i] += 1
    L1_photon_mults[tag] = temp

# %%
for tag, dict in datasets.items():
    print(f'\n{tag}:')
    for key, value in dict.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 20, 3)
# L1_data: (10000, 20, 3)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 20, 3)
# L1_data: (70000, 20, 3)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 20, 3)
# L1_data: (50000, 20, 3)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 20, 3)
# L1_data: (100000, 20, 3)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_zerobias:
# HLT_data: (1501347, 20, 3)
# L1_data: (1501347, 20, 3)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 20, 3)
# L1_data: (15255, 20, 3)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4:
# HLT_data: (300000, 20, 3)
# L1_data: (300000, 20, 3)
# passL1: (300000,)
# passHLT: (300000,)
# weights: (300000,)
#
# EB_datatrain:
# HLT_data: (301743, 20, 3)
# L1_data: (301743, 20, 3)
# passL1: (301743,)
# passHLT: (301743,)
# weights: (301743,)
#
# EB_datatest1:
# HLT_data: (150871, 20, 3)
# L1_data: (150871, 20, 3)
# passL1: (150871,)
# passHLT: (150871,)
# weights: (150871,)
#
# EB_datatest2:
# HLT_data: (150872, 20, 3)
# L1_data: (150872, 20, 3)
# passL1: (150872,)
# passHLT: (150872,)
# weights: (150872,)

# %%
"""Met bias. For some events, MET was not calculated, so was written as -999.
We don't want this to impact training, so we map 0 --> 0.001 and -999 --> 0"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):

            # MET: 0 --> 0.001 and -999 --> 0 and nan --> 0
            MET_zeros = (data[:, 19, 0] == 0) # indices where MET=0
            MET_999 = ((data[:, 19, 0] == -999)) # indices where MET=-999 (not calculated)
            MET_nan = np.isnan(data[:, 19, 2])
            data[MET_zeros, 19, 0] = 0.001
            data[MET_999, 19, :] = 0
            data[MET_nan, 19, :] = 0

# %%
"""Normalize pt such that sum(pt) = 1 in each event"""
for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
#             # sum of the pt and E in each event
            sum_pt = np.sum(data[:, :, 0], axis=1, keepdims=True)
        
#             # If the sum is 0, set the sum to 1 to avoid division by 0
            sum_pt[sum_pt == 0] = 1
        
#             # Divide pt and E by their respective sums, multiply by 10
            data[:, :, 0] *= (1/sum_pt)

# %%
## Autoencoder Architecture

# %%
# Flatten ndarrays for use in DNN

for tag, dict in datasets.items():
    for label, data in dict.items():
        if label.endswith('data'):
            datasets[tag][label] = np.reshape(data, newshape=(-1, 60))

# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
#
# jjJZ1&2&4:
# HLT_data: (300000, 60)
# L1_data: (300000, 60)
# passL1: (300000,)
# passHLT: (300000,)
# weights: (300000,)
#
# EB_datatrain:
# HLT_data: (301743, 60)
# L1_data: (301743, 60)
# passL1: (301743,)
# passHLT: (301743,)
# weights: (301743,)
#
# EB_datatest1:
# HLT_data: (150871, 60)
# L1_data: (150871, 60)
# passL1: (150871,)
# passHLT: (150871,)
# weights: (150871,)
#
# EB_datatest2:
# HLT_data: (150872, 60)
# L1_data: (150872, 60)
# passL1: (150872,)
# passHLT: (150872,)
# weights: (150872,)

# %%
def create_AE(input_dim, h_dim_1, h_dim_2, latent_dim):
    
     # Encoder
    encoder_inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(h_dim_1, activation='relu')(encoder_inputs)
    x = layers.Dense(h_dim_2, activation='relu')(x)
    z = layers.Dense(latent_dim, activation='relu')(x)
    
    encoder = Model(inputs=encoder_inputs, outputs=z)

    # Decoder
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(h_dim_2, activation='relu')(decoder_inputs)
    x = layers.Dense(h_dim_1, activation='relu')(x)
    outputs = layers.Dense(input_dim)(x)

    decoder = Model(inputs=decoder_inputs, outputs=outputs)

    ae_outputs = decoder(encoder(encoder_inputs))
    ae = Model(encoder_inputs, outputs=ae_outputs)
    return ae, encoder, decoder

# %%
def loss_fn(y_true, y_pred):
    """masked mse"""
    # mask0 = K.cast(K.not_equal(y_true, 0), K.floatx())
    # maskMET = K.cast(K.not_equal(y_true, -999), K.floatx())
    # mask = mask0 * maskMET
    # squared_difference = K.square(mask * (y_pred - y_true))
    squared_difference = K.square((y_pred - y_true))
    return K.mean(squared_difference)

# %%
# Initialize models
INPUT_DIM = datasets['EB_datatrain']['HLT_data'].shape[1]
H_DIM_1 = 32
H_DIM_2 = 8
LATENT_DIM = 2

HLT_AE, HLT_encoder, HLT_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)
L1_AE, L1_encoder, L1_decoder = create_AE(input_dim=INPUT_DIM, h_dim_1=H_DIM_1, h_dim_2=H_DIM_2, latent_dim=LATENT_DIM)

HLT_AE.summary()
L1_AE.summary()
# Out:
# 2024-10-05 15:14:26.967123: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20732 MB memory:  -> device: 0, name: NVIDIA A10, pci bus id: 0000:41:00.0, compute capability: 8.6
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_3 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 60)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_7 (Functional)       │ (None, 2)              │         2,234 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_9 (Functional)       │ (None, 60)             │         2,292 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,526 (17.68 KB)
#  Trainable params: 4,526 (17.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# Define callbacks: early stopping and learning rate scheduler

STOP_PATIENCE = 8
LR_PATIENCE = 4

early_stopping = EarlyStopping(patience=STOP_PATIENCE, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=LR_PATIENCE, verbose=1)

callbacks = [early_stopping, reduce_lr]

# %%
NUM_EPOCHS = 150
BATCH_SIZE = 512

# %%
#Model Training

# %%
HLT_AE.compile(optimizer='adam', loss=loss_fn)
L1_AE.compile(optimizer='adam', loss=loss_fn)

# %%
# train HLT model
history = HLT_AE.fit(
    x=datasets['EB_datatrain']['HLT_data'], 
    y=datasets['EB_datatrain']['HLT_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['EB_datatrain']['weights']
)
# Out:
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728141269.777280     588 service.cc:145] XLA service 0x7f276c00b730 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728141269.777324     588 service.cc:153]   StreamExecutor device (0): NVIDIA A10, Compute Capability 8.6
# 2024-10-05 15:14:29.815532: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-05 15:14:30.091695: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728141270.653117     780 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_504', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1728141270.715868     765 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_504', 8 bytes spill stores, 8 bytes spill loads
# 178/501 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 1778.0002
# I0000 00:00:1728141272.466756     588 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 491/501 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 1705.9041
# I0000 00:00:1728141273.421486     991 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_491', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1728141273.459190     964 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_491', 20 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1728141273.498733     989 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'triton_gemm_dot_491', 12 bytes spill stores, 12 bytes spill loads
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 1703.7548 - val_loss: 1399.2426 - learning_rate: 0.0010
# Epoch 2/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 991us/step - loss: 1489.3783 - val_loss: 1386.4535 - learning_rate: 0.0010
# Epoch 3/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 1469.6825 - val_loss: 1371.6685 - learning_rate: 0.0010
# Epoch 4/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1480.2142 - val_loss: 1357.7148 - learning_rate: 0.0010
# Epoch 5/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1456.7603 - val_loss: 1348.6554 - learning_rate: 0.0010
# Epoch 6/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1446.5161 - val_loss: 1344.8241 - learning_rate: 0.0010
# Epoch 7/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1402.3824 - val_loss: 1340.3959 - learning_rate: 0.0010
# Epoch 8/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1430.4604 - val_loss: 1338.4805 - learning_rate: 0.0010
# Epoch 9/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1428.8309 - val_loss: 1334.7977 - learning_rate: 0.0010
# Epoch 10/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - loss: 1409.7622 - val_loss: 1333.5029 - learning_rate: 0.0010
# Epoch 11/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 999us/step - loss: 1411.6166 - val_loss: 1330.0682 - learning_rate: 0.0010
# Epoch 12/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - loss: 1426.6208 - val_loss: 1326.9187 - learning_rate: 0.0010
# Epoch 13/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - loss: 1404.9763 - val_loss: 1322.9683 - learning_rate: 0.0010
# Epoch 14/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 992us/step - loss: 1391.2212 - val_loss: 1320.5662 - learning_rate: 0.0010
# Epoch 15/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1401.8503 - val_loss: 1317.7823 - learning_rate: 0.0010
# Epoch 16/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - loss: 1394.1151 - val_loss: 1314.5066 - learning_rate: 0.0010
# Epoch 17/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 968us/step - loss: 1382.2960 - val_loss: 1312.5713 - learning_rate: 0.0010
# Epoch 18/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 999us/step - loss: 1389.6287 - val_loss: 1311.0864 - learning_rate: 0.0010
# Epoch 19/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1400.3833 - val_loss: 1308.6967 - learning_rate: 0.0010
# Epoch 20/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1396.7826 - val_loss: 1306.8280 - learning_rate: 0.0010
# Epoch 21/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1404.2528 - val_loss: 1304.6179 - learning_rate: 0.0010
# Epoch 22/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1386.4435 - val_loss: 1303.5063 - learning_rate: 0.0010
# Epoch 23/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1399.5770 - val_loss: 1302.1748 - learning_rate: 0.0010
# Epoch 24/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1361.8485 - val_loss: 1299.0980 - learning_rate: 0.0010
# Epoch 25/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1410.1903 - val_loss: 1300.8080 - learning_rate: 0.0010
# Epoch 26/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1380.7848 - val_loss: 1298.4500 - learning_rate: 0.0010
# Epoch 27/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 1378.1370 - val_loss: 1297.1006 - learning_rate: 0.0010
# Epoch 28/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 992us/step - loss: 1376.6829 - val_loss: 1296.0776 - learning_rate: 0.0010
# Epoch 29/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1367.8228 - val_loss: 1295.3607 - learning_rate: 0.0010
# Epoch 30/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1381.4543 - val_loss: 1293.6083 - learning_rate: 0.0010
# Epoch 31/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1391.7277 - val_loss: 1294.0007 - learning_rate: 0.0010
# Epoch 32/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1373.2935 - val_loss: 1292.9126 - learning_rate: 0.0010
# Epoch 33/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 998us/step - loss: 1370.5756 - val_loss: 1292.8115 - learning_rate: 0.0010
# Epoch 34/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1363.1451 - val_loss: 1291.7729 - learning_rate: 0.0010
# Epoch 35/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 998us/step - loss: 1371.7865 - val_loss: 1290.3540 - learning_rate: 0.0010
# Epoch 36/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 991us/step - loss: 1378.2804 - val_loss: 1289.4368 - learning_rate: 0.0010
# Epoch 37/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 1378.8696 - val_loss: 1289.1379 - learning_rate: 0.0010
# Epoch 38/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 999us/step - loss: 1392.4886 - val_loss: 1288.7681 - learning_rate: 0.0010
# Epoch 39/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - loss: 1395.7672 - val_loss: 1289.5057 - learning_rate: 0.0010
# Epoch 40/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - loss: 1382.7635 - val_loss: 1288.4429 - learning_rate: 0.0010
# Epoch 41/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - loss: 1358.8772 - val_loss: 1287.3547 - learning_rate: 0.0010
# Epoch 42/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step - loss: 1391.0839 - val_loss: 1286.8636 - learning_rate: 0.0010
# Epoch 43/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - loss: 1373.7111 - val_loss: 1287.3186 - learning_rate: 0.0010
# Epoch 44/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 975us/step - loss: 1379.7832 - val_loss: 1287.1919 - learning_rate: 0.0010
# Epoch 45/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step - loss: 1379.3185 - val_loss: 1287.2932 - learning_rate: 0.0010
# Epoch 46/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1355.9457 - val_loss: 1286.4384 - learning_rate: 0.0010
# Epoch 47/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 998us/step - loss: 1375.3940 - val_loss: 1284.9559 - learning_rate: 0.0010
# Epoch 48/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1361.8480 - val_loss: 1286.1851 - learning_rate: 0.0010
# Epoch 49/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1343.6776 - val_loss: 1287.4994 - learning_rate: 0.0010
# Epoch 50/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1355.8862 - val_loss: 1284.8480 - learning_rate: 0.0010
# Epoch 51/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1366.5361 - val_loss: 1283.4955 - learning_rate: 0.0010
# Epoch 52/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1339.1487 - val_loss: 1283.9989 - learning_rate: 0.0010
# Epoch 53/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - loss: 1374.9708 - val_loss: 1283.4384 - learning_rate: 0.0010
# Epoch 54/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - loss: 1379.8376 - val_loss: 1282.9578 - learning_rate: 0.0010
# Epoch 55/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 988us/step - loss: 1354.6218 - val_loss: 1282.1622 - learning_rate: 0.0010
# Epoch 56/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1348.9268 - val_loss: 1281.4303 - learning_rate: 0.0010
# Epoch 57/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - loss: 1368.6453 - val_loss: 1281.6919 - learning_rate: 0.0010
# Epoch 58/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - loss: 1379.3646 - val_loss: 1281.8770 - learning_rate: 0.0010
# Epoch 59/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 1395.4449 - val_loss: 1280.7666 - learning_rate: 0.0010
# Epoch 60/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1366.7372 - val_loss: 1279.3441 - learning_rate: 0.0010
# Epoch 61/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1365.9988 - val_loss: 1278.3708 - learning_rate: 0.0010
# Epoch 62/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1357.3396 - val_loss: 1279.9641 - learning_rate: 0.0010
# Epoch 63/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1338.6682 - val_loss: 1280.5162 - learning_rate: 0.0010
# Epoch 64/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - loss: 1361.9194 - val_loss: 1278.4941 - learning_rate: 0.0010
# Epoch 65/150
# 487/501 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 1366.2186
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1366.2040 - val_loss: 1278.3768 - learning_rate: 0.0010
# Epoch 66/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - loss: 1347.7690 - val_loss: 1275.3052 - learning_rate: 1.0000e-04
# Epoch 67/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1346.7936 - val_loss: 1275.4246 - learning_rate: 1.0000e-04
# Epoch 68/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 983us/step - loss: 1335.4503 - val_loss: 1275.2257 - learning_rate: 1.0000e-04
# Epoch 69/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1348.0885 - val_loss: 1275.1782 - learning_rate: 1.0000e-04
# Epoch 70/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1384.3425 - val_loss: 1274.9961 - learning_rate: 1.0000e-04
# Epoch 71/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 986us/step - loss: 1367.5112 - val_loss: 1274.8041 - learning_rate: 1.0000e-04
# Epoch 72/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 1365.6848 - val_loss: 1274.8226 - learning_rate: 1.0000e-04
# Epoch 73/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - loss: 1346.4357 - val_loss: 1274.4146 - learning_rate: 1.0000e-04
# Epoch 74/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 988us/step - loss: 1342.2606 - val_loss: 1274.2025 - learning_rate: 1.0000e-04
# Epoch 75/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - loss: 1349.8734 - val_loss: 1274.4292 - learning_rate: 1.0000e-04
# Epoch 76/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - loss: 1364.3439 - val_loss: 1273.8428 - learning_rate: 1.0000e-04
# Epoch 77/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - loss: 1329.7786 - val_loss: 1273.8580 - learning_rate: 1.0000e-04
# Epoch 78/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 996us/step - loss: 1346.0393 - val_loss: 1273.7675 - learning_rate: 1.0000e-04
# Epoch 79/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - loss: 1370.1343 - val_loss: 1273.7688 - learning_rate: 1.0000e-04
# Epoch 80/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1344.1138 - val_loss: 1273.1843 - learning_rate: 1.0000e-04
# Epoch 81/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - loss: 1339.4615 - val_loss: 1273.1345 - learning_rate: 1.0000e-04
# Epoch 82/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - loss: 1357.8025 - val_loss: 1272.8781 - learning_rate: 1.0000e-04
# Epoch 83/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 1368.9639 - val_loss: 1272.7290 - learning_rate: 1.0000e-04
# Epoch 84/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1340.3907 - val_loss: 1272.6046 - learning_rate: 1.0000e-04
# Epoch 85/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1332.7817 - val_loss: 1272.6776 - learning_rate: 1.0000e-04
# Epoch 86/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1322.1365 - val_loss: 1272.1049 - learning_rate: 1.0000e-04
# Epoch 87/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1385.5339 - val_loss: 1272.1570 - learning_rate: 1.0000e-04
# Epoch 88/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1348.8220 - val_loss: 1272.1254 - learning_rate: 1.0000e-04
# Epoch 89/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1351.1993 - val_loss: 1271.8636 - learning_rate: 1.0000e-04
# Epoch 90/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1373.0640 - val_loss: 1271.5782 - learning_rate: 1.0000e-04
# Epoch 91/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1374.3362 - val_loss: 1271.6971 - learning_rate: 1.0000e-04
# Epoch 92/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1331.2305 - val_loss: 1271.5001 - learning_rate: 1.0000e-04
# Epoch 93/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1360.0059 - val_loss: 1271.7222 - learning_rate: 1.0000e-04
# Epoch 94/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1364.7650 - val_loss: 1271.1013 - learning_rate: 1.0000e-04
# Epoch 95/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1359.2841 - val_loss: 1271.3325 - learning_rate: 1.0000e-04
# Epoch 96/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1392.5099 - val_loss: 1271.3665 - learning_rate: 1.0000e-04
# Epoch 97/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1354.8390 - val_loss: 1271.2930 - learning_rate: 1.0000e-04
# Epoch 98/150
# 472/501 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 1354.5157
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1354.4045 - val_loss: 1271.2769 - learning_rate: 1.0000e-04
# Epoch 99/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1360.2573 - val_loss: 1270.7029 - learning_rate: 1.0000e-05
# Epoch 100/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1351.8789 - val_loss: 1270.6495 - learning_rate: 1.0000e-05
# Epoch 101/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1361.8175 - val_loss: 1270.7151 - learning_rate: 1.0000e-05
# Epoch 102/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1337.6765 - val_loss: 1270.7263 - learning_rate: 1.0000e-05
# Epoch 103/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1318.7111 - val_loss: 1270.6616 - learning_rate: 1.0000e-05
# Epoch 104/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1355.8837 - val_loss: 1270.6056 - learning_rate: 1.0000e-05
# Epoch 105/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1353.0209 - val_loss: 1270.6107 - learning_rate: 1.0000e-05
# Epoch 106/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1355.7505 - val_loss: 1270.6150 - learning_rate: 1.0000e-05
# Epoch 107/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1377.2134 - val_loss: 1270.5742 - learning_rate: 1.0000e-05
# Epoch 108/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1368.1456 - val_loss: 1270.5543 - learning_rate: 1.0000e-05
# Epoch 109/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1356.8182 - val_loss: 1270.5541 - learning_rate: 1.0000e-05
# Epoch 110/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 1346.6071 - val_loss: 1270.5042 - learning_rate: 1.0000e-05
# Epoch 111/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1356.8563 - val_loss: 1270.4862 - learning_rate: 1.0000e-05
# Epoch 112/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1336.4678 - val_loss: 1270.5249 - learning_rate: 1.0000e-05
# Epoch 113/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1347.8262 - val_loss: 1270.4742 - learning_rate: 1.0000e-05
# Epoch 114/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1353.3459 - val_loss: 1270.5099 - learning_rate: 1.0000e-05
# Epoch 115/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1356.6304 - val_loss: 1270.4982 - learning_rate: 1.0000e-05
# Epoch 116/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1346.5237 - val_loss: 1270.4938 - learning_rate: 1.0000e-05
# Epoch 117/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1347.3474 - val_loss: 1270.4485 - learning_rate: 1.0000e-05
# Epoch 118/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1355.8651 - val_loss: 1270.4880 - learning_rate: 1.0000e-05
# Epoch 119/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1343.6228 - val_loss: 1270.4276 - learning_rate: 1.0000e-05
# Epoch 120/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 1341.3940 - val_loss: 1270.4357 - learning_rate: 1.0000e-05
# Epoch 121/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1359.7385 - val_loss: 1270.4152 - learning_rate: 1.0000e-05
# Epoch 122/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1324.9991 - val_loss: 1270.4752 - learning_rate: 1.0000e-05
# Epoch 123/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1354.1456 - val_loss: 1270.4166 - learning_rate: 1.0000e-05
# Epoch 124/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1365.0846 - val_loss: 1270.4039 - learning_rate: 1.0000e-05
# Epoch 125/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1324.0216 - val_loss: 1270.4426 - learning_rate: 1.0000e-05
# Epoch 126/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1362.1975 - val_loss: 1270.3625 - learning_rate: 1.0000e-05
# Epoch 127/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1380.2323 - val_loss: 1270.3580 - learning_rate: 1.0000e-05
# Epoch 128/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1346.9015 - val_loss: 1270.3911 - learning_rate: 1.0000e-05
# Epoch 129/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1333.5635 - val_loss: 1270.3783 - learning_rate: 1.0000e-05
# Epoch 130/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1368.4325 - val_loss: 1270.3229 - learning_rate: 1.0000e-05
# Epoch 131/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1353.2349 - val_loss: 1270.3389 - learning_rate: 1.0000e-05
# Epoch 132/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1353.5038 - val_loss: 1270.3457 - learning_rate: 1.0000e-05
# Epoch 133/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1360.7972 - val_loss: 1270.3510 - learning_rate: 1.0000e-05
# Epoch 134/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1353.1615 - val_loss: 1270.2992 - learning_rate: 1.0000e-05
# Epoch 135/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1358.0645 - val_loss: 1270.2729 - learning_rate: 1.0000e-05
# Epoch 136/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1352.6748 - val_loss: 1270.3361 - learning_rate: 1.0000e-05
# Epoch 137/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1316.3420 - val_loss: 1270.2711 - learning_rate: 1.0000e-05
# Epoch 138/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1345.8589 - val_loss: 1270.2926 - learning_rate: 1.0000e-05
# Epoch 139/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1364.2715 - val_loss: 1270.3138 - learning_rate: 1.0000e-05
# Epoch 140/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1354.7262 - val_loss: 1270.3373 - learning_rate: 1.0000e-05
# Epoch 141/150
# 494/501 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 1375.3352
# Epoch 141: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1374.9966 - val_loss: 1270.2874 - learning_rate: 1.0000e-05
# Epoch 142/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1350.8278 - val_loss: 1270.2694 - learning_rate: 1.0000e-06
# Epoch 143/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1331.0739 - val_loss: 1270.2426 - learning_rate: 1.0000e-06
# Epoch 144/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1359.0323 - val_loss: 1270.2473 - learning_rate: 1.0000e-06
# Epoch 145/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1352.9886 - val_loss: 1270.2458 - learning_rate: 1.0000e-06
# Epoch 146/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1344.5175 - val_loss: 1270.2236 - learning_rate: 1.0000e-06
# Epoch 147/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - loss: 1370.6011 - val_loss: 1270.2297 - learning_rate: 1.0000e-06
# Epoch 148/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1346.0763 - val_loss: 1270.2307 - learning_rate: 1.0000e-06
# Epoch 149/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1358.7937 - val_loss: 1270.2479 - learning_rate: 1.0000e-06
# Epoch 150/150
# 483/501 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 1350.4026
# Epoch 150: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1350.5089 - val_loss: 1270.2410 - learning_rate: 1.0000e-06

# %%
HLT_AE.save_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.save_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')
HLT_AE.load_weights('/home/jovyan/Keras_weights/Weights_HLT_AE.weights.h5')
HLT_encoder.load_weights('/home/jovyan/Keras_weights/Weights_HLT_encoder.weights.h5')

# %%
# train L1 model
# train HLT model
history = L1_AE.fit(
    x=datasets['EB_datatrain']['L1_data'], 
    y=datasets['EB_datatrain']['L1_data'], 
    validation_split=0.15, 
    epochs=NUM_EPOCHS, 
    batch_size=BATCH_SIZE, 
    callbacks=callbacks, 
    sample_weight = datasets['EB_datatrain']['weights']
)
# Out:
# Epoch 1/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 645.3751 - val_loss: 497.0924 - learning_rate: 0.0010
# Epoch 2/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 528.0843 - val_loss: 487.0674 - learning_rate: 0.0010
# Epoch 3/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 512.8840 - val_loss: 476.2349 - learning_rate: 0.0010
# Epoch 4/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 506.6286 - val_loss: 468.3342 - learning_rate: 0.0010
# Epoch 5/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 502.5429 - val_loss: 462.4378 - learning_rate: 0.0010
# Epoch 6/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 490.9015 - val_loss: 456.2537 - learning_rate: 0.0010
# Epoch 7/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 484.2981 - val_loss: 451.3101 - learning_rate: 0.0010
# Epoch 8/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 481.6163 - val_loss: 447.5033 - learning_rate: 0.0010
# Epoch 9/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 469.5871 - val_loss: 443.5516 - learning_rate: 0.0010
# Epoch 10/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 470.7473 - val_loss: 442.6421 - learning_rate: 0.0010
# Epoch 11/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 479.5190 - val_loss: 440.2016 - learning_rate: 0.0010
# Epoch 12/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 473.9997 - val_loss: 438.2818 - learning_rate: 0.0010
# Epoch 13/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 469.2216 - val_loss: 436.8624 - learning_rate: 0.0010
# Epoch 14/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 467.6353 - val_loss: 435.5431 - learning_rate: 0.0010
# Epoch 15/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 466.5979 - val_loss: 435.4241 - learning_rate: 0.0010
# Epoch 16/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 464.2582 - val_loss: 434.0046 - learning_rate: 0.0010
# Epoch 17/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 456.1392 - val_loss: 433.7537 - learning_rate: 0.0010
# Epoch 18/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 467.2558 - val_loss: 432.3719 - learning_rate: 0.0010
# Epoch 19/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 455.4703 - val_loss: 431.7746 - learning_rate: 0.0010
# Epoch 20/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 459.8343 - val_loss: 431.5833 - learning_rate: 0.0010
# Epoch 21/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 998us/step - loss: 458.4640 - val_loss: 430.6973 - learning_rate: 0.0010
# Epoch 22/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.4881 - val_loss: 429.5536 - learning_rate: 0.0010
# Epoch 23/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 458.0211 - val_loss: 429.4907 - learning_rate: 0.0010
# Epoch 24/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 460.1954 - val_loss: 429.6715 - learning_rate: 0.0010
# Epoch 25/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 454.8216 - val_loss: 428.5889 - learning_rate: 0.0010
# Epoch 26/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 461.4007 - val_loss: 428.6654 - learning_rate: 0.0010
# Epoch 27/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 455.8922 - val_loss: 427.2144 - learning_rate: 0.0010
# Epoch 28/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 459.0213 - val_loss: 427.4166 - learning_rate: 0.0010
# Epoch 29/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 452.9569 - val_loss: 426.4006 - learning_rate: 0.0010
# Epoch 30/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 457.0400 - val_loss: 426.2170 - learning_rate: 0.0010
# Epoch 31/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.1485 - val_loss: 425.5422 - learning_rate: 0.0010
# Epoch 32/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.0269 - val_loss: 425.1222 - learning_rate: 0.0010
# Epoch 33/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.9519 - val_loss: 425.1377 - learning_rate: 0.0010
# Epoch 34/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 455.8568 - val_loss: 424.7542 - learning_rate: 0.0010
# Epoch 35/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.5738 - val_loss: 423.8435 - learning_rate: 0.0010
# Epoch 36/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.5985 - val_loss: 423.7887 - learning_rate: 0.0010
# Epoch 37/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.3277 - val_loss: 424.0145 - learning_rate: 0.0010
# Epoch 38/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 459.2457 - val_loss: 424.3197 - learning_rate: 0.0010
# Epoch 39/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.7573 - val_loss: 423.2564 - learning_rate: 0.0010
# Epoch 40/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 452.8362 - val_loss: 422.4890 - learning_rate: 0.0010
# Epoch 41/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.0143 - val_loss: 422.1668 - learning_rate: 0.0010
# Epoch 42/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.6621 - val_loss: 422.3417 - learning_rate: 0.0010
# Epoch 43/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.0881 - val_loss: 421.9283 - learning_rate: 0.0010
# Epoch 44/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 459.1688 - val_loss: 421.4412 - learning_rate: 0.0010
# Epoch 45/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.8967 - val_loss: 422.9365 - learning_rate: 0.0010
# Epoch 46/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 456.9442 - val_loss: 421.7394 - learning_rate: 0.0010
# Epoch 47/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.5936 - val_loss: 422.1655 - learning_rate: 0.0010
# Epoch 48/150
# 452/501 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 447.5073
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.7128 - val_loss: 421.5146 - learning_rate: 0.0010
# Epoch 49/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 441.8838 - val_loss: 420.1380 - learning_rate: 1.0000e-04
# Epoch 50/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 448.5553 - val_loss: 420.3534 - learning_rate: 1.0000e-04
# Epoch 51/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.3719 - val_loss: 420.1173 - learning_rate: 1.0000e-04
# Epoch 52/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.6498 - val_loss: 420.0571 - learning_rate: 1.0000e-04
# Epoch 53/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.3626 - val_loss: 420.0749 - learning_rate: 1.0000e-04
# Epoch 54/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.7855 - val_loss: 420.0342 - learning_rate: 1.0000e-04
# Epoch 55/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 457.5501 - val_loss: 419.9607 - learning_rate: 1.0000e-04
# Epoch 56/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.9138 - val_loss: 419.9308 - learning_rate: 1.0000e-04
# Epoch 57/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.9164 - val_loss: 419.8721 - learning_rate: 1.0000e-04
# Epoch 58/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 452.1839 - val_loss: 419.8869 - learning_rate: 1.0000e-04
# Epoch 59/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.3298 - val_loss: 419.8105 - learning_rate: 1.0000e-04
# Epoch 60/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 439.9318 - val_loss: 419.9144 - learning_rate: 1.0000e-04
# Epoch 61/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.6257 - val_loss: 419.6451 - learning_rate: 1.0000e-04
# Epoch 62/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.6705 - val_loss: 419.7054 - learning_rate: 1.0000e-04
# Epoch 63/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.4376 - val_loss: 419.6094 - learning_rate: 1.0000e-04
# Epoch 64/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 443.7115 - val_loss: 419.6740 - learning_rate: 1.0000e-04
# Epoch 65/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.3022 - val_loss: 419.5966 - learning_rate: 1.0000e-04
# Epoch 66/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.4154 - val_loss: 419.4936 - learning_rate: 1.0000e-04
# Epoch 67/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 441.6183 - val_loss: 419.5274 - learning_rate: 1.0000e-04
# Epoch 68/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 439.4767 - val_loss: 419.5074 - learning_rate: 1.0000e-04
# Epoch 69/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 443.3537 - val_loss: 419.5760 - learning_rate: 1.0000e-04
# Epoch 70/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 443.7819 - val_loss: 419.4362 - learning_rate: 1.0000e-04
# Epoch 71/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.5298 - val_loss: 419.3599 - learning_rate: 1.0000e-04
# Epoch 72/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.3610 - val_loss: 419.3993 - learning_rate: 1.0000e-04
# Epoch 73/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 448.1722 - val_loss: 419.5052 - learning_rate: 1.0000e-04
# Epoch 74/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - loss: 436.8041 - val_loss: 419.3837 - learning_rate: 1.0000e-04
# Epoch 75/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.5027 - val_loss: 419.3357 - learning_rate: 1.0000e-04
# Epoch 76/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.6024 - val_loss: 419.2740 - learning_rate: 1.0000e-04
# Epoch 77/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.0775 - val_loss: 419.2601 - learning_rate: 1.0000e-04
# Epoch 78/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.7477 - val_loss: 419.2244 - learning_rate: 1.0000e-04
# Epoch 79/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.3131 - val_loss: 419.2318 - learning_rate: 1.0000e-04
# Epoch 80/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.6543 - val_loss: 419.2416 - learning_rate: 1.0000e-04
# Epoch 81/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.0019 - val_loss: 419.1647 - learning_rate: 1.0000e-04
# Epoch 82/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.0023 - val_loss: 419.1710 - learning_rate: 1.0000e-04
# Epoch 83/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 443.5006 - val_loss: 419.2364 - learning_rate: 1.0000e-04
# Epoch 84/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.6537 - val_loss: 419.1494 - learning_rate: 1.0000e-04
# Epoch 85/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.1576 - val_loss: 419.0866 - learning_rate: 1.0000e-04
# Epoch 86/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.2552 - val_loss: 419.0334 - learning_rate: 1.0000e-04
# Epoch 87/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.6172 - val_loss: 419.0565 - learning_rate: 1.0000e-04
# Epoch 88/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.4051 - val_loss: 419.0355 - learning_rate: 1.0000e-04
# Epoch 89/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.2768 - val_loss: 418.9573 - learning_rate: 1.0000e-04
# Epoch 90/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.5629 - val_loss: 418.8995 - learning_rate: 1.0000e-04
# Epoch 91/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.1122 - val_loss: 418.9409 - learning_rate: 1.0000e-04
# Epoch 92/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.7590 - val_loss: 418.8466 - learning_rate: 1.0000e-04
# Epoch 93/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 443.9847 - val_loss: 418.9085 - learning_rate: 1.0000e-04
# Epoch 94/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.6942 - val_loss: 418.8616 - learning_rate: 1.0000e-04
# Epoch 95/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 441.7478 - val_loss: 418.8814 - learning_rate: 1.0000e-04
# Epoch 96/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.7422 - val_loss: 418.7550 - learning_rate: 1.0000e-04
# Epoch 97/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 453.3646 - val_loss: 418.7587 - learning_rate: 1.0000e-04
# Epoch 98/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 441.9130 - val_loss: 418.8155 - learning_rate: 1.0000e-04
# Epoch 99/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.6163 - val_loss: 418.7527 - learning_rate: 1.0000e-04
# Epoch 100/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.7194 - val_loss: 418.7302 - learning_rate: 1.0000e-04
# Epoch 101/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.0280 - val_loss: 418.7925 - learning_rate: 1.0000e-04
# Epoch 102/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 441.6518 - val_loss: 418.7447 - learning_rate: 1.0000e-04
# Epoch 103/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.0002 - val_loss: 418.7174 - learning_rate: 1.0000e-04
# Epoch 104/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.8213 - val_loss: 418.5942 - learning_rate: 1.0000e-04
# Epoch 105/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 439.4406 - val_loss: 418.6998 - learning_rate: 1.0000e-04
# Epoch 106/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.6974 - val_loss: 418.6683 - learning_rate: 1.0000e-04
# Epoch 107/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.7380 - val_loss: 418.6581 - learning_rate: 1.0000e-04
# Epoch 108/150
# 483/501 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 445.7211
# Epoch 108: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.7051 - val_loss: 418.6219 - learning_rate: 1.0000e-04
# Epoch 109/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 451.6182 - val_loss: 418.4498 - learning_rate: 1.0000e-05
# Epoch 110/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.9732 - val_loss: 418.4528 - learning_rate: 1.0000e-05
# Epoch 111/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.3003 - val_loss: 418.4583 - learning_rate: 1.0000e-05
# Epoch 112/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.3571 - val_loss: 418.4419 - learning_rate: 1.0000e-05
# Epoch 113/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.1854 - val_loss: 418.4356 - learning_rate: 1.0000e-05
# Epoch 114/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 433.5167 - val_loss: 418.4332 - learning_rate: 1.0000e-05
# Epoch 115/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 448.9022 - val_loss: 418.4435 - learning_rate: 1.0000e-05
# Epoch 116/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.4808 - val_loss: 418.4294 - learning_rate: 1.0000e-05
# Epoch 117/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.0425 - val_loss: 418.4142 - learning_rate: 1.0000e-05
# Epoch 118/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 441.3428 - val_loss: 418.4109 - learning_rate: 1.0000e-05
# Epoch 119/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 439.8421 - val_loss: 418.4200 - learning_rate: 1.0000e-05
# Epoch 120/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 443.9528 - val_loss: 418.4119 - learning_rate: 1.0000e-05
# Epoch 121/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.8899 - val_loss: 418.4162 - learning_rate: 1.0000e-05
# Epoch 122/150
# 463/501 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 446.4365
# Epoch 122: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.3113 - val_loss: 418.4252 - learning_rate: 1.0000e-05
# Epoch 123/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.0050 - val_loss: 418.4090 - learning_rate: 1.0000e-06
# Epoch 124/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.8403 - val_loss: 418.4046 - learning_rate: 1.0000e-06
# Epoch 125/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 445.1472 - val_loss: 418.4072 - learning_rate: 1.0000e-06
# Epoch 126/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.1762 - val_loss: 418.4034 - learning_rate: 1.0000e-06
# Epoch 127/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.5969 - val_loss: 418.4023 - learning_rate: 1.0000e-06
# Epoch 128/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.6152 - val_loss: 418.3977 - learning_rate: 1.0000e-06
# Epoch 129/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.0282 - val_loss: 418.4026 - learning_rate: 1.0000e-06
# Epoch 130/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.4769 - val_loss: 418.3977 - learning_rate: 1.0000e-06
# Epoch 131/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 442.8409 - val_loss: 418.3957 - learning_rate: 1.0000e-06
# Epoch 132/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 438.0861 - val_loss: 418.3986 - learning_rate: 1.0000e-06
# Epoch 133/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.3716 - val_loss: 418.4020 - learning_rate: 1.0000e-06
# Epoch 134/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 446.3890 - val_loss: 418.3987 - learning_rate: 1.0000e-06
# Epoch 135/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 440.4161 - val_loss: 418.3955 - learning_rate: 1.0000e-06
# Epoch 136/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 449.8537 - val_loss: 418.3952 - learning_rate: 1.0000e-06
# Epoch 137/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 443.9487 - val_loss: 418.3967 - learning_rate: 1.0000e-06
# Epoch 138/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 447.9964 - val_loss: 418.4010 - learning_rate: 1.0000e-06
# Epoch 139/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.1735 - val_loss: 418.3974 - learning_rate: 1.0000e-06
# Epoch 140/150
# 486/501 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 444.7359
# Epoch 140: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 444.7239 - val_loss: 418.4026 - learning_rate: 1.0000e-06
# Epoch 141/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 436.5637 - val_loss: 418.4052 - learning_rate: 1.0000e-07
# Epoch 142/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 450.0929 - val_loss: 418.4047 - learning_rate: 1.0000e-07
# Epoch 143/150
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 438.4598 - val_loss: 418.3978 - learning_rate: 1.0000e-07
# Epoch 144/150
# 478/501 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 438.3842
# Epoch 144: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 438.6658 - val_loss: 418.4041 - learning_rate: 1.0000e-07

# %%
L1_AE.save_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.save_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')
L1_AE.load_weights('/home/jovyan/Keras_weights/Weights_L1_AE.weights.h5')
L1_encoder.load_weights('/home/jovyan/Keras_weights/Weights_L1_encoder.weights.h5')

# %%
##Model Evaluation

# %%
# Pass the datasets through the model

for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue

    dict['HLT_model_outputs'] = HLT_AE.predict(dict['HLT_data'])
    #dict['HLT_latent_reps'] = HLT_encoder.predict(dict['HLT_data'])
    dict['L1_model_outputs'] = L1_AE.predict(dict['L1_data'])
    #dict['L1_latent_reps'] = L1_encoder.predict(dict['L1_data'])
# Out:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 563us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 576us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 558us/step
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 1s 542us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 551us/step
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 1s 554us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 558us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 567us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 569us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 564us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 563us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 556us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 573us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 556us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 538us/step
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 546us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 27s 575us/step
# 46918/46918 ━━━━━━━━━━━━━━━━━━━━ 27s 566us/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 477/477 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 5s 577us/step
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 5s 569us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 564us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 565us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 676us/step
# 4715/4715 ━━━━━━━━━━━━━━━━━━━━ 3s 634us/step

# %%
def mse_loss(true, prediction):
    loss = np.mean(np.square(true - prediction), axis=-1)
    return loss

# %%
def MSE_AD_score(y, x):
    # masked mse
    mask = (y != 0) & (y != -999)
    _x = x * mask
    _y = y * mask
    # return (mse_loss(_y, _x))
    return (mse_loss(y, x))

# %%
# Calculate the AD scores

for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue

    dict['HLT_AD_scores'] = MSE_AD_score(dict['HLT_data'], dict['HLT_model_outputs'])
    dict['L1_AD_scores'] = MSE_AD_score(dict['L1_data'], dict['L1_model_outputs'])

# %%
# Display the structure of updated datasets
for tag, data in datasets.items():
    print(f'\n{tag}:')
    for key, value in data.items():
        print(f'{key}: {value.shape}')
# Out:
# jjJZ4:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# A14N23LO:
# HLT_data: (10000, 60)
# L1_data: (10000, 60)
# passL1: (10000,)
# passHLT: (10000,)
# weights: (10000,)
# HLT_model_outputs: (10000, 60)
# L1_model_outputs: (10000, 60)
# HLT_AD_scores: (10000,)
# L1_AD_scores: (10000,)
#
# HAHMggfZdZd2l2nu:
# HLT_data: (70000, 60)
# L1_data: (70000, 60)
# passL1: (70000,)
# passHLT: (70000,)
# weights: (70000,)
# HLT_model_outputs: (70000, 60)
# L1_model_outputs: (70000, 60)
# HLT_AD_scores: (70000,)
# L1_AD_scores: (70000,)
#
# qqa:
# HLT_data: (50000, 60)
# L1_data: (50000, 60)
# passL1: (50000,)
# passHLT: (50000,)
# weights: (50000,)
# HLT_model_outputs: (50000, 60)
# L1_model_outputs: (50000, 60)
# HLT_AD_scores: (50000,)
# L1_AD_scores: (50000,)
#
# ZZ4lep:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# Zprime2EJs:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# HHbbttHadHad:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ2:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# jjJZ1:
# HLT_data: (100000, 60)
# L1_data: (100000, 60)
# passL1: (100000,)
# passHLT: (100000,)
# weights: (100000,)
# HLT_model_outputs: (100000, 60)
# L1_model_outputs: (100000, 60)
# HLT_AD_scores: (100000,)
# L1_AD_scores: (100000,)
#
# EB_zerobias:
# HLT_data: (1501347, 60)
# L1_data: (1501347, 60)
# passL1: (1501347,)
# passHLT: (1501347,)
# weights: (1501347,)
# HLT_model_outputs: (1501347, 60)
# L1_model_outputs: (1501347, 60)
# HLT_AD_scores: (1501347,)
# L1_AD_scores: (1501347,)
#
# EB_passHLT:
# HLT_data: (15255, 60)
# L1_data: (15255, 60)
# passL1: (15255,)
# passHLT: (15255,)
# weights: (15255,)
# HLT_model_outputs: (15255, 60)
# L1_model_outputs: (15255, 60)
# HLT_AD_scores: (15255,)
# L1_AD_scores: (15255,)
#
# jjJZ1&2&4:
# HLT_data: (300000, 60)
# L1_data: (300000, 60)
# passL1: (300000,)
# passHLT: (300000,)
# weights: (300000,)
# HLT_model_outputs: (300000, 60)
# L1_model_outputs: (300000, 60)
# HLT_AD_scores: (300000,)
# L1_AD_scores: (300000,)
#
# EB_datatrain:
# HLT_data: (301743, 60)
# L1_data: (301743, 60)
# passL1: (301743,)
# passHLT: (301743,)
# weights: (301743,)
#
# EB_datatest1:
# HLT_data: (150871, 60)
# L1_data: (150871, 60)
# passL1: (150871,)
# passHLT: (150871,)
# weights: (150871,)
# HLT_model_outputs: (150871, 60)
# L1_model_outputs: (150871, 60)
# HLT_AD_scores: (150871,)
# L1_AD_scores: (150871,)
#
# EB_datatest2:
# HLT_data: (150872, 60)
# L1_data: (150872, 60)
# passL1: (150872,)
# passHLT: (150872,)
# weights: (150872,)
# HLT_model_outputs: (150872, 60)
# L1_model_outputs: (150872, 60)
# HLT_AD_scores: (150872,)
# L1_AD_scores: (150872,)

# %%
def ROC_curve(dataset, bkg_type, target_rate=10, plot=True):
    """
    Plots ROC curve and returns AUC, TPR, FPR, and thresholds for each dataset.
    
    inputs: 
    dataset: dictionary containing dataset information
    bkg_type: the background type to calculate over
    plot: whether to plot the ROC curve or not
    
    returns:
    results: dictionary {dataset_names: {'TPR': ..., 'AUC': ..., 'FPR': ..., 'threshold': ...}}
    """
    
    bkg_tag = 'EB_datatest1'
    #target_rate = 10  # 10 Hz pure rate
    plt.figure(figsize=(8.5,6.8))
    
    results = {}
    
    for tag in dataset.keys():
        if tag != bkg_tag and tag != 'EB_datatrain':
        
            # Combine true labels, anomaly=1 and background=0
            trueVal = np.concatenate((np.ones(dataset[tag][f'{bkg_type}_AD_scores'].shape[0]), np.zeros(dataset[bkg_tag][f'{bkg_type}_AD_scores'].shape[0])))
            
            # Combine predictions from current dataset and background
            predVal_loss = np.concatenate((dataset[tag][f'{bkg_type}_AD_scores'], dataset[bkg_tag][f'{bkg_type}_AD_scores']))
        
            sample_weights = np.concatenate((dataset[tag]['weights'], dataset[bkg_tag]['weights']))
            
            for i in range(len(predVal_loss)):
                if np.isnan(predVal_loss[i]):
                    predVal_loss[i] = 0
           
            # Calculate ROC curve and AUC, including weights
            fpr_loss, tpr_loss, threshold_loss = sklearn.metrics.roc_curve(y_true=trueVal, y_score=predVal_loss, sample_weight=sample_weights)
            auc_loss = auc(fpr_loss, tpr_loss)

            # Initialize variables for early stopping
            min_diff = float('inf')
            best_idx = 0
            previous_diff = float('inf')
            
            # Iterate over thresholds with early stopping
            for idx, value in enumerate(threshold_loss):
                anomaly_idxs_bkg = dataset[bkg_tag][f'{bkg_type}_AD_scores'] > value
                bkg_rate = 100000 * np.sum(dataset[bkg_tag]['weights'] * (anomaly_idxs_bkg & ~dataset[bkg_tag]['passHLT'])) / np.sum(dataset[bkg_tag]['weights'])
                # Calculate the difference from the target rate
                diff = abs(bkg_rate - target_rate)
                
                # Check if the difference is decreasing
                if diff < min_diff:
                    min_diff = diff
                    best_idx = idx
                else:
                    # If the difference starts increasing, break the loop
                    if diff > previous_diff:
                        print(f'Background rate = {bkg_rate:.3}Hz')
                        break
                
                previous_diff = diff
            
            # Use the best index found
            selected_threshold = threshold_loss[best_idx]
            selected_fpr = fpr_loss[best_idx]
            signal_tpr = tpr_loss[best_idx]
            
            # Store the results
            results[tag] = {
                'TPR': signal_tpr,
                'AUC': auc_loss,
                'FPR': selected_fpr,
                'threshold': selected_threshold
            }
        
            # Plot ROC curve
            if plot:
                plt.plot(fpr_loss, tpr_loss, "-", label='%s (AUC = %.1f%%)' % (tag, auc_loss*100.), linewidth=1.5)

    if plot:
        # Set log scale for x and y axis
        plt.semilogx()
        plt.semilogy()
        
        # Plot aesthetics and layout
        plt.plot(np.linspace(0, 1), np.linspace(0, 1), '--', color='0.75')
        plt.plot([selected_fpr, selected_fpr], [0, 1], '--', color='r')
        plt.ylabel("True Positive Rate", fontsize=16)
        plt.xlabel("False Positive Rate", fontsize=16)
        plt.legend(loc='lower right', fontsize=6)
        plt.grid(True)
        plt.tight_layout()
        plt.title(f'Trained over {bkg_type} objects', fontsize=20)
        plt.show()

    return results

# %%
for target_rate in [10, 200, 1000]:
    print(f'TARGET (PURE) RATE::::: {target_rate}')
    HLT_results = ROC_curve(datasets, bkg_type='HLT', target_rate=target_rate)
    L1_results = ROC_curve(datasets, bkg_type='L1', target_rate=target_rate)

    # L1 Signal Efficiencies

    tags = []
    l1_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            L1_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            L1_anomaly_idxs = datasets[tag]['L1_AD_scores'] > L1_results[tag]['threshold']
            L1_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | L1_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            l1_efficiencies.append(L1_TPR)
            combined_efficiencies.append(L1_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, l1_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(l1_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, L1 Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()



    # Signal Efficiencies

    tags = []
    hlt_efficiencies = []
    combined_efficiencies = []
    
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag, dict in datasets.items():
        if tag in skip_tags: 
            continue
    
        # Extract HLT and L1 results from the respective dictionaries
        hlt_result = HLT_results.get(tag)
        l1_result = L1_results.get(tag)
        
        if hlt_result and l1_result:
            # Extract TPR for regular HLT efficiency
            #HLT_TPR = hlt_result['TPR']
            HLT_TPR = np.sum(dict['passHLT'] * dict['weights']) / np.sum(dict['weights'])
            
            # Calculate the combined efficiency (HLT + Anomaly Detection)
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_results[tag]['threshold']
            HLT_or_anom_TPR = np.sum((datasets[tag]['passHLT'] | HLT_anomaly_idxs) * datasets[tag]['weights']) / np.sum(datasets[tag]['weights'])
            
            tags.append(tag)
            hlt_efficiencies.append(HLT_TPR)
            combined_efficiencies.append(HLT_or_anom_TPR)
    
    # Create bar plot
    fig, ax = plt.subplots(figsize=(16, 6))
    
    # Plot regular HLT efficiency
    bar_width = 0.2
    index = np.arange(len(tags))
    bar1 = ax.bar(index, hlt_efficiencies, bar_width, label='Regular HLT Efficiency', color='cornflowerblue', edgecolor='k', linewidth=2)
    
    # Plot combined efficiency (HLT + Anomaly Detection)
    bar2 = ax.bar(index + bar_width, combined_efficiencies, bar_width, label='HLT + Anomaly Detection Efficiency', color='mediumvioletred', edgecolor='k', linewidth=2)
    print(f'Normalized by the left bar:\n{np.array(combined_efficiencies) / np.array(hlt_efficiencies)}')
    # Add labels and title
    ax.set_xlabel('Tags', fontsize=15)
    ax.set_ylabel('Efficiency', fontsize=15)
    ax.set_title('Signal Efficiencies, HLT Objects', fontsize=16)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(tags)
    #ax.set_yscale('log')
    ax.legend(fontsize=6)
    
    plt.tight_layout()
    plt.show()
    
    # HLT overlaps
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = HLT_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['HLT_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")

    # HLT overlaps
    skip_tags = ['EB_datatrain', 'EB_datatest1']
    for tag in datasets.keys():
        if tag in skip_tags:
            continue
    
        # Extract relevant information from the results dictionaries
        hlt_result = L1_results.get(tag)
        
        if hlt_result:
            HLT_threshold = hlt_result['threshold']
            
            # Calculate HLT anomaly indices based on the threshold
            HLT_anomaly_idxs = datasets[tag]['L1_AD_scores'] > HLT_threshold
    
            # Calculate overlaps
            HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
            inverse_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs | datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * datasets[tag]['passHLT'])
    
            # Print the results
            print(f'-----\n{tag}:')
            print(f'HLT overlap: {HLT_overlap}')
            print(f'inverse overlap: {inverse_overlap}')
            print(f"Weighted percentage of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT']) / len(datasets[tag]['passHLT'])}")
            print(f"Weighted percentage of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs) / len(HLT_anomaly_idxs)}")
            print(f'Raw number of events that we tagged as anomalous: {np.sum(HLT_anomaly_idxs)}')
            print(f"Raw number of events that passed some HLT trigger: {np.sum(datasets[tag]['passHLT'])}")
            print(f"Raw number of events that we tagged as anomalous and passed some HLT trigger: {np.sum(HLT_anomaly_idxs * datasets[tag]['passHLT'])}")
# Out:
# TARGET (PURE) RATE::::: 10
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 13.9Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Background rate = 11.5Hz
# Normalized by the left bar:
# [ 1.00003054  1.03854167  1.01031207  1.05208563  1.00407704  1.00007947
#   1.00137731  1.35480859  3.8287037  12.28779345  1.          1.009999
#   1.00293754]
# Normalized by the left bar:
# [1.         1.         1.00002083 1.         1.00001148 1.
#  1.         1.         1.         1.         1.         1.
#  1.        ]
# -----
# jjJZ4:
# HLT overlap: 0.8571428571428571
# inverse overlap: 1.000010180914857
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 7e-05
# Raw number of events that we tagged as anomalous: 7
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 6
# -----
# A14N23LO:
# HLT overlap: 0.0
# inverse overlap: 1.0002604166666667
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0001
# Raw number of events that we tagged as anomalous: 1
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.6666666666666666
# inverse overlap: 1.000020832465314
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 4.2857142857142856e-05
# Raw number of events that we tagged as anomalous: 3
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# qqa:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# ZZ4lep:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 5e-05
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# Zprime2EJs:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# HHbbttHadHad:
# HLT overlap: 0.0
# inverse overlap: 1.0000367282476954
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 2e-05
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ2:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.0
# inverse overlap: 1.0092592592592593
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 2e-05
# Raw number of events that we tagged as anomalous: 2
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_zerobias:
# HLT overlap: 0.0
# inverse overlap: 60.876695452251475
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 5.2619414432506276e-05
# Raw number of events that we tagged as anomalous: 79
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_passHLT:
# HLT overlap: nan
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0
# Raw number of events that we tagged as anomalous: 0
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1&2&4:
# HLT overlap: 0.6666666666666666
# inverse overlap: 1.000030147723847
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 3e-05
# Raw number of events that we tagged as anomalous: 9
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 6
# -----
# EB_datatest2:
# HLT overlap: 0.0
# inverse overlap: 1.007794073943146
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.00015907524258974495
# Raw number of events that we tagged as anomalous: 24
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ4:
# HLT overlap: 0.9797297297297297
# inverse overlap: 1.000030542744571
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00148
# Raw number of events that we tagged as anomalous: 148
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 145
# -----
# A14N23LO:
# HLT overlap: 0.23316062176165803
# inverse overlap: 1.0385416666666667
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0193
# Raw number of events that we tagged as anomalous: 193
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 45
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7177879133409351
# inverse overlap: 1.010312070330403
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.025057142857142858
# Raw number of events that we tagged as anomalous: 1754
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1259
# -----
# qqa:
# HLT overlap: 0.078125
# inverse overlap: 1.0520856323107481
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00512
# Raw number of events that we tagged as anomalous: 256
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 20
# -----
# ZZ4lep:
# HLT overlap: 0.8449104412407165
# inverse overlap: 1.0040770388065188
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.02289
# Raw number of events that we tagged as anomalous: 2289
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1934
# -----
# Zprime2EJs:
# HLT overlap: 0.8970588235294118
# inverse overlap: 1.0000794659885568
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00068
# Raw number of events that we tagged as anomalous: 68
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 61
# -----
# HHbbttHadHad:
# HLT overlap: 0.4444444444444444
# inverse overlap: 1.0013773092885738
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00135
# Raw number of events that we tagged as anomalous: 135
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 60
# -----
# jjJZ2:
# HLT overlap: 0.01808785529715762
# inverse overlap: 1.3548085901027078
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00387
# Raw number of events that we tagged as anomalous: 387
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 7
# -----
# jjJZ1:
# HLT overlap: 0.008116883116883116
# inverse overlap: 3.8287037037037037
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00616
# Raw number of events that we tagged as anomalous: 616
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 5
# -----
# EB_zerobias:
# HLT overlap: 0.00030407041084383235
# inverse overlap: 12.287793453067778
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 5.9946168340829935e-05
# Raw number of events that we tagged as anomalous: 90
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.00039331366764995085
# Raw number of events that we tagged as anomalous: 6
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 6
# -----
# jjJZ1&2&4:
# HLT overlap: 0.1370338248048569
# inverse overlap: 1.0099989950758719
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.003843333333333333
# Raw number of events that we tagged as anomalous: 1153
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 158
# -----
# EB_datatest2:
# HLT overlap: 0.1794073332165793
# inverse overlap: 1.0029375439052988
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 7.290948618696644e-05
# Raw number of events that we tagged as anomalous: 11
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# TARGET (PURE) RATE::::: 200
# /tmp/ipykernel_218/1416309897.py:126: RuntimeWarning: invalid value encountered in scalar divide
#   HLT_overlap = np.sum(datasets[tag]['weights'] * (HLT_anomaly_idxs & datasets[tag]['passHLT'])) / np.sum(datasets[tag]['weights'] * HLT_anomaly_idxs)
# Background rate = 2.1e+02Hz
# Background rate = 2.1e+02Hz
# Background rate = 2.09e+02Hz
# Background rate = 2.1e+02Hz
# Background rate = 2.1e+02Hz
# Background rate = 2.1e+02Hz
# Background rate = 2.1e+02Hz
# Background rate = 2.09e+02Hz
# Background rate = 2.1e+02Hz
# Background rate = 2.09e+02Hz
# Background rate = 2.1e+02Hz
# Background rate = 2.09e+02Hz
# Background rate = 2.09e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.17e+02Hz
# Background rate = 2.16e+02Hz
# Background rate = 2.16e+02Hz
# Normalized by the left bar:
# [  1.00082465   1.34088542   1.08607975   2.12668285   1.03294936
#    1.00189583   1.04063981   7.51727358  37.53240741 162.23623054
#    1.           1.1502663    1.10565962]
# Normalized by the left bar:
# [1.00001018 1.00651042 1.00179159 1.00816597 1.00078095 1.00001135
#  1.00018364 1.0410831  1.4212963  1.69176926 1.         1.0013667
#  1.00032605]
# -----
# jjJZ4:
# HLT overlap: 0.9375
# inverse overlap: 1.000020361829714
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00032
# Raw number of events that we tagged as anomalous: 32
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 30
# -----
# A14N23LO:
# HLT overlap: 0.4
# inverse overlap: 1.00078125
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0005
# Raw number of events that we tagged as anomalous: 5
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.8
# inverse overlap: 1.0001666597225116
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.0005714285714285715
# Raw number of events that we tagged as anomalous: 40
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 32
# -----
# qqa:
# HLT overlap: 0.16666666666666666
# inverse overlap: 1.002207018318252
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00024
# Raw number of events that we tagged as anomalous: 12
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2
# -----
# ZZ4lep:
# HLT overlap: 0.8333333333333334
# inverse overlap: 1.0001033615472075
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00054
# Raw number of events that we tagged as anomalous: 54
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 45
# -----
# Zprime2EJs:
# HLT overlap: 0.75
# inverse overlap: 1.0000113522840794
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 4e-05
# Raw number of events that we tagged as anomalous: 4
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3
# -----
# HHbbttHadHad:
# HLT overlap: 0.34782608695652173
# inverse overlap: 1.0002754618577148
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00023
# Raw number of events that we tagged as anomalous: 23
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 8
# -----
# jjJZ2:
# HLT overlap: 0.0
# inverse overlap: 1.0410830999066294
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00044
# Raw number of events that we tagged as anomalous: 44
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# jjJZ1:
# HLT overlap: 0.025
# inverse overlap: 1.1805555555555556
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.0004
# Raw number of events that we tagged as anomalous: 40
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_zerobias:
# HLT overlap: 0.0
# inverse overlap: 1006.999695570381
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.000979120749566889
# Raw number of events that we tagged as anomalous: 1470
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 0
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.0019665683382497543
# Raw number of events that we tagged as anomalous: 30
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 30
# -----
# jjJZ1&2&4:
# HLT overlap: 0.2672413793103448
# inverse overlap: 1.000854185508994
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.00038666666666666667
# Raw number of events that we tagged as anomalous: 116
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 31
# -----
# EB_datatest2:
# HLT overlap: 0.018122766097524744
# inverse overlap: 1.1052372403993895
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.0018028527493504428
# Raw number of events that we tagged as anomalous: 272
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 6
# -----
# jjJZ4:
# HLT overlap: 0.9786110377607605
# inverse overlap: 1.0008246541034178
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.03787
# Raw number of events that we tagged as anomalous: 3787
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3706
# -----
# A14N23LO:
# HLT overlap: 0.2905149051490515
# inverse overlap: 1.3408854166666666
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.1845
# Raw number of events that we tagged as anomalous: 1845
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 536
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.6848447868202273
# inverse overlap: 1.0860797466772218
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.1873
# Raw number of events that we tagged as anomalous: 13111
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 8979
# -----
# qqa:
# HLT overlap: 0.09549964564138909
# inverse overlap: 2.1266828514676672
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.11288
# Raw number of events that we tagged as anomalous: 5644
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 539
# -----
# ZZ4lep:
# HLT overlap: 0.8406996113270405
# inverse overlap: 1.0329493643264847
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.1801
# Raw number of events that we tagged as anomalous: 18010
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 15141
# -----
# Zprime2EJs:
# HLT overlap: 0.9134266459305339
# inverse overlap: 1.001895831441286
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.01929
# Raw number of events that we tagged as anomalous: 1929
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1762
# -----
# HHbbttHadHad:
# HLT overlap: 0.46968607716271266
# inverse overlap: 1.040639806074852
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.04173
# Raw number of events that we tagged as anomalous: 4173
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1960
# -----
# jjJZ2:
# HLT overlap: 0.014820042342978124
# inverse overlap: 7.5172735760971054
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.07085
# Raw number of events that we tagged as anomalous: 7085
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 105
# -----
# jjJZ1:
# HLT overlap: 0.006546644844517185
# inverse overlap: 37.532407407407405
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.07943
# Raw number of events that we tagged as anomalous: 7943
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 52
# -----
# EB_zerobias:
# HLT overlap: 0.0004904597422697901
# inverse overlap: 162.23623053613187
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.0009864475034752126
# Raw number of events that we tagged as anomalous: 1481
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 23
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.006686332350049164
# Raw number of events that we tagged as anomalous: 102
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 102
# -----
# jjJZ1&2&4:
# HLT overlap: 0.20534622947334857
# inverse overlap: 1.1502663048939805
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.06272333333333334
# Raw number of events that we tagged as anomalous: 18817
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 3864
# -----
# EB_datatest2:
# HLT overlap: 0.057932813143291066
# inverse overlap: 1.1056596237488632
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.0014117927779839865
# Raw number of events that we tagged as anomalous: 213
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 20
# TARGET (PURE) RATE::::: 1000
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1.01e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Background rate = 1e+03Hz
# Normalized by the left bar:
# [  1.00565041   1.90989583   1.24286488   5.57161774   1.09030354
#    1.02523613   1.21271165  35.55835668 166.40740741 890.86692157
#    1.           1.73656919   1.92382335]
# Normalized by the left bar:
# [ 1.00003054  1.04453125  1.01202033  1.06334143  1.00458236  1.00009082
#   1.00163441  1.41456583  4.34259259 14.28202904  1.          1.01174756
#   1.00293754]
# -----
# jjJZ4:
# HLT overlap: 0.9817073170731707
# inverse overlap: 1.000030542744571
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.00164
# Raw number of events that we tagged as anomalous: 164
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 161
# -----
# A14N23LO:
# HLT overlap: 0.5384615384615384
# inverse overlap: 1.003125
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.0026
# Raw number of events that we tagged as anomalous: 26
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 14
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.7476190476190476
# inverse overlap: 1.0011041206616391
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.003
# Raw number of events that we tagged as anomalous: 210
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 157
# -----
# qqa:
# HLT overlap: 0.22388059701492538
# inverse overlap: 1.0114764952549107
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.00134
# Raw number of events that we tagged as anomalous: 67
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 15
# -----
# ZZ4lep:
# HLT overlap: 0.9011627906976745
# inverse overlap: 1.0003904769561174
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.00344
# Raw number of events that we tagged as anomalous: 344
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 310
# -----
# Zprime2EJs:
# HLT overlap: 0.7916666666666666
# inverse overlap: 1.0000567614203977
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.00024
# Raw number of events that we tagged as anomalous: 24
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 19
# -----
# HHbbttHadHad:
# HLT overlap: 0.41964285714285715
# inverse overlap: 1.0011936680500972
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.00112
# Raw number of events that we tagged as anomalous: 112
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 47
# -----
# jjJZ2:
# HLT overlap: 0.01593625498007968
# inverse overlap: 1.23062558356676
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.00251
# Raw number of events that we tagged as anomalous: 251
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 4
# -----
# jjJZ1:
# HLT overlap: 0.0036363636363636364
# inverse overlap: 2.2685185185185186
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.00275
# Raw number of events that we tagged as anomalous: 275
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1
# -----
# EB_zerobias:
# HLT overlap: 6.4115764457008534e-06
# inverse overlap: 4821.8944487972385
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.004859636046829947
# Raw number of events that we tagged as anomalous: 7296
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 9
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.008718452966240577
# Raw number of events that we tagged as anomalous: 133
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 133
# -----
# jjJZ1&2&4:
# HLT overlap: 0.24057971014492754
# inverse overlap: 1.0052658024319163
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.0023
# Raw number of events that we tagged as anomalous: 690
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 166
# -----
# EB_datatest2:
# HLT overlap: 0.007619241909801166
# inverse overlap: 1.8914475286144237
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.007986902805026778
# Raw number of events that we tagged as anomalous: 1205
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 22
# -----
# jjJZ4:
# HLT overlap: 0.9807164448768284
# inverse overlap: 1.00565040774564
# Weighted percentage of events that passed some HLT trigger: 0.98223
# Weighted percentage of events that we tagged as anomalous: 0.28781
# Raw number of events that we tagged as anomalous: 28781
# Raw number of events that passed some HLT trigger: 98223
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 28226
# -----
# A14N23LO:
# HLT overlap: 0.3320588797553049
# inverse overlap: 1.9098958333333333
# Weighted percentage of events that passed some HLT trigger: 0.384
# Weighted percentage of events that we tagged as anomalous: 0.5231
# Raw number of events that we tagged as anomalous: 5231
# Raw number of events that passed some HLT trigger: 3840
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 1737
# -----
# HAHMggfZdZd2l2nu:
# HLT overlap: 0.68301702104519
# inverse overlap: 1.2428648806299738
# Weighted percentage of events that passed some HLT trigger: 0.6857428571428571
# Weighted percentage of events that we tagged as anomalous: 0.5254
# Raw number of events that we tagged as anomalous: 36778
# Raw number of events that passed some HLT trigger: 48002
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 25120
# -----
# qqa:
# HLT overlap: 0.09224768832990052
# inverse overlap: 5.571617744427279
# Weighted percentage of events that passed some HLT trigger: 0.09062
# Weighted percentage of events that we tagged as anomalous: 0.45638
# Raw number of events that we tagged as anomalous: 22819
# Raw number of events that passed some HLT trigger: 4531
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 2105
# -----
# ZZ4lep:
# HLT overlap: 0.8535426911041574
# inverse overlap: 1.0903035384102995
# Weighted percentage of events that passed some HLT trigger: 0.87073
# Weighted percentage of events that we tagged as anomalous: 0.53688
# Raw number of events that we tagged as anomalous: 53688
# Raw number of events that passed some HLT trigger: 87073
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 45825
# -----
# Zprime2EJs:
# HLT overlap: 0.8850925255866846
# inverse overlap: 1.0252361275088548
# Weighted percentage of events that passed some HLT trigger: 0.88088
# Weighted percentage of events that we tagged as anomalous: 0.19346
# Raw number of events that we tagged as anomalous: 19346
# Raw number of events that passed some HLT trigger: 88088
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 17123
# -----
# HHbbttHadHad:
# HLT overlap: 0.5316783245057211
# inverse overlap: 1.2127116465273442
# Weighted percentage of events that passed some HLT trigger: 0.54454
# Weighted percentage of events that we tagged as anomalous: 0.24733
# Raw number of events that we tagged as anomalous: 24733
# Raw number of events that passed some HLT trigger: 54454
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 13150
# -----
# jjJZ2:
# HLT overlap: 0.013092285950457297
# inverse overlap: 35.55835667600373
# Weighted percentage of events that passed some HLT trigger: 0.01071
# Weighted percentage of events that we tagged as anomalous: 0.37503
# Raw number of events that we tagged as anomalous: 37503
# Raw number of events that passed some HLT trigger: 1071
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 491
# -----
# jjJZ1:
# HLT overlap: 0.004069799855048225
# inverse overlap: 166.40740740740742
# Weighted percentage of events that passed some HLT trigger: 0.00216
# Weighted percentage of events that we tagged as anomalous: 0.35874
# Raw number of events that we tagged as anomalous: 35874
# Raw number of events that passed some HLT trigger: 216
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 146
# -----
# EB_zerobias:
# HLT overlap: 0.00024310741532959407
# inverse overlap: 890.866921569337
# Weighted percentage of events that passed some HLT trigger: 0.00020847945211866412
# Weighted percentage of events that we tagged as anomalous: 0.004157599808705116
# Raw number of events that we tagged as anomalous: 6242
# Raw number of events that passed some HLT trigger: 313
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 63
# -----
# EB_passHLT:
# HLT overlap: 1.0
# inverse overlap: 1.0
# Weighted percentage of events that passed some HLT trigger: 1.0
# Weighted percentage of events that we tagged as anomalous: 0.023795476892822024
# Raw number of events that we tagged as anomalous: 363
# Raw number of events that passed some HLT trigger: 15255
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 363
# -----
# jjJZ1&2&4:
# HLT overlap: 0.28253719655442444
# inverse overlap: 1.7365691890262285
# Weighted percentage of events that passed some HLT trigger: 0.3317
# Weighted percentage of events that we tagged as anomalous: 0.34053333333333335
# Raw number of events that we tagged as anomalous: 102160
# Raw number of events that passed some HLT trigger: 99510
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 28864
# -----
# EB_datatest2:
# HLT overlap: 0.02344633301281823
# inverse overlap: 1.9238233451211295
# Weighted percentage of events that passed some HLT trigger: 0.024908531735510896
# Weighted percentage of events that we tagged as anomalous: 0.010790603955671033
# Raw number of events that we tagged as anomalous: 1628
# Raw number of events that passed some HLT trigger: 3758
# Raw number of events that we tagged as anomalous and passed some HLT trigger: 76

# %%
#HLT
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
#HLT
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
#HLT
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = hlt_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['HLT_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['HLT_AD_scores'])):
            if (HLT_max_pt_vals[tag][n] > l) and (HLT_max_pt_vals[tag][n] < r) and (HLT_jet_mults[tag][n] > 1) and (HLT_electron_mults[tag][n] > 1) and (HLT_muon_mults[tag][n] > 1) and (HLT_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['HLT_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    ax1.hist(HLT_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1

plt.xticks(np.arange(0, 2000,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
#L1
efficiencies = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies[tag] = efficiency

# %%
efficiencies2 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n]  > 5):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies2[tag] = efficiency

# %%
efficiencies3 = {}

bins = np.zeros(20)
bins[0] = 50
for i in range(1,20):
    bins[i] = 100 + bins[i-1]
    
for tag, dict in datasets.items():
    efficiency = np.zeros(20)
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    threshold = l1_result['threshold']
    for i in range(0,20):
        mask = np.zeros((len(datasets[tag]['L1_AD_scores'])),dtype='bool')
        l = i * 100
        r = i * 100 + 100
        for n in range(len(datasets[tag]['L1_AD_scores'])):
            if (L1_max_pt_vals[tag][n] > l) and (L1_max_pt_vals[tag][n] < r) and (L1_jet_mults[tag][n] > 1) and (L1_electron_mults[tag][n] > 1) and (L1_muon_mults[tag][n] > 1) and (L1_photon_mults[tag][n] > 1):
                mask[n] = True
        data1 = datasets[tag]['L1_AD_scores'][mask]
        weight = datasets[tag]['weights'][mask]
        sumA = 0
        sumB = 0
        for j in range(len(data1)):
            if data1[j] > threshold:
                sumA += weight[j]
            sumB += weight[j]
        if sumB != 0:
            efficiency[i] = sumA/sumB
    efficiencies3[tag] = efficiency

# %%
fig, ax1 = plt.subplots(figsize=(10, 12))
    # Plot on the left y-axis (logarithmic scale)
ax1.set_yscale('log')
ax1.set_xlabel('Max pt')
ax1.set_ylabel('Density')
ax1.set_ylim(1e-6, 1e-2)
    # Create a second y-axis for efficiency
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency')
ax2.set_ylim(0, 1)

i = 0
for tag, dict in datasets.items():
    if tag == 'EB_datatest1': continue
    if tag == 'EB_datatrain': continue
    ax1.hist(L1_max_pt_vals[tag], bins=np.linspace(0,2000, 20), label=f'Max Pt Distribution {tag}', histtype='step', ls='--', density=True, fill=False, linewidth=1, weights=datasets[tag]['weights'],color=new_color_cycle[i])
    ax2.scatter(bins,efficiencies[tag],s=20,c=new_color_cycle[i],marker="o",label=f'Efficiencies of {tag}')
    ax2.scatter(bins,efficiencies2[tag],s=20,c=new_color_cycle[i],marker="v",label=f'Efficiencies of {tag} at least 5 jets')
    ax2.scatter(bins,efficiencies3[tag],s=20,c=new_color_cycle[i],marker="s",label=f'Efficiencies of {tag} at least 1 of each object')
    i += 1
plt.xlim(0, 800)
plt.xticks(np.arange(0, 800,100))
plt.title(f'Efficiency Plots', loc='center')
ax1.legend(loc='upper left', fontsize=6)
ax2.legend(loc='upper right', fontsize=6)
plt.show()

# %%
import ROOT

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "HLT" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/Root/HLT', f"{title}_plot.png")
    canvas.SaveAs(output_path)

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "L1" + tag + "max pt v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 1600, 50, 0, 5)
    histogram.SetXTitle("Max pt")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_max_pt_vals[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,1600,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "HLT" + tag + "jet mult v ad score  "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(HLT_jet_mults[tag], datasets[tag]['HLT_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = hlt_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)

# %%
for tag, dict in datasets.items():
    if tag == 'EB_datatrain': continue
    title = "L1" + tag + "jet mult v ad score "
    histogram = ROOT.TH2F(title, title, 50, 0, 10, 50, 0, 5)
    histogram.SetXTitle("Jet Multiplicity")  
    histogram.SetYTitle("AD Score")
    for x, y in zip(L1_jet_mults[tag], datasets[tag]['L1_AD_scores']):
        histogram.Fill(x, y)
    norm = 1
    binsX = 50  
    binsY = 50  
    for i in range(1, binsX + 1):
        num_events = 0.0
        for j in range(1, binsY + 1):
            bincont = histogram.GetBinContent(i, j)
            num_events += bincont
        if num_events > 0: 
            for j in range(1, binsY + 1):
                bincont = histogram.GetBinContent(i, j)
                fact = norm / num_events
                value = bincont * fact
                histogram.SetBinContent(i, j, value)
    ROOT.gStyle.SetStatX(0.9)  
    ROOT.gStyle.SetStatY(0.9)   
    ROOT.gStyle.SetStatW(0.1) 
    ROOT.gStyle.SetStatH(0.1)
        
    canvas = ROOT.TCanvas(title,title, 450, 300)
    canvas.SetLogz()  
    histogram.Draw("COLZ") 
    threshold = l1_result['threshold']

    redline = ROOT.TLine(0,threshold,10,threshold)
    redline.SetLineWidth(2)
    redline.SetLineColor(2)
    redline.Draw()
        
    canvas.Update()
    canvas.Draw()
    output_path = os.path.join('/home/jovyan/RootPlots/Final5', f"{title}_plot.png")
    canvas.SaveAs(output_path)
